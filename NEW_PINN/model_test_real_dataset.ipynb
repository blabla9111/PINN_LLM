# %%
import sys
sys.path.append("../")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
from pathlib import Path
from sklearn.metrics import mean_squared_error, mean_absolute_error
import json

# ============================================================
# НАСТРОЙКА
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Фиксируем seed
torch.manual_seed(123)
if device.type == 'cuda':
    torch.cuda.manual_seed(123)
np.random.seed(123)
torch.backends.cudnn.deterministic = True

# Создаем папку для результатов
results_dir = Path("real_datasets_results")
results_dir.mkdir(exist_ok=True)

# ============================================================
# ЗАГРУЗКА РЕАЛЬНЫХ ДАННЫХ
# ============================================================

print("="*60)
print("ЗАГРУЗКА РЕАЛЬНОГО ДАТАСЕТА")
print("="*60)

# Загружаем данные
df_real = pd.read_csv('real_datasets\covid-19_Kouprianov.csv')

# Переименовываем колонки для удобства (если нужно)
df_real.columns = ['t', 'I', 'D', 'S', 'R']

# Получаем данные
timesteps = df_real['t'].values.astype(float)
S = df_real['S'].values
I = df_real['I'].values
D = df_real['D'].values
R = df_real['R'].values

population = S[0] + I[0] + R[0] + D[0]  # Общая популяция в начале

print(f"Всего точек данных: {len(timesteps)}")
print(f"Население: {population}")
print(f"Диапазон времени: {timesteps[0]} - {timesteps[-1]} дней")

# ============================================================
# РАЗМЕРЫ ОБУЧАЮЩЕЙ ВЫБОРКИ ДЛЯ ТЕСТИРОВАНИЯ
# ============================================================

train_sizes = [120, 150, 180, 200, 220]

# ============================================================
# ФУНКЦИИ ДЛЯ РАСЧЕТА МЕТРИК
# ============================================================

def calculate_metrics(y_true, y_pred):
    """Рассчитывает MSE, RMSE, MAE для временных рядов"""
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae}

# ============================================================
# ФУНКЦИЯ ДЛЯ ВИЗУАЛИЗАЦИИ С ПУНКТИРНОЙ ЛИНИЕЙ
# ============================================================

def plot_real_data_results(df_true, df_pred_model1, df_pred_model2, train_size, save_dir):
    """Создает визуализацию для реальных данных с пунктирной линией train/test"""
    
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    fig.suptitle(f'Реальные данные: COVID-19 (train_size={train_size})', 
                 fontsize=16, fontweight='bold')
    
    t = df_true['t'].values
    
    # Вертикальная линия, разделяющая train и test
    train_cutoff = t[train_size - 1] if train_size < len(t) else t[-1]
    
    # 1. Инфицированные I(t)
    ax = axes[0, 0]
    ax.plot(t, df_true['I'], 'k-', linewidth=2.5, label='Реальные данные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['I'])], df_pred_model1['I'], 'r--', linewidth=2, label='Модель 1 (конст)')
    ax.plot(t[:len(df_pred_model2['I'])], df_pred_model2['I'], 'b--', linewidth=2, label='Модель 2 (врем)')
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2, 
               label=f'Граница train/test (день {train_cutoff:.0f})')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Инфицированные')
    ax.set_title('Динамика I(t)')
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    # 2. Умершие D(t)
    ax = axes[0, 1]
    ax.plot(t, df_true['D'], 'k-', linewidth=2.5, label='Реальные данные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['D'])], df_pred_model1['D'], 'r--', linewidth=2, label='Модель 1')
    ax.plot(t[:len(df_pred_model2['D'])], df_pred_model2['D'], 'b--', linewidth=2, label='Модель 2')
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Умершие')
    ax.set_title('Динамика D(t)')
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    # 3. Выздоровевшие R(t)
    ax = axes[0, 2]
    ax.plot(t, df_true['R'], 'k-', linewidth=2.5, label='Реальные данные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['R'])], df_pred_model1['R'], 'r--', linewidth=2, label='Модель 1')
    ax.plot(t[:len(df_pred_model2['R'])], df_pred_model2['R'], 'b--', linewidth=2, label='Модель 2')
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Выздоровевшие')
    ax.set_title('Динамика R(t)')
    ax.legend(loc='upper left', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    # 4. Восприимчивые S(t)
    ax = axes[1, 0]
    ax.plot(t, df_true['S'], 'k-', linewidth=2.5, label='Реальные данные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['S'])], df_pred_model1['S'], 'r--', linewidth=2, label='Модель 1')
    ax.plot(t[:len(df_pred_model2['S'])], df_pred_model2['S'], 'b--', linewidth=2, label='Модель 2')
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Восприимчивые')
    ax.set_title('Динамика S(t)')
    ax.legend(loc='upper right', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    # 5. Параметры модели 2 (β, γ, μ)
    ax = axes[1, 1]
    if 'beta' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['beta'])], df_pred_model2['beta'], 
                'orange', linewidth=2, label='β(t)')
    if 'gamma' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['gamma'])], df_pred_model2['gamma'], 
                'green', linewidth=2, label='γ(t)')
    if 'mu' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['mu'])], df_pred_model2['mu'], 
                'brown', linewidth=2, label='μ(t)')
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Значения параметров')
    ax.set_title('Параметры модели 2 (временные)')
    ax.legend(loc='upper right', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    # 6. Репродуктивное число R₀ (для модели 2)
    ax = axes[1, 2]
    if 'R0' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['R0'])], df_pred_model2['R0'], 
                'purple', linewidth=2, label='R₀(t) - модель 2')
    # Добавляем константное R₀ для модели 1
    if 'R0_const' in df_pred_model1.columns:
        r0_const = df_pred_model1['R0_const'].iloc[0]
        ax.axhline(y=r0_const, color='red', linestyle='--', linewidth=2, 
                   label=f'R₀ const = {r0_const:.3f} (мод 1)')
    ax.axhline(y=1.0, color='black', linestyle='-', linewidth=1, alpha=0.5)
    ax.axvline(x=train_cutoff, color='gray', linestyle=':', linewidth=2)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('R₀')
    ax.set_title('Репродуктивное число')
    ax.legend(loc='upper right', fontsize=8)
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(save_dir / f"real_data_train{train_size}_comparison.png", 
                dpi=150, bbox_inches='tight')
    plt.close()

# ============================================================
# ОСНОВНОЙ ЦИКЛ ТЕСТИРОВАНИЯ
# ============================================================

def run_real_data_testing():
    """Запускает тестирование на реальных данных"""
    
    results = []
    
    print("="*80)
    print("НАЧАЛО ТЕСТИРОВАНИЯ НА РЕАЛЬНЫХ ДАННЫХ")
    print("="*80)
    
    for train_size in train_sizes:
        print(f"\n{'='*60}")
        print(f"ТЕСТИРОВАНИЕ: train_size = {train_size}")
        print('='*60)
        
        try:
            # Проверяем, что train_size не превышает длину данных
            if train_size > len(timesteps):
                print(f"❌ train_size ({train_size}) больше длины данных ({len(timesteps)})")
                continue
            
            # ==================================================
            # МОДЕЛЬ 1: EINN_PINN (константные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 1 (константные параметры) ---")
            
            from NEW_PINN.PINN_const import EINN_PINN
            
            model1 = EINN_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                R_data=R,
                D_data=D,
                population=population,
                train_size=train_size,
                device=device
            )
            
            # Обучаем
            model1.train_model(n_epoch=20000, lambda_data=0.01, lambda_ode=1.0)
            
            # Получаем параметры
            final_params = model1.params.get_params_dict()
            
            # Предсказание
            S_pred1, I_pred1, R_pred1, D_pred1 = model1.predict(timesteps)
            
            # Конвертируем в numpy
            S_pred1 = S_pred1.numpy()
            I_pred1 = I_pred1.numpy()
            R_pred1 = R_pred1.numpy()
            D_pred1 = D_pred1.numpy()
            
            # Создаем DataFrame с предсказаниями модели 1
            df_pred1 = pd.DataFrame({
                't': timesteps[:len(S_pred1)],
                'S': S_pred1,
                'I': I_pred1,
                'R': R_pred1,
                'D': D_pred1,
                'beta_const': final_params['beta'],
                'gamma_const': final_params['gamma'],
                'mu_const': final_params['mu']
            })
            df_pred1['R0_const'] = df_pred1['beta_const'] / (df_pred1['gamma_const'] + df_pred1['mu_const'])
            
            # ==================================================
            # МОДЕЛЬ 2: Nature_PINN (временные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 2 (временные параметры) ---")
            
            from NEW_PINN.PINN_time import Nature_PINN
            
            model2 = Nature_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                D_data=D,
                R_data=R,
                device=device,
                train_size=train_size,
                population_n=population
            )
            
            # Обучаем
            model2.train(n_epoch=20000)
            
            # Получаем предсказания
            predictions = model2.predict()
            
            # Создаем DataFrame с предсказаниями модели 2
            df_pred2 = pd.DataFrame({
                't': predictions['t'][:len(predictions['S'])],
                'S': predictions['S'],
                'I': predictions['I'],
                'R': predictions['R'],
                'D': predictions['D'],
                'beta': predictions['beta'],
                'gamma': predictions['gamma'],
                'mu': predictions['mu']
            })
            df_pred2['R0'] = df_pred2['beta'] / (df_pred2['gamma'] + df_pred2['mu'])
            
            # ==================================================
            # РАСЧЕТ МЕТРИК
            # ==================================================
            
            # Обрезаем до одинаковой длины
            min_len = min(len(df_real), len(df_pred1), len(df_pred2))
            df_real_trim = df_real.iloc[:min_len]
            df_pred1_trim = df_pred1.iloc[:min_len]
            df_pred2_trim = df_pred2.iloc[:min_len]
            
            # Метрики для SIRD
            metrics_model1 = {}
            metrics_model2 = {}
            
            # Метрики на всей выборке
            for compartment in ['S', 'I', 'R', 'D']:
                true_vals = df_real_trim[compartment].values
                pred1_vals = df_pred1_trim[compartment].values
                pred2_vals = df_pred2_trim[compartment].values
                
                metrics_model1[compartment] = calculate_metrics(true_vals, pred1_vals)
                metrics_model2[compartment] = calculate_metrics(true_vals, pred2_vals)
            
            # Метрики только на тестовой части (после train_size)
            if train_size < min_len:
                test_metrics_model1 = {}
                test_metrics_model2 = {}
                
                for compartment in ['S', 'I', 'R', 'D']:
                    true_vals = df_real_trim[compartment].values[train_size:]
                    pred1_vals = df_pred1_trim[compartment].values[train_size:]
                    pred2_vals = df_pred2_trim[compartment].values[train_size:]
                    
                    if len(true_vals) > 0:
                        test_metrics_model1[compartment] = calculate_metrics(true_vals, pred1_vals)
                        test_metrics_model2[compartment] = calculate_metrics(true_vals, pred2_vals)
            else:
                test_metrics_model1 = None
                test_metrics_model2 = None
            
            # ==================================================
            # СОХРАНЕНИЕ РЕЗУЛЬТАТОВ
            # ==================================================
            
            # Сохраняем предсказания
            df_pred1.to_csv(results_dir / f"real_data_model1_train{train_size}.csv", index=False)
            df_pred2.to_csv(results_dir / f"real_data_model2_train{train_size}.csv", index=False)
            
            # Сохраняем метрики
            result_entry = {
                'train_size': train_size,
                'test_size': min_len - train_size,
                
                # Модель 1
                'model1_I_RMSE': metrics_model1['I']['RMSE'],
                'model1_I_MAE': metrics_model1['I']['MAE'],
                'model1_D_RMSE': metrics_model1['D']['RMSE'],
                'model1_D_MAE': metrics_model1['D']['MAE'],
                'model1_beta': final_params['beta'],
                'model1_gamma': final_params['gamma'],
                'model1_mu': final_params['mu'],
                'model1_R0': final_params['beta'] / (final_params['gamma'] + final_params['mu']),
                
                # Модель 2
                'model2_I_RMSE': metrics_model2['I']['RMSE'],
                'model2_I_MAE': metrics_model2['I']['MAE'],
                'model2_D_RMSE': metrics_model2['D']['RMSE'],
                'model2_D_MAE': metrics_model2['D']['MAE'],
                'model2_beta_mean': np.mean(df_pred2['beta']),
                'model2_gamma_mean': np.mean(df_pred2['gamma']),
                'model2_mu_mean': np.mean(df_pred2['mu']),
                'model2_R0_mean': np.mean(df_pred2['R0']),
            }
            
            # Добавляем тестовые метрики если есть
            if test_metrics_model1 and test_metrics_model2:
                result_entry.update({
                    'model1_test_I_RMSE': test_metrics_model1['I']['RMSE'],
                    'model1_test_D_RMSE': test_metrics_model1['D']['RMSE'],
                    'model2_test_I_RMSE': test_metrics_model2['I']['RMSE'],
                    'model2_test_D_RMSE': test_metrics_model2['D']['RMSE'],
                })
            
            results.append(result_entry)
            
            # ==================================================
            # ВИЗУАЛИЗАЦИЯ
            # ==================================================
            
            plot_real_data_results(df_real, df_pred1, df_pred2, train_size, results_dir)
            
            print(f"\n✅ Завершено: train_size={train_size}")
            print(f"   Модель 1 - I_RMSE: {metrics_model1['I']['RMSE']:.2f}, R₀={result_entry['model1_R0']:.3f}")
            print(f"   Модель 2 - I_RMSE: {metrics_model2['I']['RMSE']:.2f}, R₀_mean={result_entry['model2_R0_mean']:.3f}")
            
        except Exception as e:
            print(f"❌ Ошибка при train_size={train_size}: {str(e)}")
            import traceback
            traceback.print_exc()
            continue
    
    # ==================================================
    # СОХРАНЕНИЕ СВОДНЫХ РЕЗУЛЬТАТОВ
    # ==================================================
    
    df_results = pd.DataFrame(results)
    df_results.to_csv(results_dir / "real_data_summary.csv", index=False)
    
    with open(results_dir / "real_data_summary.json", 'w') as f:
        json.dump(results, f, indent=2, default=str)
    
    print("\n" + "="*80)
    print("ТЕСТИРОВАНИЕ НА РЕАЛЬНЫХ ДАННЫХ ЗАВЕРШЕНО")
    print("="*80)
    print(f"Результаты сохранены в: {results_dir.absolute()}")
    
    return df_results

# ============================================================
# ФУНКЦИЯ ДЛЯ ВИЗУАЛИЗАЦИИ СВОДНЫХ РЕЗУЛЬТАТОВ
# ============================================================

def plot_real_data_summary(df_results):
    """Создает сводные графики по результатам на реальных данных"""
    
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle('Реальные данные: сводные результаты по размерам обучающей выборки', 
                 fontsize=16, fontweight='bold')
    
    train_sizes = df_results['train_size'].values
    
    # 1. Сравнение RMSE для I(t)
    ax = axes[0, 0]
    ax.plot(train_sizes, df_results['model1_I_RMSE'], 'ro-', linewidth=2, markersize=8, label='Модель 1')
    ax.plot(train_sizes, df_results['model2_I_RMSE'], 'bo-', linewidth=2, markersize=8, label='Модель 2')
    ax.set_xlabel('Размер обучающей выборки (дней)')
    ax.set_ylabel('RMSE для I(t)')
    ax.set_title('Точность предсказания I(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 2. Сравнение RMSE для D(t)
    ax = axes[0, 1]
    ax.plot(train_sizes, df_results['model1_D_RMSE'], 'ro-', linewidth=2, markersize=8, label='Модель 1')
    ax.plot(train_sizes, df_results['model2_D_RMSE'], 'bo-', linewidth=2, markersize=8, label='Модель 2')
    ax.set_xlabel('Размер обучающей выборки (дней)')
    ax.set_ylabel('RMSE для D(t)')
    ax.set_title('Точность предсказания смертности')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 3. Оценка R₀
    ax = axes[1, 0]
    ax.plot(train_sizes, df_results['model1_R0'], 'ro-', linewidth=2, markersize=8, label='Модель 1 (конст)')
    ax.plot(train_sizes, df_results['model2_R0_mean'], 'bo-', linewidth=2, markersize=8, label='Модель 2 (средний)')
    ax.axhline(y=1.0, color='gray', linestyle='--', alpha=0.7)
    ax.set_xlabel('Размер обучающей выборки (дней)')
    ax.set_ylabel('R₀')
    ax.set_title('Оценка репродуктивного числа')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 4. Оценка параметров модели 1
    ax = axes[1, 1]
    ax.plot(train_sizes, df_results['model1_beta'], 'orange', marker='o', linewidth=2, label='β')
    ax.plot(train_sizes, df_results['model1_gamma'], 'green', marker='s', linewidth=2, label='γ')
    ax.plot(train_sizes, df_results['model1_mu'], 'brown', marker='^', linewidth=2, label='μ')
    ax.set_xlabel('Размер обучающей выборки (дней)')
    ax.set_ylabel('Значения параметров')
    ax.set_title('Модель 1: оценка параметров')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(results_dir / "real_data_summary.png", dpi=150, bbox_inches='tight')
    plt.show()

# ============================================================
# ЗАПУСК
# ============================================================

if __name__ == "__main__":
    # Запускаем тестирование на реальных данных
    df_results = run_real_data_testing()
    
    # Строим сводные графики
    if len(df_results) > 0:
        plot_real_data_summary(df_results)
    
    print("\n" + "="*80)
    print("ГОТОВО! Все результаты сохранены.")
    print("="*80)
# Out:
# Using device: cuda
# ============================================================
# ЗАГРУЗКА РЕАЛЬНОГО ДАТАСЕТА
# ============================================================
# Всего точек данных: 369
# Население: 6000000
# Диапазон времени: 0.0 - 368.0 дней
# ================================================================================
# НАЧАЛО ТЕСТИРОВАНИЯ НА РЕАЛЬНЫХ ДАННЫХ
# ================================================================================
#
# ============================================================
# ТЕСТИРОВАНИЕ: train_size = 120
# ============================================================
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 14100263.000000 | Data: 121957208.000000 | ODE: 12880691.000000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 839726.187500 | Data: 73228640.000000 | ODE: 107439.828125
# Params: β=0.2944, γ=0.1051, μ=0.0104
# ---
# Epoch  2000 | Loss: 732974.875000 | Data: 59827256.000000 | ODE: 134702.296875
# Params: β=0.2806, γ=0.1189, μ=0.0115
# ---
# Epoch  3000 | Loss: 648569.250000 | Data: 49881908.000000 | ODE: 149750.156250
# Params: β=0.2560, γ=0.1372, μ=0.0137
# ---
# Epoch  4000 | Loss: 562687.437500 | Data: 40623048.000000 | ODE: 156456.953125
# Params: β=0.2256, γ=0.1426, μ=0.0168
# ---
# Epoch  5000 | Loss: 471291.000000 | Data: 30862242.000000 | ODE: 162668.593750
# Params: β=0.1943, γ=0.1255, μ=0.0206
# ---
# Epoch  6000 | Loss: 379058.125000 | Data: 21554790.000000 | ODE: 163510.250000
# Params: β=0.1648, γ=0.1047, μ=0.0250
# ---
# Epoch  7000 | Loss: 296180.781250 | Data: 14335713.000000 | ODE: 152823.656250
# Params: β=0.1396, γ=0.0865, μ=0.0283
# ---
# Epoch  8000 | Loss: 226427.234375 | Data: 9156544.000000 | ODE: 134861.796875
# Params: β=0.1188, γ=0.0723, μ=0.0275
# ---
# Epoch  9000 | Loss: 168398.093750 | Data: 5628736.000000 | ODE: 112110.742188
# Params: β=0.1014, γ=0.0616, μ=0.0243
# ---
# Epoch 10000 | Loss: 122372.429688 | Data: 3343441.500000 | ODE: 88938.015625
# Params: β=0.0870, γ=0.0534, μ=0.0210
# ---
# Epoch 11000 | Loss: 87883.890625 | Data: 1981757.125000 | ODE: 68066.320312
# Params: β=0.0751, γ=0.0467, μ=0.0182
# ---
# Epoch 12000 | Loss: 62603.976562 | Data: 1134604.625000 | ODE: 51257.929688
# Params: β=0.0652, γ=0.0413, μ=0.0158
# ---
# Epoch 13000 | Loss: 44759.503906 | Data: 684446.187500 | ODE: 37915.042969
# Params: β=0.0570, γ=0.0368, μ=0.0138
# ---
# Epoch 14000 | Loss: 32439.820312 | Data: 416249.812500 | ODE: 28277.322266
# Params: β=0.0502, γ=0.0331, μ=0.0120
# ---
# Epoch 15000 | Loss: 24284.291016 | Data: 291727.937500 | ODE: 21367.011719
# Params: β=0.0445, γ=0.0300, μ=0.0105
# ---
# Epoch 16000 | Loss: 18993.501953 | Data: 224340.859375 | ODE: 16750.093750
# Params: β=0.0397, γ=0.0273, μ=0.0092
# ---
# Epoch 17000 | Loss: 15716.923828 | Data: 202164.781250 | ODE: 13695.276367
# Params: β=0.0358, γ=0.0251, μ=0.0081
# ---
# Epoch 18000 | Loss: 13698.384766 | Data: 199888.234375 | ODE: 11699.501953
# Params: β=0.0326, γ=0.0232, μ=0.0071
# ---
# Epoch 19000 | Loss: 12491.441406 | Data: 205400.640625 | ODE: 10437.435547
# Params: β=0.0301, γ=0.0216, μ=0.0063
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 6.84e+06
#   Data Loss: 1.12e+00
#   Physics Loss: 6.84e+06
#   β mean: 0.5096 [min: 0.4782, max: 0.5410]
#   γ mean: 0.2798 [min: 0.2772, max: 0.2824]
#   μ mean: 0.0502 [min: 0.0424, max: 0.0579]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.07e+02
#   Data Loss: 1.35e+00
#   Physics Loss: 1.05e+02
#   β mean: 0.4530 [min: 0.4435, max: 0.4648]
#   γ mean: 0.2755 [min: 0.2721, max: 0.2792]
#   μ mean: 0.0597 [min: 0.0534, max: 0.0651]
#
# Эпоха  2000:
#   Total Loss: 2.83e+01
#   Data Loss: 1.24e+00
#   Physics Loss: 2.70e+01
#   β mean: 0.2920 [min: 0.2893, max: 0.3029]
#   γ mean: 0.2073 [min: 0.2015, max: 0.2173]
#   μ mean: 0.0604 [min: 0.0570, max: 0.0630]
#
# Эпоха  3000:
#   Total Loss: 1.82e+00
#   Data Loss: 9.29e-01
#   Physics Loss: 8.86e-01
#   β mean: 0.0520 [min: 0.0504, max: 0.0548]
#   γ mean: 0.0331 [min: 0.0328, max: 0.0340]
#   μ mean: 0.0188 [min: 0.0181, max: 0.0212]
#
# Эпоха  4000:
#   Total Loss: 1.64e+00
#   Data Loss: 8.26e-01
#   Physics Loss: 8.18e-01
#   β mean: 0.0373 [min: 0.0363, max: 0.0396]
#   γ mean: 0.0309 [min: 0.0307, max: 0.0313]
#   μ mean: 0.0066 [min: 0.0060, max: 0.0085]
#
# Эпоха  5000:
#   Total Loss: 9.04e-01
#   Data Loss: 7.13e-01
#   Physics Loss: 1.90e-01
#   β mean: 0.0317 [min: 0.0308, max: 0.0348]
#   γ mean: 0.0303 [min: 0.0302, max: 0.0307]
#   μ mean: 0.0018 [min: 0.0012, max: 0.0040]
#
# Эпоха  6000:
#   Total Loss: 1.10e+00
#   Data Loss: 6.58e-01
#   Physics Loss: 4.40e-01
#   β mean: 0.0236 [min: 0.0191, max: 0.0324]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0302]
#   μ mean: 0.0009 [min: 0.0008, max: 0.0011]
#
# Эпоха  7000:
#   Total Loss: 6.63e-01
#   Data Loss: 6.40e-01
#   Physics Loss: 2.34e-02
#   β mean: 0.0195 [min: 0.0181, max: 0.0230]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0006 [min: 0.0004, max: 0.0014]
#
# Эпоха  8000:
#   Total Loss: 6.80e-01
#   Data Loss: 6.32e-01
#   Physics Loss: 4.80e-02
#   β mean: 0.0207 [min: 0.0168, max: 0.0284]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0005 [min: 0.0003, max: 0.0013]
#
# Эпоха  9000:
#   Total Loss: 7.20e-01
#   Data Loss: 6.28e-01
#   Physics Loss: 9.12e-02
#   β mean: 0.0221 [min: 0.0157, max: 0.0353]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0004 [min: 0.0002, max: 0.0011]
#
# Эпоха 10000:
#   Total Loss: 6.64e-01
#   Data Loss: 6.28e-01
#   Physics Loss: 3.60e-02
#   β mean: 0.0233 [min: 0.0154, max: 0.0405]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0004 [min: 0.0002, max: 0.0008]
#
# Эпоха 11000:
#   Total Loss: 6.39e-01
#   Data Loss: 6.28e-01
#   Physics Loss: 1.12e-02
#   β mean: 0.0243 [min: 0.0161, max: 0.0418]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0003 [min: 0.0002, max: 0.0007]
#
# Эпоха 12000:
#   Total Loss: 6.82e-01
#   Data Loss: 6.27e-01
#   Physics Loss: 5.54e-02
#   β mean: 0.0262 [min: 0.0188, max: 0.0407]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0003 [min: 0.0002, max: 0.0007]
#
# Эпоха 13000:
#   Total Loss: 6.29e-01
#   Data Loss: 6.26e-01
#   Physics Loss: 2.40e-03
#   β mean: 0.0291 [min: 0.0246, max: 0.0380]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0004 [min: 0.0002, max: 0.0013]
#
# Эпоха 14000:
#   Total Loss: 6.27e-01
#   Data Loss: 6.23e-01
#   Physics Loss: 4.64e-03
#   β mean: 0.0304 [min: 0.0289, max: 0.0343]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0005 [min: 0.0002, max: 0.0020]
#
# Эпоха 15000:
#   Total Loss: 6.22e-01
#   Data Loss: 6.20e-01
#   Physics Loss: 2.82e-03
#   β mean: 0.0305 [min: 0.0295, max: 0.0332]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0004 [min: 0.0001, max: 0.0017]
#
# Эпоха 16000:
#   Total Loss: 6.18e-01
#   Data Loss: 6.14e-01
#   Physics Loss: 3.74e-03
#   β mean: 0.0305 [min: 0.0297, max: 0.0325]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0304]
#   μ mean: 0.0003 [min: 0.0001, max: 0.0013]
#
# Эпоха 17000:
#   Total Loss: 6.13e-01
#   Data Loss: 6.09e-01
#   Physics Loss: 3.45e-03
#   β mean: 0.0305 [min: 0.0298, max: 0.0324]
#   γ mean: 0.0302 [min: 0.0300, max: 0.0310]
#   μ mean: 0.0003 [min: 0.0001, max: 0.0011]
#
# Эпоха 18000:
#   Total Loss: 6.10e-01
#   Data Loss: 6.06e-01
#   Physics Loss: 4.76e-03
#   β mean: 0.0305 [min: 0.0298, max: 0.0322]
#   γ mean: 0.0302 [min: 0.0300, max: 0.0310]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0010]
#
# Эпоха 19000:
#   Total Loss: 6.12e-01
#   Data Loss: 6.02e-01
#   Physics Loss: 9.81e-03
#   β mean: 0.0305 [min: 0.0298, max: 0.0320]
#   γ mean: 0.0302 [min: 0.0300, max: 0.0310]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0010]
#
# ✅ Завершено: train_size=120
#    Модель 1 - I_RMSE: 36702.17, R₀=1.085
#    Модель 2 - I_RMSE: 45790.93, R₀_mean=1.002
#
# ============================================================
# ТЕСТИРОВАНИЕ: train_size = 150
# ============================================================
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 26783770.000000 | Data: 830563584.000000 | ODE: 18478134.000000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 2687312.750000 | Data: 237156976.000000 | ODE: 315743.062500
# Params: β=0.2884, γ=0.1130, μ=0.0109
# ---
# Epoch  2000 | Loss: 1876497.125000 | Data: 151358976.000000 | ODE: 362907.375000
# Params: β=0.2548, γ=0.1399, μ=0.0139
# ---
# Epoch  3000 | Loss: 1372412.875000 | Data: 101330320.000000 | ODE: 359109.656250
# Params: β=0.2188, γ=0.1509, μ=0.0174
# ---
# Epoch  4000 | Loss: 1103982.625000 | Data: 72661400.000000 | ODE: 377368.625000
# Params: β=0.1877, γ=0.1359, μ=0.0207
# ---
# Epoch  5000 | Loss: 880328.500000 | Data: 50625904.000000 | ODE: 374069.437500
# Params: β=0.1602, γ=0.1145, μ=0.0232
# ---
# Epoch  6000 | Loss: 685150.000000 | Data: 33614636.000000 | ODE: 349003.625000
# Params: β=0.1367, γ=0.0962, μ=0.0232
# ---
# Epoch  7000 | Loss: 517396.750000 | Data: 21125674.000000 | ODE: 306140.031250
# Params: β=0.1169, γ=0.0822, μ=0.0207
# ---
# Epoch  8000 | Loss: 387788.375000 | Data: 12990476.000000 | ODE: 257883.625000
# Params: β=0.1005, γ=0.0711, μ=0.0181
# ---
# Epoch  9000 | Loss: 294021.687500 | Data: 8116725.000000 | ODE: 212854.421875
# Params: β=0.0872, γ=0.0623, μ=0.0158
# ---
# Epoch 10000 | Loss: 230778.218750 | Data: 5411780.500000 | ODE: 176660.421875
# Params: β=0.0763, γ=0.0552, μ=0.0138
# ---
# Epoch 11000 | Loss: 192194.000000 | Data: 4172286.500000 | ODE: 150471.140625
# Params: β=0.0677, γ=0.0496, μ=0.0120
# ---
# Epoch 12000 | Loss: 168563.593750 | Data: 3555692.750000 | ODE: 133006.671875
# Params: β=0.0608, γ=0.0453, μ=0.0105
# ---
# Epoch 13000 | Loss: 156909.031250 | Data: 3433350.000000 | ODE: 122575.523438
# Params: β=0.0555, γ=0.0420, μ=0.0093
# ---
# Epoch 14000 | Loss: 151527.671875 | Data: 3477103.250000 | ODE: 116756.640625
# Params: β=0.0518, γ=0.0397, μ=0.0084
# ---
# Epoch 15000 | Loss: 149501.859375 | Data: 3610631.750000 | ODE: 113395.546875
# Params: β=0.0496, γ=0.0383, μ=0.0078
# ---
# Epoch 16000 | Loss: 147124.343750 | Data: 3601685.500000 | ODE: 111107.492188
# Params: β=0.0485, γ=0.0376, μ=0.0075
# ---
# Epoch 17000 | Loss: 145447.000000 | Data: 3608094.750000 | ODE: 109366.062500
# Params: β=0.0481, γ=0.0373, μ=0.0073
# ---
# Epoch 18000 | Loss: 143846.859375 | Data: 3602748.250000 | ODE: 107819.375000
# Params: β=0.0479, γ=0.0372, μ=0.0072
# ---
# Epoch 19000 | Loss: 142386.093750 | Data: 3592641.000000 | ODE: 106459.679688
# Params: β=0.0478, γ=0.0371, μ=0.0071
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 1.39e+07
#   Data Loss: 1.23e+00
#   Physics Loss: 1.39e+07
#   β mean: 0.5096 [min: 0.4946, max: 0.5247]
#   γ mean: 0.2798 [min: 0.2660, max: 0.2936]
#   μ mean: 0.0501 [min: 0.0414, max: 0.0588]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.41e+02
#   Data Loss: 1.03e+00
#   Physics Loss: 1.40e+02
#   β mean: 0.4557 [min: 0.4401, max: 0.4737]
#   γ mean: 0.2506 [min: 0.2410, max: 0.2615]
#   μ mean: 0.0540 [min: 0.0438, max: 0.0636]
#
# Эпоха  2000:
#   Total Loss: 3.30e+01
#   Data Loss: 9.59e-01
#   Physics Loss: 3.20e+01
#   β mean: 0.1071 [min: 0.0913, max: 0.1309]
#   γ mean: 0.0516 [min: 0.0464, max: 0.0598]
#   μ mean: 0.0523 [min: 0.0378, max: 0.0664]
#
# Эпоха  3000:
#   Total Loss: 1.32e+00
#   Data Loss: 7.32e-01
#   Physics Loss: 5.90e-01
#   β mean: 0.0173 [min: 0.0165, max: 0.0190]
#   γ mean: 0.0302 [min: 0.0302, max: 0.0302]
#   μ mean: 0.0010 [min: 0.0008, max: 0.0014]
#
# Эпоха  4000:
#   Total Loss: 6.64e+00
#   Data Loss: 6.27e-01
#   Physics Loss: 6.01e+00
#   β mean: 0.0140 [min: 0.0125, max: 0.0167]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0003]
#
# Эпоха  5000:
#   Total Loss: 2.41e+00
#   Data Loss: 5.44e-01
#   Physics Loss: 1.87e+00
#   β mean: 0.0149 [min: 0.0123, max: 0.0201]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха  6000:
#   Total Loss: 7.77e-01
#   Data Loss: 4.73e-01
#   Physics Loss: 3.04e-01
#   β mean: 0.0140 [min: 0.0120, max: 0.0178]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха  7000:
#   Total Loss: 6.49e-01
#   Data Loss: 4.23e-01
#   Physics Loss: 2.26e-01
#   β mean: 0.0146 [min: 0.0122, max: 0.0196]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха  8000:
#   Total Loss: 8.09e-01
#   Data Loss: 3.94e-01
#   Physics Loss: 4.14e-01
#   β mean: 0.0143 [min: 0.0119, max: 0.0191]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха  9000:
#   Total Loss: 3.89e-01
#   Data Loss: 3.79e-01
#   Physics Loss: 1.04e-02
#   β mean: 0.0146 [min: 0.0120, max: 0.0198]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 10000:
#   Total Loss: 3.89e-01
#   Data Loss: 3.74e-01
#   Physics Loss: 1.45e-02
#   β mean: 0.0146 [min: 0.0120, max: 0.0200]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 11000:
#   Total Loss: 4.38e-01
#   Data Loss: 3.69e-01
#   Physics Loss: 6.94e-02
#   β mean: 0.0147 [min: 0.0120, max: 0.0203]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 12000:
#   Total Loss: 3.85e-01
#   Data Loss: 3.67e-01
#   Physics Loss: 1.84e-02
#   β mean: 0.0136 [min: 0.0116, max: 0.0176]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 13000:
#   Total Loss: 3.67e-01
#   Data Loss: 3.64e-01
#   Physics Loss: 2.66e-03
#   β mean: 0.0139 [min: 0.0117, max: 0.0185]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 14000:
#   Total Loss: 3.62e-01
#   Data Loss: 3.61e-01
#   Physics Loss: 9.92e-04
#   β mean: 0.0142 [min: 0.0117, max: 0.0197]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 15000:
#   Total Loss: 3.60e-01
#   Data Loss: 3.58e-01
#   Physics Loss: 1.99e-03
#   β mean: 0.0146 [min: 0.0118, max: 0.0207]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 16000:
#   Total Loss: 3.60e-01
#   Data Loss: 3.56e-01
#   Physics Loss: 3.59e-03
#   β mean: 0.0148 [min: 0.0118, max: 0.0216]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 17000:
#   Total Loss: 3.55e-01
#   Data Loss: 3.53e-01
#   Physics Loss: 1.71e-03
#   β mean: 0.0152 [min: 0.0119, max: 0.0226]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 18000:
#   Total Loss: 3.53e-01
#   Data Loss: 3.50e-01
#   Physics Loss: 2.09e-03
#   β mean: 0.0156 [min: 0.0119, max: 0.0241]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 19000:
#   Total Loss: 3.57e-01
#   Data Loss: 3.48e-01
#   Physics Loss: 9.12e-03
#   β mean: 0.0160 [min: 0.0119, max: 0.0254]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# ✅ Завершено: train_size=150
#    Модель 1 - I_RMSE: 26116.67, R₀=1.084
#    Модель 2 - I_RMSE: 45969.91, R₀_mean=0.527
#
# ============================================================
# ТЕСТИРОВАНИЕ: train_size = 180
# ============================================================
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 131859344.000000 | Data: 5114499072.000000 | ODE: 80714352.000000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 10630023.000000 | Data: 960295040.000000 | ODE: 1027072.687500
# Params: β=0.2916, γ=0.1126, μ=0.0108
# ---
# Epoch  2000 | Loss: 7556583.500000 | Data: 647603648.000000 | ODE: 1080546.875000
# Params: β=0.2602, γ=0.1419, μ=0.0137
# ---
# Epoch  3000 | Loss: 5888405.500000 | Data: 486137504.000000 | ODE: 1027030.312500
# Params: β=0.2247, γ=0.1558, μ=0.0170
# ---
# Epoch  4000 | Loss: 4816656.500000 | Data: 373191808.000000 | ODE: 1084738.625000
# Params: β=0.1939, γ=0.1403, μ=0.0196
# ---
# Epoch  5000 | Loss: 3777655.500000 | Data: 266322176.000000 | ODE: 1114433.750000
# Params: β=0.1649, γ=0.1190, μ=0.0212
# ---
# Epoch  6000 | Loss: 2731836.000000 | Data: 162873792.000000 | ODE: 1103098.250000
# Params: β=0.1396, γ=0.1004, μ=0.0197
# ---
# Epoch  7000 | Loss: 2227054.250000 | Data: 135436368.000000 | ODE: 872690.562500
# Params: β=0.1196, γ=0.0859, μ=0.0171
# ---
# Epoch  8000 | Loss: 1492950.500000 | Data: 74464000.000000 | ODE: 748310.562500
# Params: β=0.1026, γ=0.0742, μ=0.0146
# ---
# Epoch  9000 | Loss: 1164696.250000 | Data: 50992124.000000 | ODE: 654775.062500
# Params: β=0.0886, γ=0.0650, μ=0.0123
# ---
# Epoch 10000 | Loss: 752159.625000 | Data: 24850694.000000 | ODE: 503652.656250
# Params: β=0.0775, γ=0.0576, μ=0.0104
# ---
# Epoch 11000 | Loss: 568052.000000 | Data: 14978649.000000 | ODE: 418265.500000
# Params: β=0.0687, γ=0.0518, μ=0.0088
# ---
# Epoch 12000 | Loss: 493769.156250 | Data: 13028310.000000 | ODE: 363486.062500
# Params: β=0.0618, γ=0.0475, μ=0.0075
# ---
# Epoch 13000 | Loss: 449576.375000 | Data: 10893269.000000 | ODE: 340643.687500
# Params: β=0.0568, γ=0.0443, μ=0.0065
# ---
# Epoch 14000 | Loss: 408439.437500 | Data: 7473048.000000 | ODE: 333708.968750
# Params: β=0.0535, γ=0.0423, μ=0.0058
# ---
# Epoch 15000 | Loss: 406479.500000 | Data: 7251738.500000 | ODE: 333962.125000
# Params: β=0.0515, γ=0.0411, μ=0.0053
# ---
# Epoch 16000 | Loss: 394530.250000 | Data: 6570045.500000 | ODE: 328829.781250
# Params: β=0.0509, γ=0.0408, μ=0.0051
# ---
# Epoch 17000 | Loss: 401697.437500 | Data: 7099949.500000 | ODE: 330697.937500
# Params: β=0.0508, γ=0.0408, μ=0.0050
# ---
# Epoch 18000 | Loss: 391676.875000 | Data: 6826017.000000 | ODE: 323416.687500
# Params: β=0.0506, γ=0.0407, μ=0.0049
# ---
# Epoch 19000 | Loss: 389568.281250 | Data: 6719524.500000 | ODE: 322373.031250
# Params: β=0.0507, γ=0.0408, μ=0.0049
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 4.53e+07
#   Data Loss: 1.16e+00
#   Physics Loss: 4.53e+07
#   β mean: 0.5096 [min: 0.4164, max: 0.6029]
#   γ mean: 0.2798 [min: 0.2518, max: 0.3079]
#   μ mean: 0.0501 [min: 0.0438, max: 0.0565]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 3.92e+02
#   Data Loss: 1.12e+00
#   Physics Loss: 3.91e+02
#   β mean: 0.4719 [min: 0.4567, max: 0.4898]
#   γ mean: 0.2839 [min: 0.2783, max: 0.2892]
#   μ mean: 0.0572 [min: 0.0435, max: 0.0697]
#
# Эпоха  2000:
#   Total Loss: 7.19e+02
#   Data Loss: 1.08e+00
#   Physics Loss: 7.18e+02
#   β mean: 0.3351 [min: 0.3323, max: 0.3432]
#   γ mean: 0.2656 [min: 0.2626, max: 0.2694]
#   μ mean: 0.0575 [min: 0.0530, max: 0.0614]
#
# Эпоха  3000:
#   Total Loss: 1.15e+01
#   Data Loss: 1.03e+00
#   Physics Loss: 1.04e+01
#   β mean: 0.0452 [min: 0.0431, max: 0.0511]
#   γ mean: 0.0450 [min: 0.0437, max: 0.0482]
#   μ mean: 0.0112 [min: 0.0078, max: 0.0167]
#
# Эпоха  4000:
#   Total Loss: 8.73e+00
#   Data Loss: 8.90e-01
#   Physics Loss: 7.84e+00
#   β mean: 0.0165 [min: 0.0128, max: 0.0249]
#   γ mean: 0.0306 [min: 0.0304, max: 0.0313]
#   μ mean: 0.0005 [min: 0.0002, max: 0.0012]
#
# Эпоха  5000:
#   Total Loss: 4.99e+00
#   Data Loss: 8.35e-01
#   Physics Loss: 4.15e+00
#   β mean: 0.0191 [min: 0.0111, max: 0.0483]
#   γ mean: 0.0304 [min: 0.0302, max: 0.0309]
#   μ mean: 0.0004 [min: 0.0002, max: 0.0011]
#
# Эпоха  6000:
#   Total Loss: 1.18e+00
#   Data Loss: 7.77e-01
#   Physics Loss: 4.04e-01
#   β mean: 0.0140 [min: 0.0112, max: 0.0216]
#   γ mean: 0.0303 [min: 0.0302, max: 0.0307]
#   μ mean: 0.0003 [min: 0.0001, max: 0.0009]
#
# Эпоха  7000:
#   Total Loss: 7.84e-01
#   Data Loss: 7.38e-01
#   Physics Loss: 4.63e-02
#   β mean: 0.0134 [min: 0.0113, max: 0.0185]
#   γ mean: 0.0303 [min: 0.0302, max: 0.0305]
#   μ mean: 0.0003 [min: 0.0001, max: 0.0007]
#
# Эпоха  8000:
#   Total Loss: 7.59e-01
#   Data Loss: 7.17e-01
#   Physics Loss: 4.22e-02
#   β mean: 0.0131 [min: 0.0113, max: 0.0172]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0305]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0005]
#
# Эпоха  9000:
#   Total Loss: 7.91e-01
#   Data Loss: 7.02e-01
#   Physics Loss: 8.89e-02
#   β mean: 0.0132 [min: 0.0114, max: 0.0174]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0005]
#
# Эпоха 10000:
#   Total Loss: 8.45e-01
#   Data Loss: 6.97e-01
#   Physics Loss: 1.48e-01
#   β mean: 0.0130 [min: 0.0113, max: 0.0168]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0005]
#
# Эпоха 11000:
#   Total Loss: 7.23e-01
#   Data Loss: 6.92e-01
#   Physics Loss: 3.15e-02
#   β mean: 0.0128 [min: 0.0113, max: 0.0164]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 12000:
#   Total Loss: 7.04e-01
#   Data Loss: 6.87e-01
#   Physics Loss: 1.77e-02
#   β mean: 0.0127 [min: 0.0113, max: 0.0159]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 13000:
#   Total Loss: 6.87e-01
#   Data Loss: 6.83e-01
#   Physics Loss: 4.05e-03
#   β mean: 0.0126 [min: 0.0113, max: 0.0154]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 14000:
#   Total Loss: 6.79e-01
#   Data Loss: 6.78e-01
#   Physics Loss: 1.15e-03
#   β mean: 0.0124 [min: 0.0113, max: 0.0149]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 15000:
#   Total Loss: 6.74e-01
#   Data Loss: 6.73e-01
#   Physics Loss: 1.02e-03
#   β mean: 0.0123 [min: 0.0113, max: 0.0142]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0304]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 16000:
#   Total Loss: 6.72e-01
#   Data Loss: 6.69e-01
#   Physics Loss: 2.44e-03
#   β mean: 0.0122 [min: 0.0114, max: 0.0138]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 17000:
#   Total Loss: 6.66e-01
#   Data Loss: 6.66e-01
#   Physics Loss: 9.58e-04
#   β mean: 0.0121 [min: 0.0114, max: 0.0134]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 18000:
#   Total Loss: 6.62e-01
#   Data Loss: 6.62e-01
#   Physics Loss: 7.93e-04
#   β mean: 0.0119 [min: 0.0115, max: 0.0129]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха 19000:
#   Total Loss: 6.61e-01
#   Data Loss: 6.58e-01
#   Physics Loss: 2.60e-03
#   β mean: 0.0118 [min: 0.0115, max: 0.0126]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# ✅ Завершено: train_size=180
#    Модель 1 - I_RMSE: 10077.17, R₀=1.109
#    Модель 2 - I_RMSE: 45969.68, R₀_mean=0.387
#
# ============================================================
# ТЕСТИРОВАНИЕ: train_size = 200
# ============================================================
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 202546592.000000 | Data: 10657443840.000000 | ODE: 95972160.000000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 17230708.000000 | Data: 1549767424.000000 | ODE: 1733034.000000
# Params: β=0.2846, γ=0.1186, μ=0.0113
# ---
# Epoch  2000 | Loss: 13025786.000000 | Data: 1131600768.000000 | ODE: 1709778.750000
# Params: β=0.2443, γ=0.1453, μ=0.0146
# ---
# Epoch  3000 | Loss: 10785285.000000 | Data: 899098240.000000 | ODE: 1794303.125000
# Params: β=0.2101, γ=0.1475, μ=0.0176
# ---
# Epoch  4000 | Loss: 9020987.000000 | Data: 707518272.000000 | ODE: 1945804.375000
# Params: β=0.1793, γ=0.1266, μ=0.0200
# ---
# Epoch  5000 | Loss: 7224567.000000 | Data: 523726688.000000 | ODE: 1987300.250000
# Params: β=0.1512, γ=0.1054, μ=0.0206
# ---
# Epoch  6000 | Loss: 5537927.500000 | Data: 369175616.000000 | ODE: 1846171.500000
# Params: β=0.1274, γ=0.0887, μ=0.0181
# ---
# Epoch  7000 | Loss: 4080898.500000 | Data: 251443104.000000 | ODE: 1566467.500000
# Params: β=0.1078, γ=0.0757, μ=0.0151
# ---
# Epoch  8000 | Loss: 2939850.500000 | Data: 170155152.000000 | ODE: 1238298.875000
# Params: β=0.0921, γ=0.0654, μ=0.0125
# ---
# Epoch  9000 | Loss: 2111660.500000 | Data: 120191768.000000 | ODE: 909742.875000
# Params: β=0.0794, γ=0.0573, μ=0.0104
# ---
# Epoch 10000 | Loss: 1702275.125000 | Data: 101487336.000000 | ODE: 687401.812500
# Params: β=0.0693, γ=0.0508, μ=0.0087
# ---
# Epoch 11000 | Loss: 975483.875000 | Data: 41722168.000000 | ODE: 558262.187500
# Params: β=0.0613, γ=0.0457, μ=0.0074
# ---
# Epoch 12000 | Loss: 745523.250000 | Data: 27103136.000000 | ODE: 474491.937500
# Params: β=0.0550, γ=0.0417, μ=0.0063
# ---
# Epoch 13000 | Loss: 627319.812500 | Data: 19849100.000000 | ODE: 428828.812500
# Params: β=0.0501, γ=0.0387, μ=0.0053
# ---
# Epoch 14000 | Loss: 559473.250000 | Data: 15325608.000000 | ODE: 406217.187500
# Params: β=0.0466, γ=0.0365, μ=0.0046
# ---
# Epoch 15000 | Loss: 523960.750000 | Data: 12523089.000000 | ODE: 398729.843750
# Params: β=0.0445, γ=0.0353, μ=0.0040
# ---
# Epoch 16000 | Loss: 538077.687500 | Data: 13681358.000000 | ODE: 401264.125000
# Params: β=0.0434, γ=0.0347, μ=0.0036
# ---
# Epoch 17000 | Loss: 477994.968750 | Data: 9840907.000000 | ODE: 379585.906250
# Params: β=0.0430, γ=0.0344, μ=0.0033
# ---
# Epoch 18000 | Loss: 461160.312500 | Data: 9393461.000000 | ODE: 367225.718750
# Params: β=0.0428, γ=0.0343, μ=0.0032
# ---
# Epoch 19000 | Loss: 492289.250000 | Data: 13578867.000000 | ODE: 356500.593750
# Params: β=0.0427, γ=0.0341, μ=0.0031
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 4.58e+07
#   Data Loss: 1.26e+00
#   Physics Loss: 4.58e+07
#   β mean: 0.5096 [min: 0.4817, max: 0.5375]
#   γ mean: 0.2798 [min: 0.2261, max: 0.3335]
#   μ mean: 0.0501 [min: 0.0412, max: 0.0591]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 2.37e+02
#   Data Loss: 1.16e+00
#   Physics Loss: 2.36e+02
#   β mean: 0.3909 [min: 0.3891, max: 0.3942]
#   γ mean: 0.2388 [min: 0.2358, max: 0.2435]
#   μ mean: 0.0580 [min: 0.0577, max: 0.0582]
#
# Эпоха  2000:
#   Total Loss: 1.16e+01
#   Data Loss: 1.08e+00
#   Physics Loss: 1.06e+01
#   β mean: 0.0332 [min: 0.0215, max: 0.0547]
#   γ mean: 0.0335 [min: 0.0317, max: 0.0370]
#   μ mean: 0.0108 [min: 0.0019, max: 0.0326]
#
# Эпоха  3000:
#   Total Loss: 5.83e+00
#   Data Loss: 9.69e-01
#   Physics Loss: 4.86e+00
#   β mean: 0.0166 [min: 0.0163, max: 0.0176]
#   γ mean: 0.0302 [min: 0.0301, max: 0.0303]
#   μ mean: 0.0003 [min: 0.0002, max: 0.0007]
#
# Эпоха  4000:
#   Total Loss: 2.66e+00
#   Data Loss: 8.63e-01
#   Physics Loss: 1.80e+00
#   β mean: 0.0159 [min: 0.0157, max: 0.0166]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0302]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0004]
#
# Эпоха  5000:
#   Total Loss: 2.70e+00
#   Data Loss: 8.14e-01
#   Physics Loss: 1.89e+00
#   β mean: 0.0151 [min: 0.0148, max: 0.0161]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0003]
#
# Эпоха  6000:
#   Total Loss: 1.09e+00
#   Data Loss: 7.81e-01
#   Physics Loss: 3.11e-01
#   β mean: 0.0152 [min: 0.0145, max: 0.0167]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0003]
#
# Эпоха  7000:
#   Total Loss: 9.95e-01
#   Data Loss: 7.55e-01
#   Physics Loss: 2.40e-01
#   β mean: 0.0150 [min: 0.0144, max: 0.0165]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0003]
#
# Эпоха  8000:
#   Total Loss: 8.93e-01
#   Data Loss: 7.38e-01
#   Physics Loss: 1.55e-01
#   β mean: 0.0153 [min: 0.0146, max: 0.0169]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха  9000:
#   Total Loss: 8.46e-01
#   Data Loss: 7.28e-01
#   Physics Loss: 1.19e-01
#   β mean: 0.0152 [min: 0.0146, max: 0.0167]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 10000:
#   Total Loss: 7.33e-01
#   Data Loss: 7.20e-01
#   Physics Loss: 1.31e-02
#   β mean: 0.0154 [min: 0.0149, max: 0.0168]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 11000:
#   Total Loss: 7.20e-01
#   Data Loss: 7.14e-01
#   Physics Loss: 6.27e-03
#   β mean: 0.0158 [min: 0.0155, max: 0.0166]
#   γ mean: 0.0301 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 12000:
#   Total Loss: 7.14e-01
#   Data Loss: 7.10e-01
#   Physics Loss: 4.19e-03
#   β mean: 0.0159 [min: 0.0157, max: 0.0163]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 13000:
#   Total Loss: 7.10e-01
#   Data Loss: 7.07e-01
#   Physics Loss: 2.77e-03
#   β mean: 0.0166 [min: 0.0162, max: 0.0178]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 14000:
#   Total Loss: 7.06e-01
#   Data Loss: 7.05e-01
#   Physics Loss: 1.79e-03
#   β mean: 0.0174 [min: 0.0162, max: 0.0199]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 15000:
#   Total Loss: 7.07e-01
#   Data Loss: 7.02e-01
#   Physics Loss: 4.82e-03
#   β mean: 0.0181 [min: 0.0160, max: 0.0217]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 16000:
#   Total Loss: 7.02e-01
#   Data Loss: 7.00e-01
#   Physics Loss: 2.52e-03
#   β mean: 0.0186 [min: 0.0160, max: 0.0233]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 17000:
#   Total Loss: 6.98e-01
#   Data Loss: 6.97e-01
#   Physics Loss: 9.62e-04
#   β mean: 0.0190 [min: 0.0159, max: 0.0246]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 18000:
#   Total Loss: 6.95e-01
#   Data Loss: 6.94e-01
#   Physics Loss: 7.71e-04
#   β mean: 0.0194 [min: 0.0158, max: 0.0258]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 19000:
#   Total Loss: 7.02e-01
#   Data Loss: 6.93e-01
#   Physics Loss: 9.68e-03
#   β mean: 0.0194 [min: 0.0157, max: 0.0262]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# ✅ Завершено: train_size=200
#    Модель 1 - I_RMSE: 30387.85, R₀=1.152
#    Модель 2 - I_RMSE: 45971.83, R₀_mean=0.646
#
# ============================================================
# ТЕСТИРОВАНИЕ: train_size = 220
# ============================================================
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 351643552.000000 | Data: 16766280704.000000 | ODE: 183980752.000000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 21354704.000000 | Data: 1882788608.000000 | ODE: 2526818.250000
# Params: β=0.2884, γ=0.1163, μ=0.0110
# ---
# Epoch  2000 | Loss: 18192486.000000 | Data: 1581425664.000000 | ODE: 2378229.750000
# Params: β=0.2557, γ=0.1417, μ=0.0137
# ---
# Epoch  3000 | Loss: 15712248.000000 | Data: 1337119872.000000 | ODE: 2341050.000000
# Params: β=0.2220, γ=0.1521, μ=0.0165
# ---
# Epoch  4000 | Loss: 13796136.000000 | Data: 1128836352.000000 | ODE: 2507772.500000
# Params: β=0.1917, γ=0.1368, μ=0.0188
# ---
# Epoch  5000 | Loss: 11445659.000000 | Data: 887508608.000000 | ODE: 2570572.750000
# Params: β=0.1623, γ=0.1146, μ=0.0204
# ---
# Epoch  6000 | Loss: 8754040.000000 | Data: 598936832.000000 | ODE: 2764671.750000
# Params: β=0.1363, γ=0.0954, μ=0.0192
# ---
# Epoch  7000 | Loss: 6555349.000000 | Data: 396539040.000000 | ODE: 2589958.750000
# Params: β=0.1146, γ=0.0804, μ=0.0162
# ---
# Epoch  8000 | Loss: 4730848.000000 | Data: 253255168.000000 | ODE: 2198296.750000
# Params: β=0.0970, γ=0.0685, μ=0.0134
# ---
# Epoch  9000 | Loss: 3194750.500000 | Data: 147876320.000000 | ODE: 1715987.500000
# Params: β=0.0828, γ=0.0592, μ=0.0111
# ---
# Epoch 10000 | Loss: 2254755.750000 | Data: 100658744.000000 | ODE: 1248168.250000
# Params: β=0.0715, γ=0.0516, μ=0.0092
# ---
# Epoch 11000 | Loss: 1538825.750000 | Data: 62734604.000000 | ODE: 911479.687500
# Params: β=0.0625, γ=0.0460, μ=0.0076
# ---
# Epoch 12000 | Loss: 1125450.750000 | Data: 45423136.000000 | ODE: 671219.375000
# Params: β=0.0553, γ=0.0415, μ=0.0064
# ---
# Epoch 13000 | Loss: 881281.937500 | Data: 33249096.000000 | ODE: 548791.000000
# Params: β=0.0498, γ=0.0380, μ=0.0054
# ---
# Epoch 14000 | Loss: 1615491.500000 | Data: 115203568.000000 | ODE: 463455.937500
# Params: β=0.0456, γ=0.0354, μ=0.0045
# ---
# Epoch 15000 | Loss: 720901.000000 | Data: 28915128.000000 | ODE: 431749.718750
# Params: β=0.0426, γ=0.0336, μ=0.0039
# ---
# Epoch 16000 | Loss: 668002.187500 | Data: 22835218.000000 | ODE: 439650.031250
# Params: β=0.0409, γ=0.0327, μ=0.0034
# ---
# Epoch 17000 | Loss: 742888.375000 | Data: 30425680.000000 | ODE: 438631.593750
# Params: β=0.0400, γ=0.0323, μ=0.0030
# ---
# Epoch 18000 | Loss: 633861.687500 | Data: 20577648.000000 | ODE: 428085.218750
# Params: β=0.0395, γ=0.0321, μ=0.0027
# ---
# Epoch 19000 | Loss: 618366.312500 | Data: 18891032.000000 | ODE: 429456.000000
# Params: β=0.0393, γ=0.0320, μ=0.0025
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 2.48e+07
#   Data Loss: 1.31e+00
#   Physics Loss: 2.48e+07
#   β mean: 0.5096 [min: 0.4867, max: 0.5325]
#   γ mean: 0.2798 [min: 0.2603, max: 0.2993]
#   μ mean: 0.0501 [min: 0.0493, max: 0.0510]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 9.17e+02
#   Data Loss: 1.19e+00
#   Physics Loss: 9.15e+02
#   β mean: 0.3888 [min: 0.3868, max: 0.3934]
#   γ mean: 0.2942 [min: 0.2903, max: 0.2970]
#   μ mean: 0.0589 [min: 0.0554, max: 0.0620]
#
# Эпоха  2000:
#   Total Loss: 3.88e+02
#   Data Loss: 1.14e+00
#   Physics Loss: 3.87e+02
#   β mean: 0.1944 [min: 0.1907, max: 0.2043]
#   γ mean: 0.2456 [min: 0.2406, max: 0.2524]
#   μ mean: 0.0492 [min: 0.0489, max: 0.0496]
#
# Эпоха  3000:
#   Total Loss: 9.80e+00
#   Data Loss: 1.08e+00
#   Physics Loss: 8.72e+00
#   β mean: 0.0246 [min: 0.0239, max: 0.0266]
#   γ mean: 0.0345 [min: 0.0339, max: 0.0360]
#   μ mean: 0.0028 [min: 0.0021, max: 0.0040]
#
# Эпоха  4000:
#   Total Loss: 2.34e+01
#   Data Loss: 9.76e-01
#   Physics Loss: 2.24e+01
#   β mean: 0.0159 [min: 0.0142, max: 0.0191]
#   γ mean: 0.0309 [min: 0.0308, max: 0.0311]
#   μ mean: 0.0005 [min: 0.0005, max: 0.0006]
#
# Эпоха  5000:
#   Total Loss: 5.00e+00
#   Data Loss: 8.98e-01
#   Physics Loss: 4.10e+00
#   β mean: 0.0146 [min: 0.0113, max: 0.0227]
#   γ mean: 0.0302 [min: 0.0302, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0002]
#
# Эпоха  6000:
#   Total Loss: 2.69e+00
#   Data Loss: 8.23e-01
#   Physics Loss: 1.87e+00
#   β mean: 0.0137 [min: 0.0115, max: 0.0182]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0302]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0002]
#
# Эпоха  7000:
#   Total Loss: 1.22e+00
#   Data Loss: 7.89e-01
#   Physics Loss: 4.35e-01
#   β mean: 0.0161 [min: 0.0123, max: 0.0245]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0302]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0002]
#
# Эпоха  8000:
#   Total Loss: 1.26e+00
#   Data Loss: 7.77e-01
#   Physics Loss: 4.81e-01
#   β mean: 0.0154 [min: 0.0121, max: 0.0227]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0002]
#
# Эпоха  9000:
#   Total Loss: 8.15e-01
#   Data Loss: 7.67e-01
#   Physics Loss: 4.81e-02
#   β mean: 0.0154 [min: 0.0121, max: 0.0223]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0002]
#
# Эпоха 10000:
#   Total Loss: 7.72e-01
#   Data Loss: 7.59e-01
#   Physics Loss: 1.27e-02
#   β mean: 0.0152 [min: 0.0123, max: 0.0213]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 11000:
#   Total Loss: 7.63e-01
#   Data Loss: 7.55e-01
#   Physics Loss: 7.73e-03
#   β mean: 0.0157 [min: 0.0126, max: 0.0221]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 12000:
#   Total Loss: 7.56e-01
#   Data Loss: 7.51e-01
#   Physics Loss: 5.16e-03
#   β mean: 0.0160 [min: 0.0129, max: 0.0222]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 13000:
#   Total Loss: 7.61e-01
#   Data Loss: 7.47e-01
#   Physics Loss: 1.40e-02
#   β mean: 0.0164 [min: 0.0134, max: 0.0219]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха 14000:
#   Total Loss: 7.53e-01
#   Data Loss: 7.44e-01
#   Physics Loss: 8.92e-03
#   β mean: 0.0167 [min: 0.0143, max: 0.0212]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 15000:
#   Total Loss: 7.45e-01
#   Data Loss: 7.40e-01
#   Physics Loss: 4.57e-03
#   β mean: 0.0174 [min: 0.0157, max: 0.0207]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 16000:
#   Total Loss: 7.41e-01
#   Data Loss: 7.37e-01
#   Physics Loss: 3.74e-03
#   β mean: 0.0183 [min: 0.0173, max: 0.0206]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 17000:
#   Total Loss: 7.38e-01
#   Data Loss: 7.35e-01
#   Physics Loss: 2.63e-03
#   β mean: 0.0190 [min: 0.0185, max: 0.0204]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 18000:
#   Total Loss: 7.37e-01
#   Data Loss: 7.33e-01
#   Physics Loss: 3.19e-03
#   β mean: 0.0195 [min: 0.0192, max: 0.0203]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# Эпоха 19000:
#   Total Loss: 7.34e-01
#   Data Loss: 7.31e-01
#   Physics Loss: 3.01e-03
#   β mean: 0.0198 [min: 0.0195, max: 0.0208]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0002]
#
# ✅ Завершено: train_size=220
#    Модель 1 - I_RMSE: 30052.26, R₀=1.141
#    Модель 2 - I_RMSE: 45971.93, R₀_mean=0.673
#
# ================================================================================
# ТЕСТИРОВАНИЕ НА РЕАЛЬНЫХ ДАННЫХ ЗАВЕРШЕНО
# ================================================================================
# Результаты сохранены в: c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\real_datasets_results
# ================================================================================
# ГОТОВО! Все результаты сохранены.
# ================================================================================
