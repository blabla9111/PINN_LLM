# %%
import sys
sys.path.append("../")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
from pathlib import Path
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import json
from datetime import datetime

# ============================================================
# НАСТРОЙКА
# ============================================================

# Определяем девайс
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Фиксируем seed для воспроизводимости
torch.manual_seed(123)
if device.type == 'cuda':
    torch.cuda.manual_seed(123)
np.random.seed(123)
torch.backends.cudnn.deterministic = True

# Создаем папку для результатов
results_dir = Path("synthetic_datasets_results_pop_105")
results_dir.mkdir(exist_ok=True)

# Создаем подпапки для каждой модели
model1_dir = results_dir / "model1_constant"
model2_dir = results_dir / "model2_temporal"
model1_dir.mkdir(exist_ok=True)
model2_dir.mkdir(exist_ok=True)

# ============================================================
# СПИСОК ДАТАСЕТОВ ДЛЯ ТЕСТИРОВАНИЯ
# ============================================================

datasets = [
    # Основные датасеты
    {"name": "01_baseline_constant", "desc": "Базовый (константы)", "has_noise": False},
    # {"name": "02_lockdown_beta_jump", "desc": "Локдаун (скачок β)", "has_noise": False},
    # {"name": "03_seasonal_beta_sin", "desc": "Сезонность (плавная β)", "has_noise": False},
    # {"name": "04_decaying_beta_trend", "desc": "Затухание (β 0.15→0.1)", "has_noise": False},
    # {"name": "05_complex_beta_gamma_dynamics", "desc": "Сложный (β+γ)", "has_noise": False},
    
    # Шумные версии датасета 2
    # {"name": "02_lockdown_beta_jump_noise_3pct_seed42", "desc": "Локдаун + шум 3%", "has_noise": True},
    # {"name": "02_lockdown_beta_jump_noise_5pct_seed123", "desc": "Локдаун + шум 5%", "has_noise": True},
    # {"name": "02_lockdown_beta_jump_noise_10pct_seed456", "desc": "Локдаун + шум 10%", "has_noise": True},
    
    # Шумные версии датасета 5
    # {"name": "05_complex_beta_gamma_dynamics_noise_3pct_seed42", "desc": "Сложный + шум 3%", "has_noise": True},
    # {"name": "05_complex_beta_gamma_dynamics_noise_5pct_seed123", "desc": "Сложный + шум 5%", "has_noise": True},
    # {"name": "05_complex_beta_gamma_dynamics_noise_10pct_seed456", "desc": "Сложный + шум 10%", "has_noise": True},
]

# Истинные параметры для каждого датасета (для расчета ошибок)
true_params = {
    "01_baseline_constant": {"beta": 0.1, "gamma": 0.06, "mu": 0.003, "type": "constant"},
    "02_lockdown_beta_jump": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "03_seasonal_beta_sin": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "04_decaying_beta_trend": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "05_complex_beta_gamma_dynamics": {"beta": "time_varying", "gamma": "time_varying", "mu": 0.003, "type": "both_time"},
}

# Для шумных версий параметры те же, что у исходных
for noise_level in [3, 5, 10]:
    for seed in [42, 123, 456]:
        true_params[f"02_lockdown_beta_jump_noise_{noise_level}pct_seed{seed}"] = true_params["02_lockdown_beta_jump"]
        true_params[f"05_complex_beta_gamma_dynamics_noise_{noise_level}pct_seed{seed}"] = true_params["05_complex_beta_gamma_dynamics"]

# ============================================================
# ФУНКЦИИ ДЛЯ РАСЧЕТА МЕТРИК
# ============================================================

def calculate_metrics(y_true, y_pred):
    """Рассчитывает MSE, RMSE, MAE для временных рядов"""
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae}

def calculate_parameter_error_model1(pred_params, true_params_dict):
    """Относительная ошибка для константных параметров (модель 1)"""
    errors = {}
    for param in ['beta', 'gamma', 'mu']:
        if isinstance(true_params_dict[param], (int, float)):
            true_val = true_params_dict[param]
            pred_val = pred_params[param]
            rel_error = abs(pred_val - true_val) / true_val
            errors[param] = {
                "true": true_val,
                "pred": pred_val,
                "abs_error": abs(pred_val - true_val),
                "rel_error": rel_error,
                "rel_error_percent": rel_error * 100
            }
    return errors

def calculate_parameter_error_model2(df_true, df_pred, param_name):
    """Ошибки для временных параметров (модель 2)"""
    true_vals = df_true[param_name].values
    pred_vals = df_pred[param_name].values
    
    # Обрезаем до одинаковой длины
    min_len = min(len(true_vals), len(pred_vals))
    true_vals = true_vals[:min_len]
    pred_vals = pred_vals[:min_len]
    
    mse = mean_squared_error(true_vals, pred_vals)
    rmse = np.sqrt(mse)
    r2 = r2_score(true_vals, pred_vals)
    
    return {
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2,
        "mean_true": np.mean(true_vals),
        "mean_pred": np.mean(pred_vals)
    }

# ============================================================
# ФУНКЦИИ ДЛЯ ВИЗУАЛИЗАЦИИ
# ============================================================

def plot_model_results(df_true, df_pred_model1, df_pred_model2, dataset_name, save_dir):
    """Создает визуализацию сравнения моделей"""
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    fig.suptitle(f'Сравнение моделей: {dataset_name}', fontsize=16, fontweight='bold')
    
    t = df_true['day'].values
    
    # 1. Инфицированные I(t)
    ax = axes[0, 0]
    ax.plot(t, df_true['I'], 'k-', linewidth=2.5, label='Истинные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['I'])], df_pred_model1['I'], 'r--', linewidth=2, label='Модель 1 (конст)')
    ax.plot(t[:len(df_pred_model2['I'])], df_pred_model2['I'], 'b--', linewidth=2, label='Модель 2 (врем)')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Инфицированные')
    ax.set_title('Динамика I(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 2. Умершие D(t)
    ax = axes[0, 1]
    ax.plot(t, df_true['D'], 'k-', linewidth=2.5, label='Истинные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['D'])], df_pred_model1['D'], 'r--', linewidth=2, label='Модель 1')
    ax.plot(t[:len(df_pred_model2['D'])], df_pred_model2['D'], 'b--', linewidth=2, label='Модель 2')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Умершие')
    ax.set_title('Динамика D(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 3. R₀ (если есть в данных)
    ax = axes[0, 2]
    if 'R0' in df_true.columns:
        ax.plot(t, df_true['R0'], 'k-', linewidth=2.5, label='Истинный R₀', alpha=0.8)
    if 'R0' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['R0'])], df_pred_model2['R0'], 'b--', linewidth=2, label='Модель 2 R₀')
    ax.axhline(y=1.0, color='gray', linestyle='--', alpha=0.5)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('R₀')
    ax.set_title('Репродуктивное число')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 4. Параметр β(t)
    ax = axes[1, 0]
    if 'beta' in df_true.columns:
        ax.plot(t, df_true['beta'], 'k-', linewidth=2.5, label='Истинный β(t)', alpha=0.8)
    if 'beta' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['beta'])], df_pred_model2['beta'], 'b--', linewidth=2, label='Модель 2 β(t)')
    # Для модели 1 - константа
    if 'beta_const' in df_pred_model1.columns:
        beta_const = df_pred_model1['beta_const'].iloc[0]
        ax.axhline(y=beta_const, color='r', linestyle='--', linewidth=2, label=f'Модель 1 β={beta_const:.4f}')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('β')
    ax.set_title('Параметр β(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 5. Параметры γ(t) и μ(t)
    ax = axes[1, 1]
    if 'gamma' in df_true.columns:
        ax.plot(t, df_true['gamma'], 'g-', linewidth=2, label='Истинный γ(t)', alpha=0.6)
    if 'mu' in df_true.columns:
        ax.plot(t, df_true['mu'], 'brown', linewidth=2, label='Истинный μ(t)', alpha=0.6)
    if 'gamma' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['gamma'])], df_pred_model2['gamma'], 'g--', linewidth=2, label='Модель 2 γ(t)')
    if 'mu' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['mu'])], df_pred_model2['mu'], 'orange', linewidth=2, label='Модель 2 μ(t)')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Параметры')
    ax.set_title('Параметры γ(t) и μ(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 6. Ошибки предсказания I(t)
    ax = axes[1, 2]
    min_len = min(len(t), len(df_pred_model1['I']), len(df_pred_model2['I']))
    error1 = np.abs(df_true['I'].values[:min_len] - df_pred_model1['I'][:min_len])
    error2 = np.abs(df_true['I'].values[:min_len] - df_pred_model2['I'][:min_len])
    
    ax.plot(t[:min_len], error1, 'r-', linewidth=1.5, label='Ошибка Модель 1')
    ax.plot(t[:min_len], error2, 'b-', linewidth=1.5, label='Ошибка Модель 2')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('|Ошибка| I(t)')
    ax.set_title('Абсолютная ошибка для I(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(save_dir / f"{dataset_name}_comparison.png", dpi=150, bbox_inches='tight')
    plt.close()

# ============================================================
# ОСНОВНОЙ ЦИКЛ ТЕСТИРОВАНИЯ
# ============================================================

def run_testing():
    """Запускает тестирование на всех датасетах"""
    
    # Словари для накопления результатов
    results_model1 = []
    results_model2 = []
    
    print("="*80)
    print("НАЧАЛО ТЕСТИРОВАНИЯ МОДЕЛЕЙ")
    print("="*80)
    
    for ds in datasets:
        dataset_name = ds["name"]
        dataset_desc = ds["desc"]
        
        print(f"\n{'='*60}")
        print(f"ТЕСТИРОВАНИЕ: {dataset_name}")
        print(f"Описание: {dataset_desc}")
        print('='*60)
        
        try:
            # ==================================================
            # ЗАГРУЗКА ДАННЫХ
            # ==================================================
            file_path = f"./synthetic_datasets_pop_105/{dataset_name}.csv"
            if not os.path.exists(file_path):
                print(f"❌ Файл не найден: {file_path}")
                continue
                
            df_true = pd.read_csv(file_path)
            
            # Получаем данные
            S = df_true['S'].values
            I = df_true['I'].values
            D = df_true['D'].values
            R = df_true['R'].values
            timesteps = np.arange(len(S)).astype(float)
            
            # Параметры
            # train_size = min(101, len(timesteps) // 2)  # Обучаем на половине данных
            train_size = 180
            population = 100000
            
            print(f"Всего точек: {len(timesteps)}, Обучающих: {train_size}, Тестовых: {len(timesteps)-train_size}")
            
            # ==================================================
            # МОДЕЛЬ 1: EINN_PINN (константные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 1 (константные параметры) ---")
            
            from NEW_PINN.PINN_const import EINN_PINN  # предполагаемый импорт
            
            model1 = EINN_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                R_data=R,
                D_data=D,
                population=population,
                train_size=train_size,
                device=device
            )
            
            # Обучаем
            model1.train_model(n_epoch=20000, lambda_data=0.01, lambda_ode=1.0)
            
            # Получаем параметры
            final_params = model1.params.get_params_dict()
            
            # Предсказание
            S_pred1, I_pred1, R_pred1, D_pred1 = model1.predict(timesteps)
            
            # Конвертируем в numpy
            S_pred1 = S_pred1.numpy()
            I_pred1 = I_pred1.numpy()
            R_pred1 = R_pred1.numpy()
            D_pred1 = D_pred1.numpy()
            
            # Создаем DataFrame с предсказаниями модели 1
            df_pred1 = pd.DataFrame({
                'day': timesteps[:len(S_pred1)],
                'S': S_pred1,
                'I': I_pred1,
                'R': R_pred1,
                'D': D_pred1,
                'beta_const': final_params['beta'],
                'gamma_const': final_params['gamma'],
                'mu_const': final_params['mu']
            })
            df_pred1['R0_const'] = df_pred1['beta_const'] / (df_pred1['gamma_const'] + df_pred1['mu_const'])
            
            # ==================================================
            # МОДЕЛЬ 2: Nature_PINN (временные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 2 (временные параметры) ---")
            
            from NEW_PINN.PINN_time import Nature_PINN  # предполагаемый импорт
            
            model2 = Nature_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                D_data=D,
                R_data=R,
                device=device,
                train_size=train_size,
                population_n=population
            )
            
            # Обучаем
            model2.train(n_epoch=20000)
            
            # Получаем предсказания
            predictions = model2.predict()
            
            # Создаем DataFrame с предсказаниями модели 2
            df_pred2 = pd.DataFrame({
                'day': predictions['t'][:len(predictions['S'])],
                'S': predictions['S'],
                'I': predictions['I'],
                'R': predictions['R'],
                'D': predictions['D'],
                'beta': predictions['beta'],
                'gamma': predictions['gamma'],
                'mu': predictions['mu']
            })
            df_pred2['R0'] = df_pred2['beta'] / (df_pred2['gamma'] + df_pred2['mu'])
            
            # ==================================================
            # РАСЧЕТ МЕТРИК
            # ==================================================
            
            # Обрезаем до одинаковой длины
            min_len = min(len(df_true), len(df_pred1), len(df_pred2))
            df_true_trim = df_true.iloc[:min_len]
            df_pred1_trim = df_pred1.iloc[:min_len]
            df_pred2_trim = df_pred2.iloc[:min_len]
            
            # Метрики для SIRD
            metrics_model1 = {}
            metrics_model2 = {}
            
            for compartment in ['S', 'I', 'R', 'D']:
                true_vals = df_true_trim[compartment].values
                pred1_vals = df_pred1_trim[compartment].values
                pred2_vals = df_pred2_trim[compartment].values
                
                metrics_model1[compartment] = calculate_metrics(true_vals, pred1_vals)
                metrics_model2[compartment] = calculate_metrics(true_vals, pred2_vals)
            
            # Ошибки параметров для модели 1
            param_errors_model1 = {}
            if dataset_name in true_params:
                if true_params[dataset_name]["type"] == "constant":
                    param_errors_model1 = calculate_parameter_error_model1(final_params, true_params[dataset_name])
            
            # Ошибки параметров для модели 2
            param_errors_model2 = {}
            if dataset_name in true_params:
                if 'beta' in df_true.columns and true_params[dataset_name]["beta"] == "time_varying":
                    param_errors_model2['beta'] = calculate_parameter_error_model2(df_true, df_pred2, 'beta')
                if 'gamma' in df_true.columns and true_params[dataset_name]["gamma"] == "time_varying":
                    param_errors_model2['gamma'] = calculate_parameter_error_model2(df_true, df_pred2, 'gamma')
                if 'mu' in df_true.columns and isinstance(true_params[dataset_name]["mu"], (int, float)):
                    param_errors_model2['mu'] = calculate_parameter_error_model2(df_true, df_pred2, 'mu')
            
            # ==================================================
            # СОХРАНЕНИЕ РЕЗУЛЬТАТОВ
            # ==================================================
            
            # Сохраняем предсказания
            df_pred1.to_csv(model1_dir / f"{dataset_name}_predictions.csv", index=False)
            df_pred2.to_csv(model2_dir / f"{dataset_name}_predictions.csv", index=False)
            
            # Сохраняем метрики
            result_entry_model1 = {
                'dataset': dataset_name,
                'description': dataset_desc,
                **{f"{comp}_MSE": metrics_model1[comp]['MSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_RMSE": metrics_model1[comp]['RMSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_MAE": metrics_model1[comp]['MAE'] for comp in ['S', 'I', 'R', 'D']},
                'beta_pred': final_params['beta'],
                'gamma_pred': final_params['gamma'],
                'mu_pred': final_params['mu'],
            }
            
            # Добавляем ошибки параметров если есть
            if param_errors_model1:
                for param, errors in param_errors_model1.items():
                    result_entry_model1[f"{param}_true"] = errors['true']
                    result_entry_model1[f"{param}_rel_error"] = errors['rel_error']
                    result_entry_model1[f"{param}_rel_error_percent"] = errors['rel_error_percent']
            
            results_model1.append(result_entry_model1)
            
            result_entry_model2 = {
                'dataset': dataset_name,
                'description': dataset_desc,
                **{f"{comp}_MSE": metrics_model2[comp]['MSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_RMSE": metrics_model2[comp]['RMSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_MAE": metrics_model2[comp]['MAE'] for comp in ['S', 'I', 'R', 'D']},
            }
            
            # Добавляем ошибки параметров
            for param, errors in param_errors_model2.items():
                result_entry_model2[f"{param}_RMSE"] = errors['RMSE']
                result_entry_model2[f"{param}_R2"] = errors['R2']
            
            results_model2.append(result_entry_model2)
            
            # ==================================================
            # ВИЗУАЛИЗАЦИЯ
            # ==================================================
            
            plot_model_results(df_true, df_pred1, df_pred2, dataset_name, results_dir)
            
            print(f"\n✅ Завершено: {dataset_name}")
            print(f"   Модель 1 - I_RMSE: {metrics_model1['I']['RMSE']:.4f}")
            print(f"   Модель 2 - I_RMSE: {metrics_model2['I']['RMSE']:.4f}")
            
        except Exception as e:
            print(f"❌ Ошибка при обработке {dataset_name}: {str(e)}")
            import traceback
            traceback.print_exc()
            continue
    
    # ==================================================
    # СОХРАНЕНИЕ СВОДНЫХ РЕЗУЛЬТАТОВ
    # ==================================================
    
    # Сохраняем результаты в CSV
    df_results_model1 = pd.DataFrame(results_model1)
    df_results_model2 = pd.DataFrame(results_model2)
    
    df_results_model1.to_csv(results_dir / "summary_model1.csv", index=False)
    df_results_model2.to_csv(results_dir / "summary_model2.csv", index=False)
    
    # Сохраняем в JSON для удобства
    with open(results_dir / "summary_model1.json", 'w') as f:
        json.dump(results_model1, f, indent=2, default=str)
    
    with open(results_dir / "summary_model2.json", 'w') as f:
        json.dump(results_model2, f, indent=2, default=str)
    
    print("\n" + "="*80)
    print("ТЕСТИРОВАНИЕ ЗАВЕРШЕНО")
    print("="*80)
    print(f"Результаты сохранены в: {results_dir.absolute()}")
    print(f"  - Модель 1: {len(results_model1)} датасетов")
    print(f"  - Модель 2: {len(results_model2)} датасетов")
    
    return df_results_model1, df_results_model2

# ============================================================
# ФУНКЦИЯ ДЛЯ ВИЗУАЛИЗАЦИИ СВОДНЫХ РЕЗУЛЬТАТОВ
# ============================================================

def plot_summary_results(df_results_model1, df_results_model2):
    """Создает сводные графики по всем результатам"""
    
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle('Сводные результаты тестирования моделей', fontsize=16, fontweight='bold')
    
    # 1. Сравнение RMSE для I(t)
    ax = axes[0, 0]
    datasets = df_results_model1['dataset'].values
    x = np.arange(len(datasets))
    width = 0.35
    
    ax.bar(x - width/2, df_results_model1['I_RMSE'], width, label='Модель 1', color='red', alpha=0.7)
    ax.bar(x + width/2, df_results_model2['I_RMSE'], width, label='Модель 2', color='blue', alpha=0.7)
    
    ax.set_xlabel('Датасет')
    ax.set_ylabel('RMSE для I(t)')
    ax.set_title('Сравнение точности предсказания I(t)')
    ax.set_xticks(x)
    ax.set_xticklabels([d[:15] + '...' if len(d) > 15 else d for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3, axis='y')
    
    # 2. Относительная ошибка параметров (для модели 1)
    ax = axes[0, 1]
    if 'beta_rel_error_percent' in df_results_model1.columns:
        for param, color in [('beta', 'orange'), ('gamma', 'green'), ('mu', 'brown')]:
            col_name = f'{param}_rel_error_percent'
            if col_name in df_results_model1.columns:
                ax.plot(df_results_model1['dataset'], df_results_model1[col_name], 
                       'o-', color=color, label=f'{param}', alpha=0.7)
    
    ax.set_xlabel('Датасет')
    ax.set_ylabel('Относительная ошибка (%)')
    ax.set_title('Модель 1: ошибка оценки параметров')
    ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 3. R² для параметров (модель 2)
    ax = axes[1, 0]
    if 'beta_R2' in df_results_model2.columns:
        ax.plot(df_results_model2['dataset'], df_results_model2['beta_R2'], 
               'o-', color='orange', label='β(t)', alpha=0.7)
    if 'gamma_R2' in df_results_model2.columns:
        ax.plot(df_results_model2['dataset'], df_results_model2['gamma_R2'], 
               'o-', color='green', label='γ(t)', alpha=0.7)
    
    ax.axhline(y=0.0, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=1.0, color='gray', linestyle='--', alpha=0.5)
    ax.set_xlabel('Датасет')
    ax.set_ylabel('R²')
    ax.set_title('Модель 2: качество восстановления параметров')
    ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 4. Сравнение по шумным датасетам
    ax = axes[1, 1]
    noise_datasets = [d for d in datasets if 'noise' in d]
    if noise_datasets:
        noise_idx = [i for i, d in enumerate(datasets) if 'noise' in d]
        
        for idx in noise_idx:
            ax.scatter(idx, df_results_model1.iloc[idx]['I_RMSE'], 
                      color='red', s=100, marker='o', alpha=0.7)
            ax.scatter(idx, df_results_model2.iloc[idx]['I_RMSE'], 
                      color='blue', s=100, marker='s', alpha=0.7)
        
        ax.set_xlabel('Индекс датасета с шумом')
        ax.set_ylabel('RMSE для I(t)')
        ax.set_title('Устойчивость к шуму (красный=мод1, синий=мод2)')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(results_dir / "summary_comparison.png", dpi=150, bbox_inches='tight')
    plt.show()

# ============================================================
# ЗАПУСК
# ============================================================

if __name__ == "__main__":
    # Запускаем тестирование
    df_res1, df_res2 = run_testing()
    
    # Строим сводные графики
    plot_summary_results(df_res1, df_res2)
    
    print("\n" + "="*80)
    print("ГОТОВО! Все результаты сохранены.")
    print("="*80)
# Out:
# Using device: cuda
# ================================================================================
# НАЧАЛО ТЕСТИРОВАНИЯ МОДЕЛЕЙ
# ================================================================================
#
# ============================================================
# ТЕСТИРОВАНИЕ: 01_baseline_constant
# Описание: Базовый (константы)
# ============================================================
# Всего точек: 366, Обучающих: 180, Тестовых: 186
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 4600924.500000 | Data: 325088352.000000 | ODE: 1350041.125000
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 147535.031250 | Data: 11057035.000000 | ODE: 36964.683594
# Params: β=0.2869, γ=0.0981, μ=0.0104
# ---
# Epoch  2000 | Loss: 87196.781250 | Data: 6073280.500000 | ODE: 26463.974609
# Params: β=0.2565, γ=0.1129, μ=0.0116
# ---
# Epoch  3000 | Loss: 54328.171875 | Data: 3389409.250000 | ODE: 20434.082031
# Params: β=0.2226, γ=0.1040, μ=0.0121
# ---
# Epoch  4000 | Loss: 33088.730469 | Data: 1809242.750000 | ODE: 14996.302734
# Params: β=0.1909, γ=0.0920, μ=0.0111
# ---
# Epoch  5000 | Loss: 18745.035156 | Data: 920859.062500 | ODE: 9536.444336
# Params: β=0.1648, γ=0.0835, μ=0.0094
# ---
# Epoch  6000 | Loss: 10009.938477 | Data: 472904.750000 | ODE: 5280.891113
# Params: β=0.1442, γ=0.0761, μ=0.0078
# ---
# Epoch  7000 | Loss: 4288.031738 | Data: 158834.218750 | ODE: 2699.689697
# Params: β=0.1282, γ=0.0697, μ=0.0066
# ---
# Epoch  8000 | Loss: 1535.664062 | Data: 50187.250000 | ODE: 1033.791626
# Params: β=0.1159, γ=0.0650, μ=0.0057
# ---
# Epoch  9000 | Loss: 516.789368 | Data: 21350.224609 | ODE: 303.287140
# Params: β=0.1075, γ=0.0618, μ=0.0048
# ---
# Epoch 10000 | Loss: 140.052170 | Data: 3520.866211 | ODE: 104.843513
# Params: β=0.1026, γ=0.0602, μ=0.0042
# ---
# Epoch 11000 | Loss: 97.103180 | Data: 4400.118652 | ODE: 53.101994
# Params: β=0.1006, γ=0.0597, μ=0.0037
# ---
# Epoch 12000 | Loss: 78.673401 | Data: 4460.248047 | ODE: 34.070927
# Params: β=0.1000, γ=0.0597, μ=0.0034
# ---
# Epoch 13000 | Loss: 39.831940 | Data: 1224.244751 | ODE: 27.589491
# Params: β=0.0999, γ=0.0598, μ=0.0032
# ---
# Epoch 14000 | Loss: 119.403572 | Data: 9620.145508 | ODE: 23.202116
# Params: β=0.0999, γ=0.0599, μ=0.0031
# ---
# Epoch 15000 | Loss: 52.418953 | Data: 3121.425781 | ODE: 21.204699
# Params: β=0.0999, γ=0.0599, μ=0.0031
# ---
# Epoch 16000 | Loss: 247.441101 | Data: 22763.923828 | ODE: 19.801861
# Params: β=0.0999, γ=0.0599, μ=0.0031
# ---
# Epoch 17000 | Loss: 129.865723 | Data: 11556.291992 | ODE: 14.302801
# Params: β=0.0999, γ=0.0599, μ=0.0031
# ---
# Epoch 18000 | Loss: 133.740479 | Data: 11532.489258 | ODE: 18.415590
# Params: β=0.1000, γ=0.0599, μ=0.0031
# ---
# Epoch 19000 | Loss: 111.135307 | Data: 9503.246094 | ODE: 16.102850
# Params: β=0.1000, γ=0.0599, μ=0.0030
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 6.25e+04
#   Data Loss: 1.24e+00
#   Physics Loss: 6.25e+04
#   β mean: 0.5096 [min: 0.4782, max: 0.5410]
#   γ mean: 0.2798 [min: 0.2772, max: 0.2824]
#   μ mean: 0.0500 [min: 0.0418, max: 0.0583]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.49e+01
#   Data Loss: 1.20e+00
#   Physics Loss: 1.37e+01
#   β mean: 0.4094 [min: 0.3162, max: 0.5142]
#   γ mean: 0.2209 [min: 0.1813, max: 0.2662]
#   μ mean: 0.0412 [min: 0.0286, max: 0.0555]
#
# Эпоха  2000:
#   Total Loss: 1.34e+00
#   Data Loss: 9.48e-01
#   Physics Loss: 3.94e-01
#   β mean: 0.0267 [min: 0.0257, max: 0.0290]
#   γ mean: 0.0327 [min: 0.0326, max: 0.0330]
#   μ mean: 0.0010 [min: 0.0008, max: 0.0016]
#
# Эпоха  3000:
#   Total Loss: 8.50e-01
#   Data Loss: 7.59e-01
#   Physics Loss: 9.05e-02
#   β mean: 0.0162 [min: 0.0128, max: 0.0241]
#   γ mean: 0.0315 [min: 0.0310, max: 0.0325]
#   μ mean: 0.0006 [min: 0.0005, max: 0.0008]
#
# Эпоха  4000:
#   Total Loss: 8.07e-01
#   Data Loss: 6.64e-01
#   Physics Loss: 1.43e-01
#   β mean: 0.0236 [min: 0.0218, max: 0.0281]
#   γ mean: 0.0304 [min: 0.0302, max: 0.0307]
#   μ mean: 0.0002 [min: 0.0002, max: 0.0003]
#
# Эпоха  5000:
#   Total Loss: 7.14e-01
#   Data Loss: 6.23e-01
#   Physics Loss: 9.11e-02
#   β mean: 0.0132 [min: 0.0118, max: 0.0165]
#   γ mean: 0.0302 [min: 0.0302, max: 0.0303]
#   μ mean: 0.0002 [min: 0.0001, max: 0.0002]
#
# Эпоха  6000:
#   Total Loss: 6.67e-01
#   Data Loss: 6.05e-01
#   Physics Loss: 6.15e-02
#   β mean: 0.0123 [min: 0.0116, max: 0.0143]
#   γ mean: 0.0301 [min: 0.0301, max: 0.0301]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха  7000:
#   Total Loss: 7.90e-01
#   Data Loss: 6.02e-01
#   Physics Loss: 1.88e-01
#   β mean: 0.0141 [min: 0.0119, max: 0.0196]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха  8000:
#   Total Loss: 6.21e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 2.08e-02
#   β mean: 0.0153 [min: 0.0146, max: 0.0176]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха  9000:
#   Total Loss: 6.06e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 5.33e-03
#   β mean: 0.0156 [min: 0.0143, max: 0.0191]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 10000:
#   Total Loss: 6.02e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 2.19e-03
#   β mean: 0.0157 [min: 0.0141, max: 0.0198]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 11000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 1.06e-03
#   β mean: 0.0160 [min: 0.0144, max: 0.0203]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 12000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 8.17e-04
#   β mean: 0.0164 [min: 0.0149, max: 0.0205]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 13000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 6.96e-04
#   β mean: 0.0167 [min: 0.0153, max: 0.0207]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 14000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 6.24e-04
#   β mean: 0.0170 [min: 0.0157, max: 0.0208]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 15000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 5.71e-04
#   β mean: 0.0172 [min: 0.0160, max: 0.0209]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 16000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 5.40e-04
#   β mean: 0.0174 [min: 0.0162, max: 0.0210]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 17000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 5.07e-04
#   β mean: 0.0175 [min: 0.0164, max: 0.0212]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 18000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 4.83e-04
#   β mean: 0.0176 [min: 0.0165, max: 0.0212]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# Эпоха 19000:
#   Total Loss: 6.01e-01
#   Data Loss: 6.00e-01
#   Physics Loss: 4.61e-04
#   β mean: 0.0177 [min: 0.0166, max: 0.0213]
#   γ mean: 0.0300 [min: 0.0300, max: 0.0300]
#   μ mean: 0.0001 [min: 0.0001, max: 0.0001]
#
# ✅ Завершено: 01_baseline_constant
#    Модель 1 - I_RMSE: 27.5187
#    Модель 2 - I_RMSE: 3824.6242
#
# ================================================================================
# ТЕСТИРОВАНИЕ ЗАВЕРШЕНО
# ================================================================================
# Результаты сохранены в: c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\synthetic_datasets_results_pop_105
#   - Модель 1: 1 датасетов
#   - Модель 2: 1 датасетов
# C:\Users\dinara\AppData\Local\Temp\ipykernel_7320\2720318893.py:517: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
# C:\Users\dinara\AppData\Local\Temp\ipykernel_7320\2720318893.py:535: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
# C:\Users\dinara\AppData\Local\Temp\ipykernel_7320\2720318893.py:536: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# ================================================================================
# ГОТОВО! Все результаты сохранены.
# ================================================================================

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
from pathlib import Path
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import json
from datetime import datetime

# ============================================================
# НАСТРОЙКА
# ============================================================

# Определяем девайс
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Фиксируем seed для воспроизводимости
torch.manual_seed(123)
if device.type == 'cuda':
    torch.cuda.manual_seed(123)
np.random.seed(123)
torch.backends.cudnn.deterministic = True

# Создаем папку для результатов
results_dir = Path("synthetic_datasets_results")
results_dir.mkdir(exist_ok=True)

# Создаем подпапки для каждой модели
model1_dir = results_dir / "model1_constant"
model2_dir = results_dir / "model2_temporal"
model1_dir.mkdir(exist_ok=True)
model2_dir.mkdir(exist_ok=True)

# ============================================================
# СПИСОК ДАТАСЕТОВ ДЛЯ ТЕСТИРОВАНИЯ
# ============================================================

datasets = [
    # Основные датасеты
    {"name": "01_baseline_constant", "desc": "Базовый (константы)", "has_noise": False},
    {"name": "02_lockdown_beta_jump", "desc": "Локдаун (скачок β)", "has_noise": False},
    {"name": "03_seasonal_beta_sin", "desc": "Сезонность (плавная β)", "has_noise": False},
    {"name": "04_decaying_beta_trend", "desc": "Затухание (β 0.15→0.1)", "has_noise": False},
    {"name": "05_complex_beta_gamma_dynamics", "desc": "Сложный (β+γ)", "has_noise": False},
    
    # Шумные версии датасета 2
    {"name": "02_lockdown_beta_jump_noise_3pct_seed42", "desc": "Локдаун + шум 3%", "has_noise": True},
    {"name": "02_lockdown_beta_jump_noise_5pct_seed123", "desc": "Локдаун + шум 5%", "has_noise": True},
    {"name": "02_lockdown_beta_jump_noise_10pct_seed456", "desc": "Локдаун + шум 10%", "has_noise": True},
    
    # Шумные версии датасета 5
    {"name": "05_complex_beta_gamma_dynamics_noise_3pct_seed42", "desc": "Сложный + шум 3%", "has_noise": True},
    {"name": "05_complex_beta_gamma_dynamics_noise_5pct_seed123", "desc": "Сложный + шум 5%", "has_noise": True},
    {"name": "05_complex_beta_gamma_dynamics_noise_10pct_seed456", "desc": "Сложный + шум 10%", "has_noise": True},
]

# Истинные параметры для каждого датасета (для расчета ошибок)
true_params = {
    "01_baseline_constant": {"beta": 0.1, "gamma": 0.06, "mu": 0.003, "type": "constant"},
    "02_lockdown_beta_jump": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "03_seasonal_beta_sin": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "04_decaying_beta_trend": {"beta": "time_varying", "gamma": 0.06, "mu": 0.003, "type": "beta_time"},
    "05_complex_beta_gamma_dynamics": {"beta": "time_varying", "gamma": "time_varying", "mu": 0.003, "type": "both_time"},
}

# Для шумных версий параметры те же, что у исходных
for noise_level in [3, 5, 10]:
    for seed in [42, 123, 456]:
        true_params[f"02_lockdown_beta_jump_noise_{noise_level}pct_seed{seed}"] = true_params["02_lockdown_beta_jump"]
        true_params[f"05_complex_beta_gamma_dynamics_noise_{noise_level}pct_seed{seed}"] = true_params["05_complex_beta_gamma_dynamics"]

# ============================================================
# ФУНКЦИИ ДЛЯ РАСЧЕТА МЕТРИК
# ============================================================

def calculate_metrics(y_true, y_pred):
    """Рассчитывает MSE, RMSE, MAE для временных рядов"""
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae}

def calculate_parameter_error_model1(pred_params, true_params_dict):
    """Относительная ошибка для константных параметров (модель 1)"""
    errors = {}
    for param in ['beta', 'gamma', 'mu']:
        if isinstance(true_params_dict[param], (int, float)):
            true_val = true_params_dict[param]
            pred_val = pred_params[param]
            rel_error = abs(pred_val - true_val) / true_val
            errors[param] = {
                "true": true_val,
                "pred": pred_val,
                "abs_error": abs(pred_val - true_val),
                "rel_error": rel_error,
                "rel_error_percent": rel_error * 100
            }
    return errors

def calculate_parameter_error_model2(df_true, df_pred, param_name):
    """Ошибки для временных параметров (модель 2)"""
    true_vals = df_true[param_name].values
    pred_vals = df_pred[param_name].values
    
    # Обрезаем до одинаковой длины
    min_len = min(len(true_vals), len(pred_vals))
    true_vals = true_vals[:min_len]
    pred_vals = pred_vals[:min_len]
    
    mse = mean_squared_error(true_vals, pred_vals)
    rmse = np.sqrt(mse)
    r2 = r2_score(true_vals, pred_vals)
    
    return {
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2,
        "mean_true": np.mean(true_vals),
        "mean_pred": np.mean(pred_vals)
    }

# ============================================================
# ФУНКЦИИ ДЛЯ ВИЗУАЛИЗАЦИИ
# ============================================================

def plot_model_results(df_true, df_pred_model1, df_pred_model2, dataset_name, save_dir):
    """Создает визуализацию сравнения моделей"""
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    fig.suptitle(f'Сравнение моделей: {dataset_name}', fontsize=16, fontweight='bold')
    
    t = df_true['day'].values
    
    # 1. Инфицированные I(t)
    ax = axes[0, 0]
    ax.plot(t, df_true['I'], 'k-', linewidth=2.5, label='Истинные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['I'])], df_pred_model1['I'], 'r--', linewidth=2, label='Модель 1 (конст)')
    ax.plot(t[:len(df_pred_model2['I'])], df_pred_model2['I'], 'b--', linewidth=2, label='Модель 2 (врем)')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Инфицированные')
    ax.set_title('Динамика I(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 2. Умершие D(t)
    ax = axes[0, 1]
    ax.plot(t, df_true['D'], 'k-', linewidth=2.5, label='Истинные', alpha=0.8)
    ax.plot(t[:len(df_pred_model1['D'])], df_pred_model1['D'], 'r--', linewidth=2, label='Модель 1')
    ax.plot(t[:len(df_pred_model2['D'])], df_pred_model2['D'], 'b--', linewidth=2, label='Модель 2')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Умершие')
    ax.set_title('Динамика D(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 3. R₀ (если есть в данных)
    ax = axes[0, 2]
    if 'R0' in df_true.columns:
        ax.plot(t, df_true['R0'], 'k-', linewidth=2.5, label='Истинный R₀', alpha=0.8)
    if 'R0' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['R0'])], df_pred_model2['R0'], 'b--', linewidth=2, label='Модель 2 R₀')
    ax.axhline(y=1.0, color='gray', linestyle='--', alpha=0.5)
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('R₀')
    ax.set_title('Репродуктивное число')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 4. Параметр β(t)
    ax = axes[1, 0]
    if 'beta' in df_true.columns:
        ax.plot(t, df_true['beta'], 'k-', linewidth=2.5, label='Истинный β(t)', alpha=0.8)
    if 'beta' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['beta'])], df_pred_model2['beta'], 'b--', linewidth=2, label='Модель 2 β(t)')
    # Для модели 1 - константа
    if 'beta_const' in df_pred_model1.columns:
        beta_const = df_pred_model1['beta_const'].iloc[0]
        ax.axhline(y=beta_const, color='r', linestyle='--', linewidth=2, label=f'Модель 1 β={beta_const:.4f}')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('β')
    ax.set_title('Параметр β(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 5. Параметры γ(t) и μ(t)
    ax = axes[1, 1]
    if 'gamma' in df_true.columns:
        ax.plot(t, df_true['gamma'], 'g-', linewidth=2, label='Истинный γ(t)', alpha=0.6)
    if 'mu' in df_true.columns:
        ax.plot(t, df_true['mu'], 'brown', linewidth=2, label='Истинный μ(t)', alpha=0.6)
    if 'gamma' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['gamma'])], df_pred_model2['gamma'], 'g--', linewidth=2, label='Модель 2 γ(t)')
    if 'mu' in df_pred_model2.columns:
        ax.plot(t[:len(df_pred_model2['mu'])], df_pred_model2['mu'], 'orange', linewidth=2, label='Модель 2 μ(t)')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('Параметры')
    ax.set_title('Параметры γ(t) и μ(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 6. Ошибки предсказания I(t)
    ax = axes[1, 2]
    min_len = min(len(t), len(df_pred_model1['I']), len(df_pred_model2['I']))
    error1 = np.abs(df_true['I'].values[:min_len] - df_pred_model1['I'][:min_len])
    error2 = np.abs(df_true['I'].values[:min_len] - df_pred_model2['I'][:min_len])
    
    ax.plot(t[:min_len], error1, 'r-', linewidth=1.5, label='Ошибка Модель 1')
    ax.plot(t[:min_len], error2, 'b-', linewidth=1.5, label='Ошибка Модель 2')
    ax.set_xlabel('Время (дни)')
    ax.set_ylabel('|Ошибка| I(t)')
    ax.set_title('Абсолютная ошибка для I(t)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(save_dir / f"{dataset_name}_comparison.png", dpi=150, bbox_inches='tight')
    plt.close()

# ============================================================
# ОСНОВНОЙ ЦИКЛ ТЕСТИРОВАНИЯ
# ============================================================

def run_testing():
    """Запускает тестирование на всех датасетах"""
    
    # Словари для накопления результатов
    results_model1 = []
    results_model2 = []
    
    print("="*80)
    print("НАЧАЛО ТЕСТИРОВАНИЯ МОДЕЛЕЙ")
    print("="*80)
    
    for ds in datasets:
        dataset_name = ds["name"]
        dataset_desc = ds["desc"]
        
        print(f"\n{'='*60}")
        print(f"ТЕСТИРОВАНИЕ: {dataset_name}")
        print(f"Описание: {dataset_desc}")
        print('='*60)
        
        try:
            # ==================================================
            # ЗАГРУЗКА ДАННЫХ
            # ==================================================
            file_path = f"./synthetic_datasets/{dataset_name}.csv"
            if not os.path.exists(file_path):
                print(f"❌ Файл не найден: {file_path}")
                continue
                
            df_true = pd.read_csv(file_path)
            
            # Получаем данные
            S = df_true['S'].values
            I = df_true['I'].values
            D = df_true['D'].values
            R = df_true['R'].values
            timesteps = np.arange(len(S)).astype(float)
            
            # Параметры
            # train_size = min(101, len(timesteps) // 2)  # Обучаем на половине данных
            train_size = 130
            population = 1000
            
            print(f"Всего точек: {len(timesteps)}, Обучающих: {train_size}, Тестовых: {len(timesteps)-train_size}")
            
            # ==================================================
            # МОДЕЛЬ 1: EINN_PINN (константные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 1 (константные параметры) ---")
            
            from NEW_PINN.PINN_const import EINN_PINN  # предполагаемый импорт
            
            model1 = EINN_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                R_data=R,
                D_data=D,
                population=population,
                train_size=train_size,
                device=device
            )
            
            # Обучаем
            model1.train_model(n_epoch=20000, lambda_data=0.01, lambda_ode=1.0)
            
            # Получаем параметры
            final_params = model1.params.get_params_dict()
            
            # Предсказание
            S_pred1, I_pred1, R_pred1, D_pred1 = model1.predict(timesteps)
            
            # Конвертируем в numpy
            S_pred1 = S_pred1.numpy()
            I_pred1 = I_pred1.numpy()
            R_pred1 = R_pred1.numpy()
            D_pred1 = D_pred1.numpy()
            
            # Создаем DataFrame с предсказаниями модели 1
            df_pred1 = pd.DataFrame({
                'day': timesteps[:len(S_pred1)],
                'S': S_pred1,
                'I': I_pred1,
                'R': R_pred1,
                'D': D_pred1,
                'beta_const': final_params['beta'],
                'gamma_const': final_params['gamma'],
                'mu_const': final_params['mu']
            })
            df_pred1['R0_const'] = df_pred1['beta_const'] / (df_pred1['gamma_const'] + df_pred1['mu_const'])
            
            # ==================================================
            # МОДЕЛЬ 2: Nature_PINN (временные параметры)
            # ==================================================
            print("\n--- МОДЕЛЬ 2 (временные параметры) ---")
            
            from NEW_PINN.PINN_time import Nature_PINN  # предполагаемый импорт
            
            model2 = Nature_PINN(
                t=timesteps,
                S_data=S,
                I_data=I,
                D_data=D,
                R_data=R,
                device=device,
                train_size=train_size,
                population_n=population
            )
            
            # Обучаем
            model2.train(n_epoch=20000)
            
            # Получаем предсказания
            predictions = model2.predict()
            
            # Создаем DataFrame с предсказаниями модели 2
            df_pred2 = pd.DataFrame({
                'day': predictions['t'][:len(predictions['S'])],
                'S': predictions['S'],
                'I': predictions['I'],
                'R': predictions['R'],
                'D': predictions['D'],
                'beta': predictions['beta'],
                'gamma': predictions['gamma'],
                'mu': predictions['mu']
            })
            df_pred2['R0'] = df_pred2['beta'] / (df_pred2['gamma'] + df_pred2['mu'])
            
            # ==================================================
            # РАСЧЕТ МЕТРИК
            # ==================================================
            
            # Обрезаем до одинаковой длины
            min_len = min(len(df_true), len(df_pred1), len(df_pred2))
            df_true_trim = df_true.iloc[:min_len]
            df_pred1_trim = df_pred1.iloc[:min_len]
            df_pred2_trim = df_pred2.iloc[:min_len]
            
            # Метрики для SIRD
            metrics_model1 = {}
            metrics_model2 = {}
            
            for compartment in ['S', 'I', 'R', 'D']:
                true_vals = df_true_trim[compartment].values
                pred1_vals = df_pred1_trim[compartment].values
                pred2_vals = df_pred2_trim[compartment].values
                
                metrics_model1[compartment] = calculate_metrics(true_vals, pred1_vals)
                metrics_model2[compartment] = calculate_metrics(true_vals, pred2_vals)
            
            # Ошибки параметров для модели 1
            param_errors_model1 = {}
            if dataset_name in true_params:
                if true_params[dataset_name]["type"] == "constant":
                    param_errors_model1 = calculate_parameter_error_model1(final_params, true_params[dataset_name])
            
            # Ошибки параметров для модели 2
            param_errors_model2 = {}
            if dataset_name in true_params:
                if 'beta' in df_true.columns and true_params[dataset_name]["beta"] == "time_varying":
                    param_errors_model2['beta'] = calculate_parameter_error_model2(df_true, df_pred2, 'beta')
                if 'gamma' in df_true.columns and true_params[dataset_name]["gamma"] == "time_varying":
                    param_errors_model2['gamma'] = calculate_parameter_error_model2(df_true, df_pred2, 'gamma')
                if 'mu' in df_true.columns and isinstance(true_params[dataset_name]["mu"], (int, float)):
                    param_errors_model2['mu'] = calculate_parameter_error_model2(df_true, df_pred2, 'mu')
            
            # ==================================================
            # СОХРАНЕНИЕ РЕЗУЛЬТАТОВ
            # ==================================================
            
            # Сохраняем предсказания
            df_pred1.to_csv(model1_dir / f"{dataset_name}_predictions.csv", index=False)
            df_pred2.to_csv(model2_dir / f"{dataset_name}_predictions.csv", index=False)
            
            # Сохраняем метрики
            result_entry_model1 = {
                'dataset': dataset_name,
                'description': dataset_desc,
                **{f"{comp}_MSE": metrics_model1[comp]['MSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_RMSE": metrics_model1[comp]['RMSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_MAE": metrics_model1[comp]['MAE'] for comp in ['S', 'I', 'R', 'D']},
                'beta_pred': final_params['beta'],
                'gamma_pred': final_params['gamma'],
                'mu_pred': final_params['mu'],
            }
            
            # Добавляем ошибки параметров если есть
            if param_errors_model1:
                for param, errors in param_errors_model1.items():
                    result_entry_model1[f"{param}_true"] = errors['true']
                    result_entry_model1[f"{param}_rel_error"] = errors['rel_error']
                    result_entry_model1[f"{param}_rel_error_percent"] = errors['rel_error_percent']
            
            results_model1.append(result_entry_model1)
            
            result_entry_model2 = {
                'dataset': dataset_name,
                'description': dataset_desc,
                **{f"{comp}_MSE": metrics_model2[comp]['MSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_RMSE": metrics_model2[comp]['RMSE'] for comp in ['S', 'I', 'R', 'D']},
                **{f"{comp}_MAE": metrics_model2[comp]['MAE'] for comp in ['S', 'I', 'R', 'D']},
            }
            
            # Добавляем ошибки параметров
            for param, errors in param_errors_model2.items():
                result_entry_model2[f"{param}_RMSE"] = errors['RMSE']
                result_entry_model2[f"{param}_R2"] = errors['R2']
            
            results_model2.append(result_entry_model2)
            
            # ==================================================
            # ВИЗУАЛИЗАЦИЯ
            # ==================================================
            
            plot_model_results(df_true, df_pred1, df_pred2, dataset_name, results_dir)
            
            print(f"\n✅ Завершено: {dataset_name}")
            print(f"   Модель 1 - I_RMSE: {metrics_model1['I']['RMSE']:.4f}")
            print(f"   Модель 2 - I_RMSE: {metrics_model2['I']['RMSE']:.4f}")
            
        except Exception as e:
            print(f"❌ Ошибка при обработке {dataset_name}: {str(e)}")
            import traceback
            traceback.print_exc()
            continue
    
    # ==================================================
    # СОХРАНЕНИЕ СВОДНЫХ РЕЗУЛЬТАТОВ
    # ==================================================
    
    # Сохраняем результаты в CSV
    df_results_model1 = pd.DataFrame(results_model1)
    df_results_model2 = pd.DataFrame(results_model2)
    
    df_results_model1.to_csv(results_dir / "summary_model1.csv", index=False)
    df_results_model2.to_csv(results_dir / "summary_model2.csv", index=False)
    
    # Сохраняем в JSON для удобства
    with open(results_dir / "summary_model1.json", 'w') as f:
        json.dump(results_model1, f, indent=2, default=str)
    
    with open(results_dir / "summary_model2.json", 'w') as f:
        json.dump(results_model2, f, indent=2, default=str)
    
    print("\n" + "="*80)
    print("ТЕСТИРОВАНИЕ ЗАВЕРШЕНО")
    print("="*80)
    print(f"Результаты сохранены в: {results_dir.absolute()}")
    print(f"  - Модель 1: {len(results_model1)} датасетов")
    print(f"  - Модель 2: {len(results_model2)} датасетов")
    
    return df_results_model1, df_results_model2

# ============================================================
# ФУНКЦИЯ ДЛЯ ВИЗУАЛИЗАЦИИ СВОДНЫХ РЕЗУЛЬТАТОВ
# ============================================================

def plot_summary_results(df_results_model1, df_results_model2):
    """Создает сводные графики по всем результатам"""
    
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle('Сводные результаты тестирования моделей', fontsize=16, fontweight='bold')
    
    # 1. Сравнение RMSE для I(t)
    ax = axes[0, 0]
    datasets = df_results_model1['dataset'].values
    x = np.arange(len(datasets))
    width = 0.35
    
    ax.bar(x - width/2, df_results_model1['I_RMSE'], width, label='Модель 1', color='red', alpha=0.7)
    ax.bar(x + width/2, df_results_model2['I_RMSE'], width, label='Модель 2', color='blue', alpha=0.7)
    
    ax.set_xlabel('Датасет')
    ax.set_ylabel('RMSE для I(t)')
    ax.set_title('Сравнение точности предсказания I(t)')
    ax.set_xticks(x)
    ax.set_xticklabels([d[:15] + '...' if len(d) > 15 else d for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3, axis='y')
    
    # 2. Относительная ошибка параметров (для модели 1)
    ax = axes[0, 1]
    if 'beta_rel_error_percent' in df_results_model1.columns:
        for param, color in [('beta', 'orange'), ('gamma', 'green'), ('mu', 'brown')]:
            col_name = f'{param}_rel_error_percent'
            if col_name in df_results_model1.columns:
                ax.plot(df_results_model1['dataset'], df_results_model1[col_name], 
                       'o-', color=color, label=f'{param}', alpha=0.7)
    
    ax.set_xlabel('Датасет')
    ax.set_ylabel('Относительная ошибка (%)')
    ax.set_title('Модель 1: ошибка оценки параметров')
    ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 3. R² для параметров (модель 2)
    ax = axes[1, 0]
    if 'beta_R2' in df_results_model2.columns:
        ax.plot(df_results_model2['dataset'], df_results_model2['beta_R2'], 
               'o-', color='orange', label='β(t)', alpha=0.7)
    if 'gamma_R2' in df_results_model2.columns:
        ax.plot(df_results_model2['dataset'], df_results_model2['gamma_R2'], 
               'o-', color='green', label='γ(t)', alpha=0.7)
    
    ax.axhline(y=0.0, color='gray', linestyle='--', alpha=0.5)
    ax.axhline(y=1.0, color='gray', linestyle='--', alpha=0.5)
    ax.set_xlabel('Датасет')
    ax.set_ylabel('R²')
    ax.set_title('Модель 2: качество восстановления параметров')
    ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    # 4. Сравнение по шумным датасетам
    ax = axes[1, 1]
    noise_datasets = [d for d in datasets if 'noise' in d]
    if noise_datasets:
        noise_idx = [i for i, d in enumerate(datasets) if 'noise' in d]
        
        for idx in noise_idx:
            ax.scatter(idx, df_results_model1.iloc[idx]['I_RMSE'], 
                      color='red', s=100, marker='o', alpha=0.7)
            ax.scatter(idx, df_results_model2.iloc[idx]['I_RMSE'], 
                      color='blue', s=100, marker='s', alpha=0.7)
        
        ax.set_xlabel('Индекс датасета с шумом')
        ax.set_ylabel('RMSE для I(t)')
        ax.set_title('Устойчивость к шуму (красный=мод1, синий=мод2)')
        ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.savefig(results_dir / "summary_comparison.png", dpi=150, bbox_inches='tight')
    plt.show()

# ============================================================
# ЗАПУСК
# ============================================================

if __name__ == "__main__":
    # Запускаем тестирование
    df_res1, df_res2 = run_testing()
    
    # Строим сводные графики
    plot_summary_results(df_res1, df_res2)
    
    print("\n" + "="*80)
    print("ГОТОВО! Все результаты сохранены.")
    print("="*80)
# Out:
# Using device: cuda
# ================================================================================
# НАЧАЛО ТЕСТИРОВАНИЯ МОДЕЛЕЙ
# ================================================================================
#
# ============================================================
# ТЕСТИРОВАНИЕ: 01_baseline_constant
# Описание: Базовый (константы)
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 95.109879 | Data: 4928.062500 | ODE: 45.829254
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 4.591902 | Data: 388.556244 | ODE: 0.706339
# Params: β=0.2864, γ=0.1194, μ=0.0114
# ---
# Epoch  2000 | Loss: 2.594807 | Data: 205.324570 | ODE: 0.541561
# Params: β=0.2526, γ=0.1398, μ=0.0142
# ---
# Epoch  3000 | Loss: 1.962349 | Data: 144.723053 | ODE: 0.515119
# Params: β=0.2233, γ=0.1324, μ=0.0159
# ---
# Epoch  4000 | Loss: 1.344892 | Data: 91.906525 | ODE: 0.425827
# Params: β=0.1944, γ=0.1161, μ=0.0162
# ---
# Epoch  5000 | Loss: 0.792266 | Data: 48.749710 | ODE: 0.304769
# Params: β=0.1680, γ=0.1011, μ=0.0145
# ---
# Epoch  6000 | Loss: 0.342333 | Data: 18.105152 | ODE: 0.161281
# Params: β=0.1464, γ=0.0892, μ=0.0120
# ---
# Epoch  7000 | Loss: 0.156195 | Data: 6.777538 | ODE: 0.088420
# Params: β=0.1301, γ=0.0795, μ=0.0098
# ---
# Epoch  8000 | Loss: 0.065234 | Data: 2.354374 | ODE: 0.041690
# Params: β=0.1179, γ=0.0716, μ=0.0081
# ---
# Epoch  9000 | Loss: 0.025063 | Data: 0.696834 | ODE: 0.018095
# Params: β=0.1091, γ=0.0661, μ=0.0069
# ---
# Epoch 10000 | Loss: 0.010557 | Data: 0.227157 | ODE: 0.008285
# Params: β=0.1036, γ=0.0628, μ=0.0060
# ---
# Epoch 11000 | Loss: 0.006371 | Data: 0.128798 | ODE: 0.005083
# Params: β=0.1010, γ=0.0613, μ=0.0054
# ---
# Epoch 12000 | Loss: 0.259707 | Data: 24.519215 | ODE: 0.014515
# Params: β=0.1002, γ=0.0607, μ=0.0050
# ---
# Epoch 13000 | Loss: 0.003831 | Data: 0.087788 | ODE: 0.002953
# Params: β=0.1000, γ=0.0605, μ=0.0048
# ---
# Epoch 14000 | Loss: 0.003168 | Data: 0.076054 | ODE: 0.002408
# Params: β=0.1000, γ=0.0604, μ=0.0046
# ---
# Epoch 15000 | Loss: 0.002673 | Data: 0.066696 | ODE: 0.002006
# Params: β=0.1000, γ=0.0603, μ=0.0045
# ---
# Epoch 16000 | Loss: 0.002286 | Data: 0.059162 | ODE: 0.001694
# Params: β=0.1000, γ=0.0602, μ=0.0044
# ---
# Epoch 17000 | Loss: 0.001968 | Data: 0.053135 | ODE: 0.001437
# Params: β=0.1001, γ=0.0602, μ=0.0043
# ---
# Epoch 18000 | Loss: 0.001717 | Data: 0.048656 | ODE: 0.001231
# Params: β=0.1001, γ=0.0601, μ=0.0043
# ---
# Epoch 19000 | Loss: 0.001518 | Data: 0.045388 | ODE: 0.001064
# Params: β=0.1001, γ=0.0601, μ=0.0042
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 6.73e+00
#   Data Loss: 1.07e+00
#   Physics Loss: 5.65e+00
#   β mean: 0.5096 [min: 0.4782, max: 0.5410]
#   γ mean: 0.2798 [min: 0.2772, max: 0.2824]
#   μ mean: 0.0502 [min: 0.0424, max: 0.0579]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.20e-01
#   Data Loss: 1.15e-01
#   Physics Loss: 5.04e-03
#   β mean: 0.0664 [min: 0.0587, max: 0.0831]
#   γ mean: 0.0497 [min: 0.0350, max: 0.0835]
#   μ mean: 0.0024 [min: 0.0015, max: 0.0042]
#
# Эпоха  2000:
#   Total Loss: 1.03e-01
#   Data Loss: 1.00e-01
#   Physics Loss: 3.03e-03
#   β mean: 0.0641 [min: 0.0526, max: 0.1066]
#   γ mean: 0.0473 [min: 0.0311, max: 0.0959]
#   μ mean: 0.0021 [min: 0.0009, max: 0.0045]
#
# Эпоха  3000:
#   Total Loss: 3.22e-02
#   Data Loss: 2.99e-02
#   Physics Loss: 2.33e-03
#   β mean: 0.0605 [min: 0.0429, max: 0.1463]
#   γ mean: 0.0427 [min: 0.0300, max: 0.1240]
#   μ mean: 0.0016 [min: 0.0003, max: 0.0051]
#
# Эпоха  4000:
#   Total Loss: 3.08e-03
#   Data Loss: 1.86e-03
#   Physics Loss: 1.23e-03
#   β mean: 0.0754 [min: 0.0367, max: 0.1943]
#   γ mean: 0.0481 [min: 0.0303, max: 0.1164]
#   μ mean: 0.0020 [min: 0.0002, max: 0.0091]
#
# Эпоха  5000:
#   Total Loss: 1.02e-03
#   Data Loss: 5.39e-04
#   Physics Loss: 4.83e-04
#   β mean: 0.0823 [min: 0.0492, max: 0.1684]
#   γ mean: 0.0484 [min: 0.0314, max: 0.0887]
#   μ mean: 0.0021 [min: 0.0002, max: 0.0092]
#
# Эпоха  6000:
#   Total Loss: 5.25e-04
#   Data Loss: 2.51e-04
#   Physics Loss: 2.74e-04
#   β mean: 0.0880 [min: 0.0644, max: 0.1460]
#   γ mean: 0.0491 [min: 0.0332, max: 0.0741]
#   μ mean: 0.0020 [min: 0.0002, max: 0.0072]
#
# Эпоха  7000:
#   Total Loss: 3.25e-04
#   Data Loss: 1.39e-04
#   Physics Loss: 1.86e-04
#   β mean: 0.0923 [min: 0.0768, max: 0.1331]
#   γ mean: 0.0500 [min: 0.0353, max: 0.0675]
#   μ mean: 0.0019 [min: 0.0004, max: 0.0055]
#
# Эпоха  8000:
#   Total Loss: 2.11e-04
#   Data Loss: 8.64e-05
#   Physics Loss: 1.25e-04
#   β mean: 0.0962 [min: 0.0882, max: 0.1243]
#   γ mean: 0.0509 [min: 0.0376, max: 0.0634]
#   μ mean: 0.0019 [min: 0.0005, max: 0.0045]
#
# Эпоха  9000:
#   Total Loss: 1.45e-04
#   Data Loss: 5.91e-05
#   Physics Loss: 8.59e-05
#   β mean: 0.0992 [min: 0.0948, max: 0.1187]
#   γ mean: 0.0516 [min: 0.0395, max: 0.0612]
#   μ mean: 0.0019 [min: 0.0006, max: 0.0041]
#
# Эпоха 10000:
#   Total Loss: 1.03e-04
#   Data Loss: 4.16e-05
#   Physics Loss: 6.15e-05
#   β mean: 0.1014 [min: 0.0971, max: 0.1149]
#   γ mean: 0.0522 [min: 0.0409, max: 0.0604]
#   μ mean: 0.0019 [min: 0.0007, max: 0.0039]
#
# Эпоха 11000:
#   Total Loss: 1.11e-04
#   Data Loss: 3.06e-05
#   Physics Loss: 8.05e-05
#   β mean: 0.1030 [min: 0.0983, max: 0.1124]
#   γ mean: 0.0525 [min: 0.0418, max: 0.0603]
#   μ mean: 0.0019 [min: 0.0007, max: 0.0038]
#
# Эпоха 12000:
#   Total Loss: 6.24e-05
#   Data Loss: 2.24e-05
#   Physics Loss: 4.00e-05
#   β mean: 0.1043 [min: 0.0989, max: 0.1129]
#   γ mean: 0.0528 [min: 0.0424, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0007, max: 0.0038]
#
# Эпоха 13000:
#   Total Loss: 4.17e-05
#   Data Loss: 1.69e-05
#   Physics Loss: 2.48e-05
#   β mean: 0.1052 [min: 0.0993, max: 0.1159]
#   γ mean: 0.0529 [min: 0.0428, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0008, max: 0.0037]
#
# Эпоха 14000:
#   Total Loss: 5.37e-05
#   Data Loss: 1.25e-05
#   Physics Loss: 4.12e-05
#   β mean: 0.1059 [min: 0.0994, max: 0.1183]
#   γ mean: 0.0530 [min: 0.0431, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0008, max: 0.0036]
#
# Эпоха 15000:
#   Total Loss: 2.64e-05
#   Data Loss: 1.07e-05
#   Physics Loss: 1.57e-05
#   β mean: 0.1066 [min: 0.0996, max: 0.1201]
#   γ mean: 0.0531 [min: 0.0433, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0008, max: 0.0036]
#
# Эпоха 16000:
#   Total Loss: 2.49e-05
#   Data Loss: 9.54e-06
#   Physics Loss: 1.53e-05
#   β mean: 0.1070 [min: 0.0997, max: 0.1216]
#   γ mean: 0.0532 [min: 0.0434, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0008, max: 0.0035]
#
# Эпоха 17000:
#   Total Loss: 1.97e-05
#   Data Loss: 7.72e-06
#   Physics Loss: 1.20e-05
#   β mean: 0.1074 [min: 0.0997, max: 0.1227]
#   γ mean: 0.0533 [min: 0.0436, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0009, max: 0.0034]
#
# Эпоха 18000:
#   Total Loss: 1.85e-05
#   Data Loss: 6.91e-06
#   Physics Loss: 1.16e-05
#   β mean: 0.1077 [min: 0.0997, max: 0.1236]
#   γ mean: 0.0533 [min: 0.0436, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0009, max: 0.0034]
#
# Эпоха 19000:
#   Total Loss: 1.52e-05
#   Data Loss: 6.53e-06
#   Physics Loss: 8.69e-06
#   β mean: 0.1079 [min: 0.0997, max: 0.1244]
#   γ mean: 0.0533 [min: 0.0437, max: 0.0601]
#   μ mean: 0.0019 [min: 0.0009, max: 0.0033]
#
# ✅ Завершено: 01_baseline_constant
#    Модель 1 - I_RMSE: 1.9327
#    Модель 2 - I_RMSE: 12.6869
#
# ============================================================
# ТЕСТИРОВАНИЕ: 02_lockdown_beta_jump
# Описание: Локдаун (скачок β)
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 10.333063 | Data: 620.891541 | ODE: 4.124148
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 0.316750 | Data: 22.733456 | ODE: 0.089416
# Params: β=0.2847, γ=0.1185, μ=0.0112
# ---
# Epoch  2000 | Loss: 0.241602 | Data: 16.760571 | ODE: 0.073996
# Params: β=0.2548, γ=0.1411, μ=0.0136
# ---
# Epoch  3000 | Loss: 0.193818 | Data: 13.414264 | ODE: 0.059675
# Params: β=0.2243, γ=0.1556, μ=0.0160
# ---
# Epoch  4000 | Loss: 0.162393 | Data: 10.726429 | ODE: 0.055129
# Params: β=0.1977, γ=0.1498, μ=0.0179
# ---
# Epoch  5000 | Loss: 0.130019 | Data: 7.784184 | ODE: 0.052177
# Params: β=0.1724, γ=0.1310, μ=0.0192
# ---
# Epoch  6000 | Loss: 0.098795 | Data: 5.128582 | ODE: 0.047509
# Params: β=0.1487, γ=0.1124, μ=0.0191
# ---
# Epoch  7000 | Loss: 0.072261 | Data: 3.243947 | ODE: 0.039822
# Params: β=0.1282, γ=0.0974, μ=0.0170
# ---
# Epoch  8000 | Loss: 0.053643 | Data: 2.029627 | ODE: 0.033346
# Params: β=0.1112, γ=0.0858, μ=0.0144
# ---
# Epoch  9000 | Loss: 0.039766 | Data: 1.324315 | ODE: 0.026522
# Params: β=0.0975, γ=0.0770, μ=0.0121
# ---
# Epoch 10000 | Loss: 0.032207 | Data: 0.961456 | ODE: 0.022592
# Params: β=0.0868, γ=0.0706, μ=0.0101
# ---
# Epoch 11000 | Loss: 0.028643 | Data: 0.817369 | ODE: 0.020469
# Params: β=0.0787, γ=0.0661, μ=0.0084
# ---
# Epoch 12000 | Loss: 0.027023 | Data: 0.720673 | ODE: 0.019817
# Params: β=0.0732, γ=0.0632, μ=0.0071
# ---
# Epoch 13000 | Loss: 0.026459 | Data: 0.684265 | ODE: 0.019616
# Params: β=0.0700, γ=0.0618, μ=0.0060
# ---
# Epoch 14000 | Loss: 0.026369 | Data: 0.677014 | ODE: 0.019598
# Params: β=0.0687, γ=0.0614, μ=0.0052
# ---
# Epoch 15000 | Loss: 0.026273 | Data: 0.668054 | ODE: 0.019592
# Params: β=0.0682, γ=0.0614, μ=0.0046
# ---
# Epoch 16000 | Loss: 0.026240 | Data: 0.665711 | ODE: 0.019583
# Params: β=0.0680, γ=0.0615, μ=0.0042
# ---
# Epoch 17000 | Loss: 0.026204 | Data: 0.663993 | ODE: 0.019565
# Params: β=0.0679, γ=0.0616, μ=0.0039
# ---
# Epoch 18000 | Loss: 0.026674 | Data: 0.719695 | ODE: 0.019477
# Params: β=0.0678, γ=0.0617, μ=0.0037
# ---
# Epoch 19000 | Loss: 0.026058 | Data: 0.668092 | ODE: 0.019377
# Params: β=0.0677, γ=0.0617, μ=0.0036
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 2.40e+00
#   Data Loss: 1.58e+00
#   Physics Loss: 8.15e-01
#   β mean: 0.5096 [min: 0.4946, max: 0.5247]
#   γ mean: 0.2798 [min: 0.2660, max: 0.2936]
#   μ mean: 0.0501 [min: 0.0414, max: 0.0588]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 7.59e-02
#   Data Loss: 7.54e-02
#   Physics Loss: 4.43e-04
#   β mean: 0.1857 [min: 0.0509, max: 0.4546]
#   γ mean: 0.1597 [min: 0.0527, max: 0.3496]
#   μ mean: 0.0116 [min: 0.0025, max: 0.0326]
#
# Эпоха  2000:
#   Total Loss: 7.49e-02
#   Data Loss: 7.45e-02
#   Physics Loss: 4.24e-04
#   β mean: 0.1751 [min: 0.0527, max: 0.4256]
#   γ mean: 0.1524 [min: 0.0532, max: 0.3320]
#   μ mean: 0.0081 [min: 0.0024, max: 0.0209]
#
# Эпоха  3000:
#   Total Loss: 7.20e-02
#   Data Loss: 7.15e-02
#   Physics Loss: 5.39e-04
#   β mean: 0.2015 [min: 0.0548, max: 0.5189]
#   γ mean: 0.1716 [min: 0.0538, max: 0.3849]
#   μ mean: 0.0105 [min: 0.0019, max: 0.0322]
#
# Эпоха  4000:
#   Total Loss: 5.68e-02
#   Data Loss: 5.51e-02
#   Physics Loss: 1.67e-03
#   β mean: 0.3125 [min: 0.0678, max: 0.6482]
#   γ mean: 0.2599 [min: 0.0639, max: 0.4876]
#   μ mean: 0.0200 [min: 0.0018, max: 0.0641]
#
# Эпоха  5000:
#   Total Loss: 3.23e-02
#   Data Loss: 3.18e-02
#   Physics Loss: 4.82e-04
#   β mean: 0.1645 [min: 0.0496, max: 0.2899]
#   γ mean: 0.1461 [min: 0.0555, max: 0.2584]
#   μ mean: 0.0082 [min: 0.0032, max: 0.0185]
#
# Эпоха  6000:
#   Total Loss: 1.24e-02
#   Data Loss: 1.17e-02
#   Physics Loss: 7.38e-04
#   β mean: 0.0731 [min: 0.0400, max: 0.1890]
#   γ mean: 0.0661 [min: 0.0383, max: 0.1043]
#   μ mean: 0.0023 [min: 0.0014, max: 0.0042]
#
# Эпоха  7000:
#   Total Loss: 5.38e-03
#   Data Loss: 4.48e-03
#   Physics Loss: 8.98e-04
#   β mean: 0.0552 [min: 0.0304, max: 0.2175]
#   γ mean: 0.0523 [min: 0.0360, max: 0.0660]
#   μ mean: 0.0017 [min: 0.0006, max: 0.0045]
#
# Эпоха  8000:
#   Total Loss: 3.87e-03
#   Data Loss: 3.04e-03
#   Physics Loss: 8.26e-04
#   β mean: 0.0537 [min: 0.0287, max: 0.2445]
#   γ mean: 0.0509 [min: 0.0359, max: 0.0607]
#   μ mean: 0.0017 [min: 0.0006, max: 0.0043]
#
# Эпоха  9000:
#   Total Loss: 2.56e-03
#   Data Loss: 1.87e-03
#   Physics Loss: 6.93e-04
#   β mean: 0.0530 [min: 0.0290, max: 0.2743]
#   γ mean: 0.0520 [min: 0.0397, max: 0.0606]
#   μ mean: 0.0023 [min: 0.0015, max: 0.0036]
#
# Эпоха 10000:
#   Total Loss: 1.76e-03
#   Data Loss: 1.23e-03
#   Physics Loss: 5.37e-04
#   β mean: 0.0524 [min: 0.0289, max: 0.3125]
#   γ mean: 0.0537 [min: 0.0483, max: 0.0608]
#   μ mean: 0.0029 [min: 0.0027, max: 0.0032]
#
# Эпоха 11000:
#   Total Loss: 1.49e-03
#   Data Loss: 1.08e-03
#   Physics Loss: 4.04e-04
#   β mean: 0.0551 [min: 0.0331, max: 0.3361]
#   γ mean: 0.0600 [min: 0.0551, max: 0.0722]
#   μ mean: 0.0027 [min: 0.0024, max: 0.0032]
#
# Эпоха 12000:
#   Total Loss: 1.37e-03
#   Data Loss: 1.06e-03
#   Physics Loss: 3.12e-04
#   β mean: 0.0600 [min: 0.0420, max: 0.3358]
#   γ mean: 0.0689 [min: 0.0554, max: 0.1033]
#   μ mean: 0.0027 [min: 0.0025, max: 0.0032]
#
# Эпоха 13000:
#   Total Loss: 1.25e-03
#   Data Loss: 1.01e-03
#   Physics Loss: 2.43e-04
#   β mean: 0.0671 [min: 0.0447, max: 0.3164]
#   γ mean: 0.0771 [min: 0.0550, max: 0.1252]
#   μ mean: 0.0029 [min: 0.0028, max: 0.0031]
#
# Эпоха 14000:
#   Total Loss: 1.14e-03
#   Data Loss: 9.07e-04
#   Physics Loss: 2.37e-04
#   β mean: 0.0777 [min: 0.0446, max: 0.2878]
#   γ mean: 0.0806 [min: 0.0550, max: 0.1268]
#   μ mean: 0.0030 [min: 0.0029, max: 0.0033]
#
# Эпоха 15000:
#   Total Loss: 9.50e-04
#   Data Loss: 7.92e-04
#   Physics Loss: 1.58e-04
#   β mean: 0.0886 [min: 0.0443, max: 0.2544]
#   γ mean: 0.0846 [min: 0.0544, max: 0.1293]
#   μ mean: 0.0031 [min: 0.0030, max: 0.0034]
#
# Эпоха 16000:
#   Total Loss: 7.94e-04
#   Data Loss: 6.71e-04
#   Physics Loss: 1.24e-04
#   β mean: 0.0985 [min: 0.0439, max: 0.2241]
#   γ mean: 0.0926 [min: 0.0545, max: 0.1509]
#   μ mean: 0.0031 [min: 0.0030, max: 0.0035]
#
# Эпоха 17000:
#   Total Loss: 6.23e-04
#   Data Loss: 5.33e-04
#   Physics Loss: 8.92e-05
#   β mean: 0.1013 [min: 0.0436, max: 0.1919]
#   γ mean: 0.0955 [min: 0.0552, max: 0.1599]
#   μ mean: 0.0031 [min: 0.0030, max: 0.0034]
#
# Эпоха 18000:
#   Total Loss: 4.56e-04
#   Data Loss: 3.95e-04
#   Physics Loss: 6.13e-05
#   β mean: 0.1019 [min: 0.0432, max: 0.1865]
#   γ mean: 0.0971 [min: 0.0569, max: 0.1683]
#   μ mean: 0.0030 [min: 0.0029, max: 0.0034]
#
# Эпоха 19000:
#   Total Loss: 3.22e-04
#   Data Loss: 2.87e-04
#   Physics Loss: 3.45e-05
#   β mean: 0.1034 [min: 0.0432, max: 0.1962]
#   γ mean: 0.1003 [min: 0.0575, max: 0.1813]
#   μ mean: 0.0030 [min: 0.0029, max: 0.0032]
#
# ✅ Завершено: 02_lockdown_beta_jump
#    Модель 1 - I_RMSE: 0.4197
#    Модель 2 - I_RMSE: 0.1140
#
# ============================================================
# ТЕСТИРОВАНИЕ: 03_seasonal_beta_sin
# Описание: Сезонность (плавная β)
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 174.813416 | Data: 9963.598633 | ODE: 75.177437
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 8.003447 | Data: 680.169983 | ODE: 1.201747
# Params: β=0.2851, γ=0.1195, μ=0.0113
# ---
# Epoch  2000 | Loss: 6.062304 | Data: 497.984741 | ODE: 1.082457
# Params: β=0.2550, γ=0.1367, μ=0.0137
# ---
# Epoch  3000 | Loss: 4.821557 | Data: 389.434052 | ODE: 0.927217
# Params: β=0.2276, γ=0.1285, μ=0.0151
# ---
# Epoch  4000 | Loss: 2.939966 | Data: 222.096588 | ODE: 0.719000
# Params: β=0.1995, γ=0.1110, μ=0.0153
# ---
# Epoch  5000 | Loss: 1.386812 | Data: 82.194511 | ODE: 0.564867
# Params: β=0.1742, γ=0.0982, μ=0.0137
# ---
# Epoch  6000 | Loss: 0.901807 | Data: 43.638866 | ODE: 0.465418
# Params: β=0.1545, γ=0.0867, μ=0.0111
# ---
# Epoch  7000 | Loss: 0.658456 | Data: 27.136305 | ODE: 0.387093
# Params: β=0.1386, γ=0.0770, μ=0.0091
# ---
# Epoch  8000 | Loss: 0.524913 | Data: 19.369434 | ODE: 0.331218
# Params: β=0.1259, γ=0.0696, μ=0.0077
# ---
# Epoch  9000 | Loss: 0.467107 | Data: 16.471176 | ODE: 0.302396
# Params: β=0.1168, γ=0.0645, μ=0.0066
# ---
# Epoch 10000 | Loss: 0.436878 | Data: 14.103947 | ODE: 0.295839
# Params: β=0.1114, γ=0.0614, μ=0.0057
# ---
# Epoch 11000 | Loss: 0.426830 | Data: 13.293499 | ODE: 0.293895
# Params: β=0.1091, γ=0.0600, μ=0.0051
# ---
# Epoch 12000 | Loss: 0.421589 | Data: 12.902088 | ODE: 0.292568
# Params: β=0.1085, γ=0.0596, μ=0.0047
# ---
# Epoch 13000 | Loss: 0.422074 | Data: 12.809581 | ODE: 0.293978
# Params: β=0.1085, γ=0.0594, μ=0.0044
# ---
# Epoch 14000 | Loss: 0.415564 | Data: 12.317602 | ODE: 0.292388
# Params: β=0.1085, γ=0.0593, μ=0.0042
# ---
# Epoch 15000 | Loss: 0.414528 | Data: 12.197167 | ODE: 0.292556
# Params: β=0.1086, γ=0.0592, μ=0.0040
# ---
# Epoch 16000 | Loss: 0.413666 | Data: 12.145086 | ODE: 0.292215
# Params: β=0.1086, γ=0.0592, μ=0.0039
# ---
# Epoch 17000 | Loss: 0.413186 | Data: 12.117290 | ODE: 0.292013
# Params: β=0.1085, γ=0.0592, μ=0.0037
# ---
# Epoch 18000 | Loss: 0.412929 | Data: 12.126177 | ODE: 0.291667
# Params: β=0.1085, γ=0.0592, μ=0.0036
# ---
# Epoch 19000 | Loss: 0.418548 | Data: 12.849991 | ODE: 0.290048
# Params: β=0.1085, γ=0.0592, μ=0.0035
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 3.36e+01
#   Data Loss: 1.13e+00
#   Physics Loss: 3.25e+01
#   β mean: 0.5096 [min: 0.4200, max: 0.5993]
#   γ mean: 0.2798 [min: 0.2518, max: 0.3079]
#   μ mean: 0.0501 [min: 0.0437, max: 0.0564]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 9.33e-02
#   Data Loss: 8.88e-02
#   Physics Loss: 4.56e-03
#   β mean: 0.3326 [min: 0.1192, max: 0.6538]
#   γ mean: 0.2059 [min: 0.1177, max: 0.3161]
#   μ mean: 0.0090 [min: 0.0066, max: 0.0128]
#
# Эпоха  2000:
#   Total Loss: 5.59e-02
#   Data Loss: 5.40e-02
#   Physics Loss: 1.88e-03
#   β mean: 0.0879 [min: 0.0762, max: 0.1120]
#   γ mean: 0.0566 [min: 0.0445, max: 0.0753]
#   μ mean: 0.0027 [min: 0.0021, max: 0.0034]
#
# Эпоха  3000:
#   Total Loss: 4.00e-02
#   Data Loss: 3.88e-02
#   Physics Loss: 1.24e-03
#   β mean: 0.0718 [min: 0.0589, max: 0.1136]
#   γ mean: 0.0457 [min: 0.0308, max: 0.1034]
#   μ mean: 0.0021 [min: 0.0008, max: 0.0046]
#
# Эпоха  4000:
#   Total Loss: 2.38e-02
#   Data Loss: 2.27e-02
#   Physics Loss: 1.12e-03
#   β mean: 0.0719 [min: 0.0572, max: 0.1263]
#   γ mean: 0.0440 [min: 0.0303, max: 0.1102]
#   μ mean: 0.0018 [min: 0.0004, max: 0.0053]
#
# Эпоха  5000:
#   Total Loss: 1.70e-02
#   Data Loss: 1.67e-02
#   Physics Loss: 3.65e-04
#   β mean: 0.0791 [min: 0.0633, max: 0.1414]
#   γ mean: 0.0460 [min: 0.0303, max: 0.1174]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0047]
#
# Эпоха  6000:
#   Total Loss: 1.63e-02
#   Data Loss: 1.59e-02
#   Physics Loss: 4.31e-04
#   β mean: 0.0858 [min: 0.0698, max: 0.1390]
#   γ mean: 0.0468 [min: 0.0305, max: 0.1164]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0046]
#
# Эпоха  7000:
#   Total Loss: 1.56e-02
#   Data Loss: 1.54e-02
#   Physics Loss: 2.26e-04
#   β mean: 0.0910 [min: 0.0749, max: 0.1331]
#   γ mean: 0.0471 [min: 0.0306, max: 0.1129]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0047]
#
# Эпоха  8000:
#   Total Loss: 1.53e-02
#   Data Loss: 1.51e-02
#   Physics Loss: 1.79e-04
#   β mean: 0.0942 [min: 0.0780, max: 0.1292]
#   γ mean: 0.0473 [min: 0.0307, max: 0.1100]
#   μ mean: 0.0018 [min: 0.0003, max: 0.0047]
#
# Эпоха  9000:
#   Total Loss: 1.50e-02
#   Data Loss: 1.48e-02
#   Physics Loss: 2.28e-04
#   β mean: 0.0982 [min: 0.0818, max: 0.1336]
#   γ mean: 0.0474 [min: 0.0309, max: 0.1052]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0047]
#
# Эпоха 10000:
#   Total Loss: 1.48e-02
#   Data Loss: 1.46e-02
#   Physics Loss: 2.52e-04
#   β mean: 0.1026 [min: 0.0852, max: 0.1469]
#   γ mean: 0.0474 [min: 0.0312, max: 0.0995]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0046]
#
# Эпоха 11000:
#   Total Loss: 1.47e-02
#   Data Loss: 1.44e-02
#   Physics Loss: 2.73e-04
#   β mean: 0.1067 [min: 0.0876, max: 0.1595]
#   γ mean: 0.0476 [min: 0.0315, max: 0.0948]
#   μ mean: 0.0017 [min: 0.0002, max: 0.0045]
#
# Эпоха 12000:
#   Total Loss: 1.47e-02
#   Data Loss: 1.43e-02
#   Physics Loss: 4.38e-04
#   β mean: 0.1102 [min: 0.0893, max: 0.1702]
#   γ mean: 0.0478 [min: 0.0318, max: 0.0916]
#   μ mean: 0.0017 [min: 0.0002, max: 0.0044]
#
# Эпоха 13000:
#   Total Loss: 1.45e-02
#   Data Loss: 1.42e-02
#   Physics Loss: 2.86e-04
#   β mean: 0.1137 [min: 0.0904, max: 0.1807]
#   γ mean: 0.0479 [min: 0.0320, max: 0.0892]
#   μ mean: 0.0017 [min: 0.0002, max: 0.0044]
#
# Эпоха 14000:
#   Total Loss: 1.43e-02
#   Data Loss: 1.40e-02
#   Physics Loss: 2.82e-04
#   β mean: 0.1178 [min: 0.0914, max: 0.1932]
#   γ mean: 0.0481 [min: 0.0322, max: 0.0872]
#   μ mean: 0.0017 [min: 0.0002, max: 0.0043]
#
# Эпоха 15000:
#   Total Loss: 1.41e-02
#   Data Loss: 1.39e-02
#   Physics Loss: 2.82e-04
#   β mean: 0.1228 [min: 0.0920, max: 0.2088]
#   γ mean: 0.0483 [min: 0.0324, max: 0.0854]
#   μ mean: 0.0016 [min: 0.0002, max: 0.0041]
#
# Эпоха 16000:
#   Total Loss: 1.40e-02
#   Data Loss: 1.37e-02
#   Physics Loss: 3.59e-04
#   β mean: 0.1282 [min: 0.0922, max: 0.2258]
#   γ mean: 0.0485 [min: 0.0326, max: 0.0837]
#   μ mean: 0.0016 [min: 0.0002, max: 0.0040]
#
# Эпоха 17000:
#   Total Loss: 1.38e-02
#   Data Loss: 1.34e-02
#   Physics Loss: 3.50e-04
#   β mean: 0.1337 [min: 0.0923, max: 0.2430]
#   γ mean: 0.0487 [min: 0.0328, max: 0.0824]
#   μ mean: 0.0016 [min: 0.0002, max: 0.0038]
#
# Эпоха 18000:
#   Total Loss: 1.37e-02
#   Data Loss: 1.32e-02
#   Physics Loss: 4.79e-04
#   β mean: 0.1392 [min: 0.0923, max: 0.2599]
#   γ mean: 0.0488 [min: 0.0330, max: 0.0811]
#   μ mean: 0.0015 [min: 0.0002, max: 0.0037]
#
# Эпоха 19000:
#   Total Loss: 1.35e-02
#   Data Loss: 1.30e-02
#   Physics Loss: 5.62e-04
#   β mean: 0.1447 [min: 0.0920, max: 0.2765]
#   γ mean: 0.0490 [min: 0.0332, max: 0.0797]
#   μ mean: 0.0015 [min: 0.0002, max: 0.0037]
#
# ✅ Завершено: 03_seasonal_beta_sin
#    Модель 1 - I_RMSE: 12.1405
#    Модель 2 - I_RMSE: 45.1740
#
# ============================================================
# ТЕСТИРОВАНИЕ: 04_decaying_beta_trend
# Описание: Затухание (β 0.15→0.1)
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 2097.501465 | Data: 163470.437500 | ODE: 462.797211
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 45.750565 | Data: 3021.888184 | ODE: 15.531682
# Params: β=0.2831, γ=0.0899, μ=0.0092
# ---
# Epoch  2000 | Loss: 16.036903 | Data: 846.521667 | ODE: 7.571686
# Params: β=0.2489, γ=0.0877, μ=0.0091
# ---
# Epoch  3000 | Loss: 8.317194 | Data: 388.105591 | ODE: 4.436138
# Params: β=0.2206, γ=0.0800, μ=0.0087
# ---
# Epoch  4000 | Loss: 4.210162 | Data: 176.348907 | ODE: 2.446673
# Params: β=0.1961, γ=0.0729, μ=0.0081
# ---
# Epoch  5000 | Loss: 1.704089 | Data: 75.178146 | ODE: 0.952308
# Params: β=0.1759, γ=0.0676, μ=0.0073
# ---
# Epoch  6000 | Loss: 0.572787 | Data: 16.314178 | ODE: 0.409645
# Params: β=0.1601, γ=0.0638, μ=0.0063
# ---
# Epoch  7000 | Loss: 0.172914 | Data: 3.843218 | ODE: 0.134482
# Params: β=0.1491, γ=0.0613, μ=0.0053
# ---
# Epoch  8000 | Loss: 0.063290 | Data: 1.134537 | ODE: 0.051945
# Params: β=0.1430, γ=0.0601, μ=0.0046
# ---
# Epoch  9000 | Loss: 0.443943 | Data: 37.882824 | ODE: 0.065114
# Params: β=0.1406, γ=0.0598, μ=0.0040
# ---
# Epoch 10000 | Loss: 0.028503 | Data: 0.548168 | ODE: 0.023021
# Params: β=0.1400, γ=0.0599, μ=0.0036
# ---
# Epoch 11000 | Loss: 0.022938 | Data: 0.437876 | ODE: 0.018559
# Params: β=0.1398, γ=0.0600, μ=0.0034
# ---
# Epoch 12000 | Loss: 0.019340 | Data: 0.349020 | ODE: 0.015850
# Params: β=0.1397, γ=0.0600, μ=0.0032
# ---
# Epoch 13000 | Loss: 0.017505 | Data: 0.329018 | ODE: 0.014215
# Params: β=0.1396, γ=0.0601, μ=0.0031
# ---
# Epoch 14000 | Loss: 0.015871 | Data: 0.289504 | ODE: 0.012976
# Params: β=0.1396, γ=0.0601, μ=0.0031
# ---
# Epoch 15000 | Loss: 0.014738 | Data: 0.268585 | ODE: 0.012052
# Params: β=0.1396, γ=0.0601, μ=0.0031
# ---
# Epoch 16000 | Loss: 0.013881 | Data: 0.258838 | ODE: 0.011293
# Params: β=0.1396, γ=0.0601, μ=0.0031
# ---
# Epoch 17000 | Loss: 0.417587 | Data: 37.659042 | ODE: 0.040996
# Params: β=0.1397, γ=0.0601, μ=0.0031
# ---
# Epoch 18000 | Loss: 0.012516 | Data: 0.239257 | ODE: 0.010123
# Params: β=0.1396, γ=0.0601, μ=0.0031
# ---
# Epoch 19000 | Loss: 0.012750 | Data: 0.300814 | ODE: 0.009741
# Params: β=0.1397, γ=0.0601, μ=0.0031
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 6.22e+01
#   Data Loss: 1.29e+00
#   Physics Loss: 6.09e+01
#   β mean: 0.5104 [min: 0.4790, max: 0.5418]
#   γ mean: 0.2798 [min: 0.2261, max: 0.3335]
#   μ mean: 0.0501 [min: 0.0415, max: 0.0586]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 5.91e-01
#   Data Loss: 5.43e-01
#   Physics Loss: 4.83e-02
#   β mean: 0.5154 [min: 0.3957, max: 0.6366]
#   γ mean: 0.2456 [min: 0.1643, max: 0.3336]
#   μ mean: 0.0153 [min: 0.0135, max: 0.0185]
#
# Эпоха  2000:
#   Total Loss: 3.61e-01
#   Data Loss: 3.39e-01
#   Physics Loss: 2.16e-02
#   β mean: 0.1350 [min: 0.0467, max: 0.3541]
#   γ mean: 0.0459 [min: 0.0381, max: 0.0590]
#   μ mean: 0.0061 [min: 0.0047, max: 0.0079]
#
# Эпоха  3000:
#   Total Loss: 1.78e-01
#   Data Loss: 1.69e-01
#   Physics Loss: 9.21e-03
#   β mean: 0.2157 [min: 0.0644, max: 0.5958]
#   γ mean: 0.0414 [min: 0.0329, max: 0.0595]
#   μ mean: 0.0029 [min: 0.0022, max: 0.0038]
#
# Эпоха  4000:
#   Total Loss: 1.08e-01
#   Data Loss: 9.81e-02
#   Physics Loss: 1.04e-02
#   β mean: 0.3195 [min: 0.0873, max: 0.7119]
#   γ mean: 0.0438 [min: 0.0312, max: 0.0818]
#   μ mean: 0.0029 [min: 0.0024, max: 0.0035]
#
# Эпоха  5000:
#   Total Loss: 7.98e-02
#   Data Loss: 7.26e-02
#   Physics Loss: 7.24e-03
#   β mean: 0.3435 [min: 0.1037, max: 0.6730]
#   γ mean: 0.0445 [min: 0.0306, max: 0.0959]
#   μ mean: 0.0031 [min: 0.0028, max: 0.0033]
#
# Эпоха  6000:
#   Total Loss: 5.69e-02
#   Data Loss: 5.34e-02
#   Physics Loss: 3.53e-03
#   β mean: 0.3510 [min: 0.1157, max: 0.6236]
#   γ mean: 0.0454 [min: 0.0304, max: 0.1074]
#   μ mean: 0.0031 [min: 0.0029, max: 0.0032]
#
# Эпоха  7000:
#   Total Loss: 4.25e-02
#   Data Loss: 4.07e-02
#   Physics Loss: 1.79e-03
#   β mean: 0.3617 [min: 0.1245, max: 0.5951]
#   γ mean: 0.0465 [min: 0.0304, max: 0.1134]
#   μ mean: 0.0033 [min: 0.0028, max: 0.0037]
#
# Эпоха  8000:
#   Total Loss: 3.53e-02
#   Data Loss: 3.27e-02
#   Physics Loss: 2.56e-03
#   β mean: 0.3684 [min: 0.1319, max: 0.5781]
#   γ mean: 0.0476 [min: 0.0305, max: 0.1176]
#   μ mean: 0.0038 [min: 0.0025, max: 0.0053]
#
# Эпоха  9000:
#   Total Loss: 2.88e-02
#   Data Loss: 2.70e-02
#   Physics Loss: 1.82e-03
#   β mean: 0.3722 [min: 0.1373, max: 0.5669]
#   γ mean: 0.0483 [min: 0.0306, max: 0.1188]
#   μ mean: 0.0042 [min: 0.0023, max: 0.0067]
#
# Эпоха 10000:
#   Total Loss: 2.50e-02
#   Data Loss: 2.28e-02
#   Physics Loss: 2.17e-03
#   β mean: 0.3730 [min: 0.1398, max: 0.5585]
#   γ mean: 0.0486 [min: 0.0307, max: 0.1162]
#   μ mean: 0.0046 [min: 0.0022, max: 0.0080]
#
# Эпоха 11000:
#   Total Loss: 2.12e-02
#   Data Loss: 1.91e-02
#   Physics Loss: 2.15e-03
#   β mean: 0.3687 [min: 0.1409, max: 0.5439]
#   γ mean: 0.0486 [min: 0.0310, max: 0.1099]
#   μ mean: 0.0049 [min: 0.0021, max: 0.0091]
#
# Эпоха 12000:
#   Total Loss: 1.87e-02
#   Data Loss: 1.58e-02
#   Physics Loss: 2.85e-03
#   β mean: 0.3580 [min: 0.1403, max: 0.5215]
#   γ mean: 0.0486 [min: 0.0316, max: 0.1007]
#   μ mean: 0.0049 [min: 0.0021, max: 0.0092]
#
# Эпоха 13000:
#   Total Loss: 1.53e-02
#   Data Loss: 1.28e-02
#   Physics Loss: 2.49e-03
#   β mean: 0.3402 [min: 0.1381, max: 0.4900]
#   γ mean: 0.0489 [min: 0.0332, max: 0.0889]
#   μ mean: 0.0045 [min: 0.0023, max: 0.0079]
#
# Эпоха 14000:
#   Total Loss: 1.29e-02
#   Data Loss: 1.04e-02
#   Physics Loss: 2.51e-03
#   β mean: 0.3200 [min: 0.1365, max: 0.4567]
#   γ mean: 0.0499 [min: 0.0359, max: 0.0802]
#   μ mean: 0.0040 [min: 0.0024, max: 0.0062]
#
# Эпоха 15000:
#   Total Loss: 1.12e-02
#   Data Loss: 8.46e-03
#   Physics Loss: 2.70e-03
#   β mean: 0.3041 [min: 0.1351, max: 0.4318]
#   γ mean: 0.0516 [min: 0.0402, max: 0.0733]
#   μ mean: 0.0037 [min: 0.0026, max: 0.0050]
#
# Эпоха 16000:
#   Total Loss: 9.82e-03
#   Data Loss: 6.91e-03
#   Physics Loss: 2.92e-03
#   β mean: 0.2922 [min: 0.1339, max: 0.4135]
#   γ mean: 0.0537 [min: 0.0453, max: 0.0682]
#   μ mean: 0.0034 [min: 0.0027, max: 0.0042]
#
# Эпоха 17000:
#   Total Loss: 9.01e-03
#   Data Loss: 5.66e-03
#   Physics Loss: 3.35e-03
#   β mean: 0.2827 [min: 0.1332, max: 0.3989]
#   γ mean: 0.0561 [min: 0.0500, max: 0.0650]
#   μ mean: 0.0033 [min: 0.0028, max: 0.0037]
#
# Эпоха 18000:
#   Total Loss: 7.87e-03
#   Data Loss: 4.80e-03
#   Physics Loss: 3.07e-03
#   β mean: 0.2746 [min: 0.1332, max: 0.3863]
#   γ mean: 0.0577 [min: 0.0527, max: 0.0640]
#   μ mean: 0.0032 [min: 0.0028, max: 0.0035]
#
# Эпоха 19000:
#   Total Loss: 6.69e-03
#   Data Loss: 4.06e-03
#   Physics Loss: 2.63e-03
#   β mean: 0.2665 [min: 0.1331, max: 0.3736]
#   γ mean: 0.0594 [min: 0.0555, max: 0.0632]
#   μ mean: 0.0031 [min: 0.0028, max: 0.0034]
#
# ✅ Завершено: 04_decaying_beta_trend
#    Модель 1 - I_RMSE: 0.8062
#    Модель 2 - I_RMSE: 8.8255
#
# ============================================================
# ТЕСТИРОВАНИЕ: 05_complex_beta_gamma_dynamics
# Описание: Сложный (β+γ)
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 148.254120 | Data: 8623.972656 | ODE: 62.014397
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 5.593756 | Data: 445.263489 | ODE: 1.141121
# Params: β=0.2811, γ=0.1217, μ=0.0117
# ---
# Epoch  2000 | Loss: 3.509886 | Data: 266.127960 | ODE: 0.848606
# Params: β=0.2460, γ=0.1360, μ=0.0141
# ---
# Epoch  3000 | Loss: 2.670938 | Data: 193.475494 | ODE: 0.736183
# Params: β=0.2165, γ=0.1275, μ=0.0150
# ---
# Epoch  4000 | Loss: 1.938667 | Data: 132.478897 | ODE: 0.613878
# Params: β=0.1885, γ=0.1140, μ=0.0143
# ---
# Epoch  5000 | Loss: 1.289937 | Data: 84.051132 | ODE: 0.449426
# Params: β=0.1639, γ=0.1011, μ=0.0127
# ---
# Epoch  6000 | Loss: 0.701097 | Data: 40.238766 | ODE: 0.298709
# Params: β=0.1433, γ=0.0890, μ=0.0110
# ---
# Epoch  7000 | Loss: 0.455452 | Data: 26.114712 | ODE: 0.194305
# Params: β=0.1268, γ=0.0799, μ=0.0095
# ---
# Epoch  8000 | Loss: 0.292829 | Data: 14.662664 | ODE: 0.146202
# Params: β=0.1141, γ=0.0731, μ=0.0081
# ---
# Epoch  9000 | Loss: 0.224190 | Data: 9.714590 | ODE: 0.127044
# Params: β=0.1051, γ=0.0681, μ=0.0070
# ---
# Epoch 10000 | Loss: 0.199747 | Data: 7.605361 | ODE: 0.123693
# Params: β=0.0996, γ=0.0650, μ=0.0060
# ---
# Epoch 11000 | Loss: 0.191658 | Data: 6.720673 | ODE: 0.124452
# Params: β=0.0972, γ=0.0637, μ=0.0053
# ---
# Epoch 12000 | Loss: 0.191241 | Data: 6.678929 | ODE: 0.124451
# Params: β=0.0966, γ=0.0633, μ=0.0049
# ---
# Epoch 13000 | Loss: 0.186916 | Data: 6.326992 | ODE: 0.123646
# Params: β=0.0966, γ=0.0632, μ=0.0046
# ---
# Epoch 14000 | Loss: 0.185791 | Data: 6.303814 | ODE: 0.122753
# Params: β=0.0966, γ=0.0632, μ=0.0044
# ---
# Epoch 15000 | Loss: 0.185099 | Data: 6.230010 | ODE: 0.122799
# Params: β=0.0966, γ=0.0632, μ=0.0043
# ---
# Epoch 16000 | Loss: 0.184504 | Data: 6.219895 | ODE: 0.122305
# Params: β=0.0967, γ=0.0632, μ=0.0042
# ---
# Epoch 17000 | Loss: 0.184042 | Data: 6.184484 | ODE: 0.122198
# Params: β=0.0967, γ=0.0632, μ=0.0041
# ---
# Epoch 18000 | Loss: 0.183669 | Data: 6.154639 | ODE: 0.122123
# Params: β=0.0967, γ=0.0632, μ=0.0041
# ---
# Epoch 19000 | Loss: 0.183353 | Data: 6.132718 | ODE: 0.122026
# Params: β=0.0968, γ=0.0632, μ=0.0040
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 7.02e+00
#   Data Loss: 1.35e+00
#   Physics Loss: 5.66e+00
#   β mean: 0.5096 [min: 0.4867, max: 0.5325]
#   γ mean: 0.2798 [min: 0.2603, max: 0.2993]
#   μ mean: 0.0501 [min: 0.0493, max: 0.0510]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 2.00e-01
#   Data Loss: 1.98e-01
#   Physics Loss: 2.71e-03
#   β mean: 0.1590 [min: 0.0633, max: 0.3381]
#   γ mean: 0.1057 [min: 0.0643, max: 0.1724]
#   μ mean: 0.0051 [min: 0.0029, max: 0.0087]
#
# Эпоха  2000:
#   Total Loss: 1.37e-01
#   Data Loss: 1.32e-01
#   Physics Loss: 5.05e-03
#   β mean: 0.0707 [min: 0.0589, max: 0.1134]
#   γ mean: 0.0477 [min: 0.0310, max: 0.1079]
#   μ mean: 0.0019 [min: 0.0007, max: 0.0046]
#
# Эпоха  3000:
#   Total Loss: 6.02e-02
#   Data Loss: 5.41e-02
#   Physics Loss: 6.10e-03
#   β mean: 0.0734 [min: 0.0474, max: 0.2028]
#   γ mean: 0.0482 [min: 0.0300, max: 0.1951]
#   μ mean: 0.0014 [min: 0.0002, max: 0.0066]
#
# Эпоха  4000:
#   Total Loss: 1.77e-02
#   Data Loss: 1.54e-02
#   Physics Loss: 2.29e-03
#   β mean: 0.0976 [min: 0.0578, max: 0.3188]
#   γ mean: 0.0567 [min: 0.0301, max: 0.2317]
#   μ mean: 0.0023 [min: 0.0001, max: 0.0140]
#
# Эпоха  5000:
#   Total Loss: 1.44e-02
#   Data Loss: 1.23e-02
#   Physics Loss: 2.05e-03
#   β mean: 0.1042 [min: 0.0657, max: 0.3089]
#   γ mean: 0.0546 [min: 0.0303, max: 0.1826]
#   μ mean: 0.0023 [min: 0.0001, max: 0.0134]
#
# Эпоха  6000:
#   Total Loss: 1.20e-02
#   Data Loss: 1.09e-02
#   Physics Loss: 1.09e-03
#   β mean: 0.1106 [min: 0.0757, max: 0.2733]
#   γ mean: 0.0529 [min: 0.0309, max: 0.1395]
#   μ mean: 0.0022 [min: 0.0002, max: 0.0096]
#
# Эпоха  7000:
#   Total Loss: 1.04e-02
#   Data Loss: 9.48e-03
#   Physics Loss: 9.43e-04
#   β mean: 0.1182 [min: 0.0848, max: 0.2364]
#   γ mean: 0.0519 [min: 0.0329, max: 0.1026]
#   μ mean: 0.0021 [min: 0.0004, max: 0.0065]
#
# Эпоха  8000:
#   Total Loss: 9.49e-03
#   Data Loss: 8.50e-03
#   Physics Loss: 9.86e-04
#   β mean: 0.1240 [min: 0.0894, max: 0.2211]
#   γ mean: 0.0530 [min: 0.0367, max: 0.0844]
#   μ mean: 0.0021 [min: 0.0007, max: 0.0044]
#
# Эпоха  9000:
#   Total Loss: 8.64e-03
#   Data Loss: 7.93e-03
#   Physics Loss: 7.14e-04
#   β mean: 0.1276 [min: 0.0912, max: 0.2192]
#   γ mean: 0.0551 [min: 0.0421, max: 0.0747]
#   μ mean: 0.0021 [min: 0.0011, max: 0.0033]
#
# Эпоха 10000:
#   Total Loss: 8.17e-03
#   Data Loss: 7.49e-03
#   Physics Loss: 6.82e-04
#   β mean: 0.1311 [min: 0.0920, max: 0.2195]
#   γ mean: 0.0576 [min: 0.0491, max: 0.0681]
#   μ mean: 0.0020 [min: 0.0012, max: 0.0032]
#
# Эпоха 11000:
#   Total Loss: 8.15e-03
#   Data Loss: 7.28e-03
#   Physics Loss: 8.74e-04
#   β mean: 0.1328 [min: 0.0921, max: 0.2216]
#   γ mean: 0.0597 [min: 0.0546, max: 0.0654]
#   μ mean: 0.0020 [min: 0.0011, max: 0.0033]
#
# Эпоха 12000:
#   Total Loss: 7.65e-03
#   Data Loss: 6.96e-03
#   Physics Loss: 6.98e-04
#   β mean: 0.1349 [min: 0.0920, max: 0.2214]
#   γ mean: 0.0621 [min: 0.0617, max: 0.0626]
#   μ mean: 0.0020 [min: 0.0011, max: 0.0036]
#
# Эпоха 13000:
#   Total Loss: 7.43e-03
#   Data Loss: 6.66e-03
#   Physics Loss: 7.76e-04
#   β mean: 0.1371 [min: 0.0917, max: 0.2189]
#   γ mean: 0.0648 [min: 0.0600, max: 0.0702]
#   μ mean: 0.0020 [min: 0.0009, max: 0.0045]
#
# Эпоха 14000:
#   Total Loss: 7.26e-03
#   Data Loss: 6.43e-03
#   Physics Loss: 8.30e-04
#   β mean: 0.1398 [min: 0.0913, max: 0.2144]
#   γ mean: 0.0676 [min: 0.0580, max: 0.0793]
#   μ mean: 0.0020 [min: 0.0008, max: 0.0053]
#
# Эпоха 15000:
#   Total Loss: 6.96e-03
#   Data Loss: 6.29e-03
#   Physics Loss: 6.74e-04
#   β mean: 0.1431 [min: 0.0910, max: 0.2089]
#   γ mean: 0.0706 [min: 0.0561, max: 0.0897]
#   μ mean: 0.0021 [min: 0.0007, max: 0.0061]
#
# Эпоха 16000:
#   Total Loss: 6.79e-03
#   Data Loss: 6.12e-03
#   Physics Loss: 6.65e-04
#   β mean: 0.1473 [min: 0.0908, max: 0.2285]
#   γ mean: 0.0739 [min: 0.0544, max: 0.1016]
#   μ mean: 0.0022 [min: 0.0006, max: 0.0070]
#
# Эпоха 17000:
#   Total Loss: 6.61e-03
#   Data Loss: 5.97e-03
#   Physics Loss: 6.42e-04
#   β mean: 0.1523 [min: 0.0906, max: 0.2532]
#   γ mean: 0.0775 [min: 0.0528, max: 0.1151]
#   μ mean: 0.0023 [min: 0.0006, max: 0.0080]
#
# Эпоха 18000:
#   Total Loss: 6.81e-03
#   Data Loss: 5.88e-03
#   Physics Loss: 9.32e-04
#   β mean: 0.1578 [min: 0.0904, max: 0.2805]
#   γ mean: 0.0815 [min: 0.0514, max: 0.1303]
#   μ mean: 0.0024 [min: 0.0005, max: 0.0094]
#
# Эпоха 19000:
#   Total Loss: 6.40e-03
#   Data Loss: 5.71e-03
#   Physics Loss: 6.82e-04
#   β mean: 0.1633 [min: 0.0904, max: 0.3067]
#   γ mean: 0.0852 [min: 0.0503, max: 0.1443]
#   μ mean: 0.0026 [min: 0.0005, max: 0.0108]
#
# ✅ Завершено: 05_complex_beta_gamma_dynamics
#    Модель 1 - I_RMSE: 10.5069
#    Модель 2 - I_RMSE: 15.6538
#
# ============================================================
# ТЕСТИРОВАНИЕ: 02_lockdown_beta_jump_noise_3pct_seed42
# Описание: Локдаун + шум 3%
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 10.374982 | Data: 600.315796 | ODE: 4.371824
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 0.321175 | Data: 23.477978 | ODE: 0.086395
# Params: β=0.2852, γ=0.1178, μ=0.0112
# ---
# Epoch  2000 | Loss: 0.246047 | Data: 17.427872 | ODE: 0.071769
# Params: β=0.2556, γ=0.1405, μ=0.0135
# ---
# Epoch  3000 | Loss: 0.195664 | Data: 13.640257 | ODE: 0.059261
# Params: β=0.2250, γ=0.1555, μ=0.0160
# ---
# Epoch  4000 | Loss: 0.163882 | Data: 10.913374 | ODE: 0.054749
# Params: β=0.1984, γ=0.1506, μ=0.0179
# ---
# Epoch  5000 | Loss: 0.131762 | Data: 7.989223 | ODE: 0.051870
# Params: β=0.1731, γ=0.1320, μ=0.0191
# ---
# Epoch  6000 | Loss: 0.100629 | Data: 5.404405 | ODE: 0.046585
# Params: β=0.1494, γ=0.1133, μ=0.0190
# ---
# Epoch  7000 | Loss: 0.074454 | Data: 3.484890 | ODE: 0.039605
# Params: β=0.1288, γ=0.0981, μ=0.0170
# ---
# Epoch  8000 | Loss: 0.055030 | Data: 2.268141 | ODE: 0.032349
# Params: β=0.1116, γ=0.0864, μ=0.0144
# ---
# Epoch  9000 | Loss: 0.042245 | Data: 1.599031 | ODE: 0.026255
# Params: β=0.0979, γ=0.0776, μ=0.0120
# ---
# Epoch 10000 | Loss: 0.034645 | Data: 1.214025 | ODE: 0.022504
# Params: β=0.0871, γ=0.0711, μ=0.0100
# ---
# Epoch 11000 | Loss: 0.030956 | Data: 1.038260 | ODE: 0.020573
# Params: β=0.0791, γ=0.0665, μ=0.0084
# ---
# Epoch 12000 | Loss: 0.029307 | Data: 0.957850 | ODE: 0.019729
# Params: β=0.0735, γ=0.0636, μ=0.0070
# ---
# Epoch 13000 | Loss: 0.028833 | Data: 0.923983 | ODE: 0.019594
# Params: β=0.0703, γ=0.0622, μ=0.0060
# ---
# Epoch 14000 | Loss: 0.028698 | Data: 0.910136 | ODE: 0.019597
# Params: β=0.0690, γ=0.0618, μ=0.0052
# ---
# Epoch 15000 | Loss: 0.030746 | Data: 1.112990 | ODE: 0.019617
# Params: β=0.0686, γ=0.0618, μ=0.0046
# ---
# Epoch 16000 | Loss: 0.028613 | Data: 0.900286 | ODE: 0.019610
# Params: β=0.0684, γ=0.0619, μ=0.0042
# ---
# Epoch 17000 | Loss: 0.028618 | Data: 0.899151 | ODE: 0.019627
# Params: β=0.0683, γ=0.0620, μ=0.0039
# ---
# Epoch 18000 | Loss: 0.028622 | Data: 0.899473 | ODE: 0.019628
# Params: β=0.0682, γ=0.0620, μ=0.0037
# ---
# Epoch 19000 | Loss: 0.029312 | Data: 0.960234 | ODE: 0.019710
# Params: β=0.0681, γ=0.0621, μ=0.0037
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 1.80e+00
#   Data Loss: 1.16e+00
#   Physics Loss: 6.39e-01
#   β mean: 0.5095 [min: 0.5019, max: 0.5171]
#   γ mean: 0.2798 [min: 0.2577, max: 0.3019]
#   μ mean: 0.0501 [min: 0.0483, max: 0.0520]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 7.12e-02
#   Data Loss: 7.10e-02
#   Physics Loss: 2.41e-04
#   β mean: 0.1721 [min: 0.0540, max: 0.4080]
#   γ mean: 0.1493 [min: 0.0537, max: 0.3204]
#   μ mean: 0.0085 [min: 0.0026, max: 0.0217]
#
# Эпоха  2000:
#   Total Loss: 7.03e-02
#   Data Loss: 6.99e-02
#   Physics Loss: 4.09e-04
#   β mean: 0.1737 [min: 0.0558, max: 0.4194]
#   γ mean: 0.1502 [min: 0.0532, max: 0.3264]
#   μ mean: 0.0082 [min: 0.0023, max: 0.0216]
#
# Эпоха  3000:
#   Total Loss: 6.58e-02
#   Data Loss: 6.55e-02
#   Physics Loss: 3.67e-04
#   β mean: 0.2179 [min: 0.0583, max: 0.5498]
#   γ mean: 0.1835 [min: 0.0534, max: 0.4079]
#   μ mean: 0.0123 [min: 0.0017, max: 0.0406]
#
# Эпоха  4000:
#   Total Loss: 4.84e-02
#   Data Loss: 4.59e-02
#   Physics Loss: 2.50e-03
#   β mean: 0.2423 [min: 0.0688, max: 0.5174]
#   γ mean: 0.2152 [min: 0.0603, max: 0.4559]
#   μ mean: 0.0111 [min: 0.0034, max: 0.0290]
#
# Эпоха  5000:
#   Total Loss: 2.82e-02
#   Data Loss: 2.72e-02
#   Physics Loss: 9.35e-04
#   β mean: 0.1643 [min: 0.0378, max: 0.3216]
#   γ mean: 0.1478 [min: 0.0476, max: 0.2777]
#   μ mean: 0.0082 [min: 0.0031, max: 0.0203]
#
# Эпоха  6000:
#   Total Loss: 1.30e-02
#   Data Loss: 1.20e-02
#   Physics Loss: 1.01e-03
#   β mean: 0.1376 [min: 0.0365, max: 0.2494]
#   γ mean: 0.1326 [min: 0.0539, max: 0.2272]
#   μ mean: 0.0025 [min: 0.0020, max: 0.0043]
#
# Эпоха  7000:
#   Total Loss: 7.91e-03
#   Data Loss: 7.01e-03
#   Physics Loss: 8.95e-04
#   β mean: 0.0682 [min: 0.0373, max: 0.2079]
#   γ mean: 0.0719 [min: 0.0578, max: 0.0868]
#   μ mean: 0.0022 [min: 0.0016, max: 0.0041]
#
# Эпоха  8000:
#   Total Loss: 5.89e-03
#   Data Loss: 5.20e-03
#   Physics Loss: 6.91e-04
#   β mean: 0.0602 [min: 0.0284, max: 0.2452]
#   γ mean: 0.0596 [min: 0.0522, max: 0.0698]
#   μ mean: 0.0020 [min: 0.0012, max: 0.0040]
#
# Эпоха  9000:
#   Total Loss: 4.58e-03
#   Data Loss: 4.02e-03
#   Physics Loss: 5.60e-04
#   β mean: 0.0551 [min: 0.0242, max: 0.2847]
#   γ mean: 0.0557 [min: 0.0484, max: 0.0636]
#   μ mean: 0.0027 [min: 0.0025, max: 0.0034]
#
# Эпоха 10000:
#   Total Loss: 3.94e-03
#   Data Loss: 3.48e-03
#   Physics Loss: 4.60e-04
#   β mean: 0.0510 [min: 0.0208, max: 0.3328]
#   γ mean: 0.0563 [min: 0.0471, max: 0.0721]
#   μ mean: 0.0047 [min: 0.0029, max: 0.0094]
#
# Эпоха 11000:
#   Total Loss: 3.75e-03
#   Data Loss: 3.38e-03
#   Physics Loss: 3.68e-04
#   β mean: 0.0504 [min: 0.0210, max: 0.3634]
#   γ mean: 0.0593 [min: 0.0458, max: 0.0952]
#   μ mean: 0.0049 [min: 0.0029, max: 0.0107]
#
# Эпоха 12000:
#   Total Loss: 3.66e-03
#   Data Loss: 3.34e-03
#   Physics Loss: 3.17e-04
#   β mean: 0.0515 [min: 0.0254, max: 0.3683]
#   γ mean: 0.0622 [min: 0.0455, max: 0.1100]
#   μ mean: 0.0046 [min: 0.0029, max: 0.0094]
#
# Эпоха 13000:
#   Total Loss: 3.58e-03
#   Data Loss: 3.29e-03
#   Physics Loss: 2.89e-04
#   β mean: 0.0557 [min: 0.0365, max: 0.3557]
#   γ mean: 0.0665 [min: 0.0472, max: 0.1231]
#   μ mean: 0.0043 [min: 0.0029, max: 0.0082]
#
# Эпоха 14000:
#   Total Loss: 3.58e-03
#   Data Loss: 3.25e-03
#   Physics Loss: 3.24e-04
#   β mean: 0.0651 [min: 0.0401, max: 0.3366]
#   γ mean: 0.0696 [min: 0.0500, max: 0.1241]
#   μ mean: 0.0041 [min: 0.0029, max: 0.0074]
#
# Эпоха 15000:
#   Total Loss: 3.40e-03
#   Data Loss: 3.15e-03
#   Physics Loss: 2.45e-04
#   β mean: 0.0783 [min: 0.0443, max: 0.3106]
#   γ mean: 0.0811 [min: 0.0515, max: 0.1556]
#   μ mean: 0.0041 [min: 0.0029, max: 0.0075]
#
# Эпоха 16000:
#   Total Loss: 3.28e-03
#   Data Loss: 3.06e-03
#   Physics Loss: 2.24e-04
#   β mean: 0.0851 [min: 0.0444, max: 0.2838]
#   γ mean: 0.0825 [min: 0.0487, max: 0.1508]
#   μ mean: 0.0042 [min: 0.0029, max: 0.0077]
#
# Эпоха 17000:
#   Total Loss: 3.13e-03
#   Data Loss: 2.94e-03
#   Physics Loss: 1.89e-04
#   β mean: 0.0929 [min: 0.0445, max: 0.2504]
#   γ mean: 0.0917 [min: 0.0457, max: 0.1793]
#   μ mean: 0.0041 [min: 0.0029, max: 0.0074]
#
# Эпоха 18000:
#   Total Loss: 2.97e-03
#   Data Loss: 2.81e-03
#   Physics Loss: 1.54e-04
#   β mean: 0.0976 [min: 0.0445, max: 0.2156]
#   γ mean: 0.0951 [min: 0.0435, max: 0.1865]
#   μ mean: 0.0042 [min: 0.0029, max: 0.0079]
#
# Эпоха 19000:
#   Total Loss: 2.80e-03
#   Data Loss: 2.67e-03
#   Physics Loss: 1.24e-04
#   β mean: 0.0958 [min: 0.0441, max: 0.1828]
#   γ mean: 0.0914 [min: 0.0428, max: 0.1681]
#   μ mean: 0.0046 [min: 0.0030, max: 0.0094]
#
# ✅ Завершено: 02_lockdown_beta_jump_noise_3pct_seed42
#    Модель 1 - I_RMSE: 0.5186
#    Модель 2 - I_RMSE: 0.3900
#
# ============================================================
# ТЕСТИРОВАНИЕ: 02_lockdown_beta_jump_noise_5pct_seed123
# Описание: Локдаун + шум 5%
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 11.014154 | Data: 598.874573 | ODE: 5.025408
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 0.323922 | Data: 23.284994 | ODE: 0.091072
# Params: β=0.2871, γ=0.1168, μ=0.0110
# ---
# Epoch  2000 | Loss: 0.257911 | Data: 18.026140 | ODE: 0.077650
# Params: β=0.2607, γ=0.1390, μ=0.0131
# ---
# Epoch  3000 | Loss: 0.208825 | Data: 14.665185 | ODE: 0.062173
# Params: β=0.2310, γ=0.1556, μ=0.0156
# ---
# Epoch  4000 | Loss: 0.176821 | Data: 12.054352 | ODE: 0.056277
# Params: β=0.2043, γ=0.1539, μ=0.0176
# ---
# Epoch  5000 | Loss: 0.145028 | Data: 9.144847 | ODE: 0.053580
# Params: β=0.1788, γ=0.1361, μ=0.0190
# ---
# Epoch  6000 | Loss: 0.112768 | Data: 6.352013 | ODE: 0.049248
# Params: β=0.1546, γ=0.1168, μ=0.0194
# ---
# Epoch  7000 | Loss: 0.084714 | Data: 4.243632 | ODE: 0.042277
# Params: β=0.1331, γ=0.1008, μ=0.0177
# ---
# Epoch  8000 | Loss: 0.063201 | Data: 2.860147 | ODE: 0.034600
# Params: β=0.1152, γ=0.0883, μ=0.0151
# ---
# Epoch  9000 | Loss: 0.048515 | Data: 2.049838 | ODE: 0.028017
# Params: β=0.1007, γ=0.0789, μ=0.0127
# ---
# Epoch 10000 | Loss: 0.039577 | Data: 1.630101 | ODE: 0.023276
# Params: β=0.0892, γ=0.0719, μ=0.0105
# ---
# Epoch 11000 | Loss: 0.034854 | Data: 1.421787 | ODE: 0.020636
# Params: β=0.0804, γ=0.0669, μ=0.0088
# ---
# Epoch 12000 | Loss: 0.032808 | Data: 1.333379 | ODE: 0.019474
# Params: β=0.0742, γ=0.0636, μ=0.0074
# ---
# Epoch 13000 | Loss: 0.032131 | Data: 1.299388 | ODE: 0.019137
# Params: β=0.0704, γ=0.0618, μ=0.0062
# ---
# Epoch 14000 | Loss: 0.031944 | Data: 1.288382 | ODE: 0.019060
# Params: β=0.0686, γ=0.0611, μ=0.0054
# ---
# Epoch 15000 | Loss: 0.031877 | Data: 1.285213 | ODE: 0.019025
# Params: β=0.0679, γ=0.0611, μ=0.0047
# ---
# Epoch 16000 | Loss: 0.031843 | Data: 1.283512 | ODE: 0.019008
# Params: β=0.0677, γ=0.0612, μ=0.0043
# ---
# Epoch 17000 | Loss: 0.031822 | Data: 1.283161 | ODE: 0.018990
# Params: β=0.0675, γ=0.0613, μ=0.0039
# ---
# Epoch 18000 | Loss: 0.031810 | Data: 1.282441 | ODE: 0.018986
# Params: β=0.0674, γ=0.0614, μ=0.0037
# ---
# Epoch 19000 | Loss: 0.031799 | Data: 1.282171 | ODE: 0.018978
# Params: β=0.0674, γ=0.0614, μ=0.0036
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 1.20e+00
#   Data Loss: 1.17e+00
#   Physics Loss: 3.17e-02
#   β mean: 0.5096 [min: 0.4425, max: 0.5767]
#   γ mean: 0.2798 [min: 0.2479, max: 0.3116]
#   μ mean: 0.0501 [min: 0.0493, max: 0.0510]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 7.28e-02
#   Data Loss: 7.26e-02
#   Physics Loss: 2.26e-04
#   β mean: 0.1738 [min: 0.0534, max: 0.4144]
#   γ mean: 0.1505 [min: 0.0535, max: 0.3230]
#   μ mean: 0.0087 [min: 0.0026, max: 0.0218]
#
# Эпоха  2000:
#   Total Loss: 7.18e-02
#   Data Loss: 7.15e-02
#   Physics Loss: 3.70e-04
#   β mean: 0.1743 [min: 0.0549, max: 0.4229]
#   γ mean: 0.1505 [min: 0.0534, max: 0.3258]
#   μ mean: 0.0084 [min: 0.0024, max: 0.0216]
#
# Эпоха  3000:
#   Total Loss: 6.78e-02
#   Data Loss: 6.74e-02
#   Physics Loss: 3.80e-04
#   β mean: 0.2157 [min: 0.0588, max: 0.5497]
#   γ mean: 0.1835 [min: 0.0545, max: 0.4081]
#   μ mean: 0.0111 [min: 0.0018, max: 0.0350]
#
# Эпоха  4000:
#   Total Loss: 4.94e-02
#   Data Loss: 4.77e-02
#   Physics Loss: 1.64e-03
#   β mean: 0.2844 [min: 0.0669, max: 0.5925]
#   γ mean: 0.2441 [min: 0.0642, max: 0.4667]
#   μ mean: 0.0162 [min: 0.0018, max: 0.0535]
#
# Эпоха  5000:
# ...
#
# ✅ Завершено: 05_complex_beta_gamma_dynamics_noise_3pct_seed42
#    Модель 1 - I_RMSE: 10.9815
#    Модель 2 - I_RMSE: 13.4346
#
# ============================================================
# ТЕСТИРОВАНИЕ: 05_complex_beta_gamma_dynamics_noise_5pct_seed123
# Описание: Сложный + шум 5%
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 171.631439 | Data: 9071.200195 | ODE: 80.919449
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 7.390652 | Data: 613.280151 | ODE: 1.257850
# Params: β=0.2869, γ=0.1191, μ=0.0113
# ---
# Epoch  2000 | Loss: 4.428425 | Data: 345.771271 | ODE: 0.970712
# Params: β=0.2560, γ=0.1370, μ=0.0137
# ---
# Epoch  3000 | Loss: 3.461715 | Data: 262.437408 | ODE: 0.837341
# Params: β=0.2267, γ=0.1300, μ=0.0148
# ---
# Epoch  4000 | Loss: 2.639062 | Data: 195.318207 | ODE: 0.685881
# Params: β=0.1976, γ=0.1166, μ=0.0146
# ---
# Epoch  5000 | Loss: 1.930610 | Data: 139.252640 | ODE: 0.538084
# Params: β=0.1714, γ=0.1042, μ=0.0130
# ---
# Epoch  6000 | Loss: 1.291424 | Data: 90.730591 | ODE: 0.384118
# Params: β=0.1493, γ=0.0924, μ=0.0111
# ---
# Epoch  7000 | Loss: 0.909330 | Data: 65.151421 | ODE: 0.257816
# Params: β=0.1313, γ=0.0822, μ=0.0095
# ---
# Epoch  8000 | Loss: 0.733689 | Data: 55.853722 | ODE: 0.175152
# Params: β=0.1174, γ=0.0750, μ=0.0081
# ---
# Epoch  9000 | Loss: 0.647426 | Data: 50.984230 | ODE: 0.137584
# Params: β=0.1072, γ=0.0699, μ=0.0070
# ---
# Epoch 10000 | Loss: 0.611119 | Data: 48.427654 | ODE: 0.126842
# Params: β=0.1006, γ=0.0666, μ=0.0060
# ---
# Epoch 11000 | Loss: 0.596264 | Data: 47.003693 | ODE: 0.126227
# Params: β=0.0971, γ=0.0649, μ=0.0053
# ---
# Epoch 12000 | Loss: 0.588355 | Data: 46.202827 | ODE: 0.126327
# Params: β=0.0957, γ=0.0642, μ=0.0047
# ---
# Epoch 13000 | Loss: 0.581809 | Data: 45.667976 | ODE: 0.125129
# Params: β=0.0953, γ=0.0639, μ=0.0044
# ---
# Epoch 14000 | Loss: 0.575738 | Data: 45.133186 | ODE: 0.124406
# Params: β=0.0953, γ=0.0637, μ=0.0041
# ---
# Epoch 15000 | Loss: 0.570995 | Data: 44.695938 | ODE: 0.124036
# Params: β=0.0954, γ=0.0636, μ=0.0040
# ---
# Epoch 16000 | Loss: 0.597709 | Data: 47.326740 | ODE: 0.124441
# Params: β=0.0955, γ=0.0635, μ=0.0040
# ---
# Epoch 17000 | Loss: 0.563285 | Data: 44.133511 | ODE: 0.121950
# Params: β=0.0957, γ=0.0633, μ=0.0039
# ---
# Epoch 18000 | Loss: 0.560808 | Data: 43.962505 | ODE: 0.121183
# Params: β=0.0959, γ=0.0632, μ=0.0039
# ---
# Epoch 19000 | Loss: 0.559069 | Data: 43.814278 | ODE: 0.120926
# Params: β=0.0960, γ=0.0631, μ=0.0038
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 1.75e+00
#   Data Loss: 1.34e+00
#   Physics Loss: 4.07e-01
#   β mean: 0.5096 [min: 0.4359, max: 0.5833]
#   γ mean: 0.2798 [min: 0.2066, max: 0.3530]
#   μ mean: 0.0501 [min: 0.0469, max: 0.0534]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.54e-01
#   Data Loss: 1.48e-01
#   Physics Loss: 5.30e-03
#   β mean: 0.0733 [min: 0.0706, max: 0.0795]
#   γ mean: 0.0510 [min: 0.0364, max: 0.0804]
#   μ mean: 0.0022 [min: 0.0013, max: 0.0035]
#
# Эпоха  2000:
#   Total Loss: 1.35e-01
#   Data Loss: 1.32e-01
#   Physics Loss: 3.42e-03
#   β mean: 0.0710 [min: 0.0625, max: 0.0998]
#   γ mean: 0.0481 [min: 0.0315, max: 0.0917]
#   μ mean: 0.0020 [min: 0.0007, max: 0.0045]
#
# Эпоха  3000:
#   Total Loss: 6.05e-02
#   Data Loss: 5.70e-02
#   Physics Loss: 3.49e-03
#   β mean: 0.0697 [min: 0.0515, max: 0.1420]
#   γ mean: 0.0431 [min: 0.0301, max: 0.1193]
#   μ mean: 0.0015 [min: 0.0002, max: 0.0065]
#
# Эпоха  4000:
#   Total Loss: 3.05e-02
#   Data Loss: 2.88e-02
#   Physics Loss: 1.73e-03
#   β mean: 0.0911 [min: 0.0642, max: 0.2304]
#   γ mean: 0.0503 [min: 0.0303, max: 0.1339]
#   μ mean: 0.0021 [min: 0.0001, max: 0.0123]
#
# Эпоха  5000:
#   Total Loss: 2.70e-02
#   Data Loss: 2.62e-02
#   Physics Loss: 7.89e-04
#   β mean: 0.1041 [min: 0.0808, max: 0.2056]
#   γ mean: 0.0499 [min: 0.0313, max: 0.0986]
#   μ mean: 0.0020 [min: 0.0001, max: 0.0090]
#
# Эпоха  6000:
#   Total Loss: 2.60e-02
#   Data Loss: 2.54e-02
#   Physics Loss: 6.28e-04
#   β mean: 0.1129 [min: 0.0899, max: 0.1794]
#   γ mean: 0.0504 [min: 0.0343, max: 0.0754]
#   μ mean: 0.0019 [min: 0.0002, max: 0.0058]
#
# Эпоха  7000:
#   Total Loss: 2.53e-02
#   Data Loss: 2.48e-02
#   Physics Loss: 5.34e-04
#   β mean: 0.1182 [min: 0.0940, max: 0.1648]
#   γ mean: 0.0524 [min: 0.0414, max: 0.0630]
#   μ mean: 0.0018 [min: 0.0005, max: 0.0036]
#
# Эпоха  8000:
#   Total Loss: 2.48e-02
#   Data Loss: 2.44e-02
#   Physics Loss: 4.57e-04
#   β mean: 0.1171 [min: 0.0944, max: 0.1601]
#   γ mean: 0.0538 [min: 0.0464, max: 0.0619]
#   μ mean: 0.0018 [min: 0.0008, max: 0.0029]
#
# Эпоха  9000:
#   Total Loss: 2.45e-02
#   Data Loss: 2.40e-02
#   Physics Loss: 4.60e-04
#   β mean: 0.1147 [min: 0.0934, max: 0.1602]
#   γ mean: 0.0547 [min: 0.0486, max: 0.0624]
#   μ mean: 0.0018 [min: 0.0009, max: 0.0029]
#
# Эпоха 10000:
#   Total Loss: 2.42e-02
#   Data Loss: 2.37e-02
#   Physics Loss: 4.77e-04
#   β mean: 0.1130 [min: 0.0924, max: 0.1606]
#   γ mean: 0.0556 [min: 0.0504, max: 0.0631]
#   μ mean: 0.0018 [min: 0.0009, max: 0.0029]
#
# Эпоха 11000:
#   Total Loss: 2.43e-02
#   Data Loss: 2.34e-02
#   Physics Loss: 8.32e-04
#   β mean: 0.1119 [min: 0.0917, max: 0.1598]
#   γ mean: 0.0568 [min: 0.0512, max: 0.0639]
#   μ mean: 0.0019 [min: 0.0009, max: 0.0029]
#
# Эпоха 12000:
#   Total Loss: 2.38e-02
#   Data Loss: 2.33e-02
#   Physics Loss: 4.69e-04
#   β mean: 0.1115 [min: 0.0914, max: 0.1578]
#   γ mean: 0.0580 [min: 0.0493, max: 0.0653]
#   μ mean: 0.0018 [min: 0.0009, max: 0.0029]
#
# Эпоха 13000:
#   Total Loss: 2.37e-02
#   Data Loss: 2.32e-02
#   Physics Loss: 5.64e-04
#   β mean: 0.1116 [min: 0.0915, max: 0.1546]
#   γ mean: 0.0594 [min: 0.0476, max: 0.0713]
#   μ mean: 0.0018 [min: 0.0010, max: 0.0030]
#
# Эпоха 14000:
#   Total Loss: 2.35e-02
#   Data Loss: 2.31e-02
#   Physics Loss: 4.81e-04
#   β mean: 0.1123 [min: 0.0919, max: 0.1510]
#   γ mean: 0.0609 [min: 0.0461, max: 0.0776]
#   μ mean: 0.0019 [min: 0.0010, max: 0.0030]
#
# Эпоха 15000:
#   Total Loss: 2.34e-02
#   Data Loss: 2.30e-02
#   Physics Loss: 4.50e-04
#   β mean: 0.1134 [min: 0.0927, max: 0.1509]
#   γ mean: 0.0625 [min: 0.0448, max: 0.0845]
#   μ mean: 0.0019 [min: 0.0011, max: 0.0030]
#
# Эпоха 16000:
#   Total Loss: 2.33e-02
#   Data Loss: 2.29e-02
#   Physics Loss: 4.66e-04
#   β mean: 0.1150 [min: 0.0936, max: 0.1603]
#   γ mean: 0.0642 [min: 0.0436, max: 0.0920]
#   μ mean: 0.0019 [min: 0.0013, max: 0.0030]
#
# Эпоха 17000:
#   Total Loss: 2.32e-02
#   Data Loss: 2.28e-02
#   Physics Loss: 4.64e-04
#   β mean: 0.1168 [min: 0.0946, max: 0.1710]
#   γ mean: 0.0661 [min: 0.0425, max: 0.0999]
#   μ mean: 0.0019 [min: 0.0014, max: 0.0030]
#
# Эпоха 18000:
#   Total Loss: 2.32e-02
#   Data Loss: 2.27e-02
#   Physics Loss: 4.68e-04
#   β mean: 0.1189 [min: 0.0956, max: 0.1831]
#   γ mean: 0.0680 [min: 0.0415, max: 0.1082]
#   μ mean: 0.0020 [min: 0.0015, max: 0.0030]
#
# Эпоха 19000:
#   Total Loss: 2.31e-02
#   Data Loss: 2.26e-02
#   Physics Loss: 5.22e-04
#   β mean: 0.1213 [min: 0.0965, max: 0.1967]
#   γ mean: 0.0699 [min: 0.0406, max: 0.1169]
#   μ mean: 0.0021 [min: 0.0015, max: 0.0030]
#
# ✅ Завершено: 05_complex_beta_gamma_dynamics_noise_5pct_seed123
#    Модель 1 - I_RMSE: 11.4263
#    Модель 2 - I_RMSE: 15.3292
#
# ============================================================
# ТЕСТИРОВАНИЕ: 05_complex_beta_gamma_dynamics_noise_10pct_seed456
# Описание: Сложный + шум 10%
# ============================================================
# Всего точек: 366, Обучающих: 130, Тестовых: 236
#
# --- МОДЕЛЬ 1 (константные параметры) ---
# Epoch     0 | Loss: 165.885773 | Data: 8855.835938 | ODE: 77.327415
# Params: β=0.3000, γ=0.1000, μ=0.0100
# ---
# Epoch  1000 | Loss: 8.691783 | Data: 749.705811 | ODE: 1.194725
# Params: β=0.2858, γ=0.1192, μ=0.0113
# ---
# Epoch  2000 | Loss: 5.478029 | Data: 448.751495 | ODE: 0.990514
# Params: β=0.2524, γ=0.1363, μ=0.0139
# ---
# Epoch  3000 | Loss: 4.535850 | Data: 365.875275 | ODE: 0.877097
# Params: β=0.2220, γ=0.1269, μ=0.0151
# ---
# Epoch  4000 | Loss: 3.691168 | Data: 293.921906 | ODE: 0.751949
# Params: β=0.1929, γ=0.1120, μ=0.0148
# ---
# Epoch  5000 | Loss: 3.009216 | Data: 243.812607 | ODE: 0.571090
# Params: β=0.1670, γ=0.0996, μ=0.0130
# ---
# Epoch  6000 | Loss: 2.456445 | Data: 205.803864 | ODE: 0.398406
# Params: β=0.1455, γ=0.0897, μ=0.0112
# ---
# Epoch  7000 | Loss: 1.865456 | Data: 159.242508 | ODE: 0.273031
# Params: β=0.1281, γ=0.0819, μ=0.0097
# ---
# Epoch  8000 | Loss: 1.606924 | Data: 140.918564 | ODE: 0.197738
# Params: β=0.1143, γ=0.0744, μ=0.0084
# ---
# Epoch  9000 | Loss: 1.510194 | Data: 134.224594 | ODE: 0.167948
# Params: β=0.1041, γ=0.0690, μ=0.0073
# ---
# Epoch 10000 | Loss: 1.471366 | Data: 131.135895 | ODE: 0.160007
# Params: β=0.0973, γ=0.0655, μ=0.0063
# ---
# Epoch 11000 | Loss: 1.456903 | Data: 129.528809 | ODE: 0.161614
# Params: β=0.0936, γ=0.0637, μ=0.0056
# ---
# Epoch 12000 | Loss: 1.446077 | Data: 128.337708 | ODE: 0.162700
# Params: β=0.0922, γ=0.0630, μ=0.0051
# ---
# Epoch 13000 | Loss: 1.433822 | Data: 127.174713 | ODE: 0.162075
# Params: β=0.0918, γ=0.0627, μ=0.0048
# ---
# Epoch 14000 | Loss: 1.423963 | Data: 126.207321 | ODE: 0.161890
# Params: β=0.0917, γ=0.0626, μ=0.0047
# ---
# Epoch 15000 | Loss: 1.416501 | Data: 125.508385 | ODE: 0.161418
# Params: β=0.0917, γ=0.0624, μ=0.0046
# ---
# Epoch 16000 | Loss: 1.411831 | Data: 125.099655 | ODE: 0.160834
# Params: β=0.0917, γ=0.0622, μ=0.0045
# ---
# Epoch 17000 | Loss: 1.406141 | Data: 124.615662 | ODE: 0.159984
# Params: β=0.0918, γ=0.0621, μ=0.0043
# ---
# Epoch 18000 | Loss: 1.615421 | Data: 145.127838 | ODE: 0.164143
# Params: β=0.0920, γ=0.0620, μ=0.0042
# ---
# Epoch 19000 | Loss: 1.398407 | Data: 123.905495 | ODE: 0.159352
# Params: β=0.0921, γ=0.0620, μ=0.0041
# ---
#
# --- МОДЕЛЬ 2 (временные параметры) ---
#
# ============================================================
# НАЧАЛО ОБУЧЕНИЯ
# ============================================================
#
# Эпоха     0:
#   Total Loss: 9.86e-01
#   Data Loss: 7.95e-01
#   Physics Loss: 1.91e-01
#   β mean: 0.5096 [min: 0.4173, max: 0.6020]
#   γ mean: 0.2798 [min: 0.2313, max: 0.3283]
#   μ mean: 0.0501 [min: 0.0473, max: 0.0530]
# c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\..\NEW_PINN\PINN_time.py:77: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.ub = torch.tensor(torch.max(self.t), device=device).float()
# Эпоха  1000:
#   Total Loss: 1.66e-01
#   Data Loss: 1.64e-01
#   Physics Loss: 2.21e-03
#   β mean: 0.1610 [min: 0.0660, max: 0.3442]
#   γ mean: 0.1060 [min: 0.0671, max: 0.1674]
#   μ mean: 0.0049 [min: 0.0025, max: 0.0092]
#
# Эпоха  2000:
#   Total Loss: 1.38e-01
#   Data Loss: 1.35e-01
#   Physics Loss: 2.82e-03
#   β mean: 0.0705 [min: 0.0650, max: 0.0854]
#   γ mean: 0.0483 [min: 0.0332, max: 0.0808]
#   μ mean: 0.0018 [min: 0.0012, max: 0.0028]
#
# Эпоха  3000:
#   Total Loss: 1.14e-01
#   Data Loss: 1.11e-01
#   Physics Loss: 2.66e-03
#   β mean: 0.0618 [min: 0.0497, max: 0.1045]
#   γ mean: 0.0404 [min: 0.0302, max: 0.0928]
#   μ mean: 0.0015 [min: 0.0006, max: 0.0035]
#
# Эпоха  4000:
#   Total Loss: 5.90e-02
#   Data Loss: 5.76e-02
#   Physics Loss: 1.46e-03
#   β mean: 0.0930 [min: 0.0682, max: 0.1464]
#   γ mean: 0.0432 [min: 0.0304, max: 0.0983]
#   μ mean: 0.0016 [min: 0.0003, max: 0.0052]
#
# Эпоха  5000:
#   Total Loss: 5.29e-02
#   Data Loss: 5.19e-02
#   Physics Loss: 1.03e-03
#   β mean: 0.1149 [min: 0.0758, max: 0.1928]
#   γ mean: 0.0466 [min: 0.0305, max: 0.1099]
#   μ mean: 0.0016 [min: 0.0003, max: 0.0055]
#
# Эпоха  6000:
#   Total Loss: 5.12e-02
#   Data Loss: 5.05e-02
#   Physics Loss: 6.67e-04
#   β mean: 0.1263 [min: 0.0830, max: 0.2267]
#   γ mean: 0.0478 [min: 0.0311, max: 0.0990]
#   μ mean: 0.0017 [min: 0.0003, max: 0.0058]
#
# Эпоха  7000:
#   Total Loss: 4.99e-02
#   Data Loss: 4.96e-02
#   Physics Loss: 3.25e-04
#   β mean: 0.1410 [min: 0.0902, max: 0.2771]
#   γ mean: 0.0486 [min: 0.0331, max: 0.0784]
#   μ mean: 0.0018 [min: 0.0004, max: 0.0051]
#
# Эпоха  8000:
#   Total Loss: 4.90e-02
#   Data Loss: 4.88e-02
#   Physics Loss: 2.01e-04
#   β mean: 0.1600 [min: 0.0943, max: 0.3383]
#   γ mean: 0.0508 [min: 0.0374, max: 0.0650]
#   μ mean: 0.0019 [min: 0.0007, max: 0.0042]
#
# Эпоха  9000:
#   Total Loss: 4.85e-02
#   Data Loss: 4.83e-02
#   Physics Loss: 2.27e-04
#   β mean: 0.1790 [min: 0.0957, max: 0.3933]
#   γ mean: 0.0543 [min: 0.0453, max: 0.0589]
#   μ mean: 0.0021 [min: 0.0012, max: 0.0034]
#
# Эпоха 10000:
#   Total Loss: 4.81e-02
#   Data Loss: 4.78e-02
#   Physics Loss: 2.92e-04
#   β mean: 0.1934 [min: 0.0961, max: 0.4291]
#   γ mean: 0.0588 [min: 0.0529, max: 0.0618]
#   μ mean: 0.0023 [min: 0.0018, max: 0.0029]
#
# Эпоха 11000:
#   Total Loss: 4.78e-02
#   Data Loss: 4.75e-02
#   Physics Loss: 2.84e-04
#   β mean: 0.2026 [min: 0.0962, max: 0.4467]
#   γ mean: 0.0635 [min: 0.0501, max: 0.0705]
#   μ mean: 0.0025 [min: 0.0024, max: 0.0026]
#
# Эпоха 12000:
#   Total Loss: 4.75e-02
#   Data Loss: 4.72e-02
#   Physics Loss: 3.04e-04
#   β mean: 0.2079 [min: 0.0962, max: 0.4521]
#   γ mean: 0.0685 [min: 0.0481, max: 0.0858]
#   μ mean: 0.0027 [min: 0.0023, max: 0.0032]
#
# Эпоха 13000:
#   Total Loss: 4.73e-02
#   Data Loss: 4.69e-02
#   Physics Loss: 3.95e-04
#   β mean: 0.2109 [min: 0.0962, max: 0.4511]
#   γ mean: 0.0735 [min: 0.0466, max: 0.1024]
#   μ mean: 0.0030 [min: 0.0021, max: 0.0041]
#
# Эпоха 14000:
#   Total Loss: 4.87e-02
#   Data Loss: 4.66e-02
#   Physics Loss: 2.14e-03
#   β mean: 0.2113 [min: 0.0959, max: 0.4447]
#   γ mean: 0.0775 [min: 0.0454, max: 0.1167]
#   μ mean: 0.0032 [min: 0.0019, max: 0.0051]
#
# Эпоха 15000:
#   Total Loss: 4.72e-02
#   Data Loss: 4.66e-02
#   Physics Loss: 6.09e-04
#   β mean: 0.2120 [min: 0.0960, max: 0.4446]
#   γ mean: 0.0793 [min: 0.0451, max: 0.1229]
#   μ mean: 0.0033 [min: 0.0018, max: 0.0056]
#
# Эпоха 16000:
#   Total Loss: 4.68e-02
#   Data Loss: 4.65e-02
#   Physics Loss: 3.05e-04
#   β mean: 0.2122 [min: 0.0960, max: 0.4426]
#   γ mean: 0.0810 [min: 0.0448, max: 0.1286]
#   μ mean: 0.0034 [min: 0.0018, max: 0.0060]
#
# Эпоха 17000:
#   Total Loss: 4.66e-02
#   Data Loss: 4.63e-02
#   Physics Loss: 3.17e-04
#   β mean: 0.2144 [min: 0.0959, max: 0.4475]
#   γ mean: 0.0839 [min: 0.0442, max: 0.1394]
#   μ mean: 0.0036 [min: 0.0017, max: 0.0068]
#
# Эпоха 18000:
#   Total Loss: 4.65e-02
#   Data Loss: 4.62e-02
#   Physics Loss: 3.57e-04
#   β mean: 0.2172 [min: 0.0957, max: 0.4546]
#   γ mean: 0.0879 [min: 0.0435, max: 0.1540]
#   μ mean: 0.0039 [min: 0.0016, max: 0.0080]
#
# Эпоха 19000:
#   Total Loss: 4.63e-02
#   Data Loss: 4.60e-02
#   Physics Loss: 3.67e-04
#   β mean: 0.2201 [min: 0.0956, max: 0.4642]
#   γ mean: 0.0925 [min: 0.0427, max: 0.1709]
#   μ mean: 0.0042 [min: 0.0015, max: 0.0094]
#
# ✅ Завершено: 05_complex_beta_gamma_dynamics_noise_10pct_seed456
#    Модель 1 - I_RMSE: 14.8571
#    Модель 2 - I_RMSE: 13.9584
#
# ================================================================================
# ТЕСТИРОВАНИЕ ЗАВЕРШЕНО
# ================================================================================
# Результаты сохранены в: c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\NEW_PINN\synthetic_datasets_results_t_130
#   - Модель 1: 11 датасетов
#   - Модель 2: 11 датасетов
# C:\Users\dinara\AppData\Local\Temp\ipykernel_15356\2159218347.py:517: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
# C:\Users\dinara\AppData\Local\Temp\ipykernel_15356\2159218347.py:535: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([d[:10] + '...' for d in datasets], rotation=45, ha='right')
# ================================================================================
# ГОТОВО! Все результаты сохранены.
# ================================================================================
