# %%
import sys
sys.path.append("../")

# %%
import torch
import numpy as np
import pandas as pd
import tempfile
import torch.optim as optim
import os
import matplotlib.pyplot as plt

from experiments_rules.PINN_class import DINN
from experiments_rules.loss import *
from web.backend.utils.tensorboard_logger import TensorBoardExperimentLogger

# Определяем девайс: cuda если есть, иначе cpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

torch.manual_seed(123)
if device.type == 'cuda':
    torch.cuda.manual_seed(123)
np.random.seed(123)
torch.backends.cudnn.deterministic = True

covid_cases = pd.read_csv('simulation.csv')

S = covid_cases['S']
I = covid_cases['I']
D = covid_cases['D']
R = covid_cases['R']
susceptible = []
infected = []
dead = []
recovered = []
timesteps = []

d1 = covid_cases['S']
d2 = covid_cases['I']
d3 = covid_cases['D']
d4 = covid_cases['R']
# d5 = covid_cases['t']

for item in range(len(d4)):
    if item % 1 == 0:
        susceptible.append(d1[item])
        infected.append(d2[item])
        dead.append(d3[item])
        recovered.append(d4[item])
        timesteps.append(float(item))

x = 101

# %%
len(d4)
# Out:
# 320

# %%
def train(model: DINN, n_epochs, w1, w2, w3, w4, w5, w6, peak_position, peak_height, logger: TensorBoardExperimentLogger, description: str = "No description"):
        # Train
        print('\nStarting training...\n')

        optimizer = optim.Adam(model.params, lr=1e-4)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5000, gamma=0.1)
        logger.save_experiment_config(n_epochs, w1, w2, w3, w4, w5, w6, peak_position, peak_height, description= description)

        for epoch in range(n_epochs):
            S_pred_list = []
            I_pred_list = []
            D_pred_list = []
            R_pred_list = []
            alpha_pred_list = []

            f1, f2, f3, f4, S_pred, I_pred, D_pred, R_pred, alpha_pred = model.net_f(
                model.t_batch)
            optimizer.zero_grad()

            S_pred_list.append(model.S_min + (model.S_max - model.S_min) * S_pred)
            I_pred_list.append(model.I_min + (model.I_max - model.I_min) * I_pred)
            D_pred_list.append(model.D_min + (model.D_max - model.D_min) * D_pred)
            R_pred_list.append(model.R_min + (model.R_max - model.R_min) * R_pred)
            alpha_pred_list.append(alpha_pred)

            loss_data = data_loss(model.S_hat[:model.train_size], S_pred[:model.train_size], 
                                  model.I_hat[:model.train_size], I_pred[:model.train_size], 
                                  model.D_hat[:model.train_size], D_pred[:model.train_size], 
                                  model.R_hat[:model.train_size], R_pred[:model.train_size], 
                                  weight=1.0)

            loss_ODE = ODE_loss(f1, f2, f3, f4, weight=1.0)

            loss_IBC = initial_boundary_conditions_loss(I_pred[0], I_pred[-1], weight=1.0)

            loss_peak_position = peak_position_loss(I_pred, torch.tensor(200.0))

            loss_peak_height = peak_height_loss(I_pred, torch.tensor(140.0))

            # print(model.train_size)
            loss_slow_growth = slow_growth_penalty(I_pred, model.train_size)

            # w1 = 1000.0
            # w2 = 1.0
            # w3 = 0.5
            # w4 = 0.0
            # w5 = 2.0
            # w6 = 2.0

            loss = w1 * loss_data + w2 * loss_ODE + w3 * loss_IBC + w4 * loss_peak_position + w5 * loss_peak_height + w6 * loss_slow_growth

            loss.backward()
            optimizer.step()
            scheduler.step()

            model.losses.append(loss.item())

            logger.save_detailed_training_process(epoch, loss, loss_data, loss_ODE, loss_IBC, loss_peak_position, loss_peak_height, model.beta, model.gamma)
            
            if epoch % 2000 == 0:
                print("="*50)
                print('Epoch: ', epoch)
                print('Loss is: ', loss)
                print('Loss data: ', loss_data)
                print('Loss ODE: ', loss_ODE)
                print('Loss I_B_C: ', loss_IBC)
                print('Loss peak_position: ', loss_peak_position)
                print('Loss peak_height: ', loss_peak_height)
                print('\ndinn.beta', model.beta)
                print('dinn.gamma', model.gamma)
                print(alpha_pred.shape)
                
        # logger.save_infected_plots(model.t, model.I_hat,model.train_size, I_pred_list)
        logger.save_infected_plot_from_day_10(model.t, model.I,model.train_size, I_pred_list)
        logger.save_infected_plot_all_data(model.t, model.I,model.train_size, I_pred_list)
        logger.save_model(model)

        return S_pred_list, I_pred_list, D_pred_list, R_pred_list, alpha_pred_list

# %%
for i in range(5):
    # torch.manual_seed(123)
    if device.type == 'cuda':
        # torch.cuda.manual_seed(123)
        i = i
    # np.random.seed(123)
    # torch.backends.cudnn.deterministic = True
    logger = TensorBoardExperimentLogger(log_dir="experiments_rules", experiment_name="peak")
    dinn = DINN(timesteps, susceptible, infected, dead, recovered, device, x)
    S_pred_list, I_pred_list, D_pred_list, R_pred_list, alpha_pred_list =train(model= dinn,
                                                                            n_epochs=20001, 
                                                                            w1 = 100.0,
                                                                            w2 = 1.0,
                                                                            w3 = 0.1,
                                                                            w4 = 1.0,
                                                                            w5 = 2.0,
                                                                            w6 = 1.0,
                                                                            peak_position= 140,
                                                                            peak_height= 140, logger=logger, description = "Запуск на синтетике добавление экспертного знания, что пик должен быть в точке 140, высота пика должна быть 140. Добавила w6")
# Out:
# ✅ TensorBoard эксперимент: peak_20251109_183319
# 📊 Для просмотра: tensorboard --logdir=./runs/
#
# Starting training...
#
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# ==================================================
# Epoch:  0
# Loss is:  tensor(80921.7117, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(4.6742, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(1335.6407, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0564, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss peak_position:  tensor(40000., device='cuda:0')
# Loss peak_height:  tensor(19559.3223, device='cuda:0', grad_fn=<PowBackward0>)
#
# dinn.beta tensor([0.0667], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([0.5646], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=0, train_size=101
# ...
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# DEBUG: peak_index=1, train_size=101
# DEBUG: Peak is in training data, returning 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       8 logger = TensorBoardExperimentLogger(log_dir="experiments_rules", experiment_name="peak")
#       9 dinn = DINN(timesteps, susceptible, infected, dead, recovered, device, x)
# ---> 10 S_pred_list, I_pred_list, D_pred_list, R_pred_list, alpha_pred_list =train(model= dinn,
#      11                                                                         n_epochs=20001,
#      12                                                                         w1 = 100.0,
#      13                                                                         w2 = 1.0,
#      14                                                                         w3 = 0.1,
#      15                                                                         w4 = 1.0,
#      16                                                                         w5 = 2.0,
#      17                                                                         w6 = 1.0,
#      18                                                                         peak_position= 140,
#      19                                                                         peak_height= 140, logger=logger, description = "Запуск на синтетике добавление экспертного знания, что пик должен быть в точке 140, высота пика должна быть 140. Добавила w6")
#
# Cell In[5], line 52, in train(model, n_epochs, w1, w2, w3, w4, w5, w6, peak_position, peak_height, logger, description)
#      43 # w1 = 1000.0
#      44 # w2 = 1.0
#      45 # w3 = 0.5
#      46 # w4 = 0.0
#      47 # w5 = 2.0
#      48 # w6 = 2.0
#      50 loss = w1 * loss_data + w2 * loss_ODE + w3 * loss_IBC + w4 * loss_peak_position + w5 * loss_peak_height + w6 * loss_slow_growth
# ---> 52 loss.backward()
#      53 optimizer.step()
#      54 scheduler.step()
#
# File c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\venv\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\venv\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\dinara\Desktop\НИР\Code\PINN_LLM\venv\Lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
dinn = DINN(timesteps, susceptible, infected, dead, recovered, device, x)

# %%
S_pred_list, I_pred_list, D_pred_list, R_pred_list, alpha_pred_list =train(dinn, 30001)
# Out:
# Starting training...
#
# ==================================================
# Epoch:  0
# Loss is:  tensor(20242.5445, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(1.5568, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(462.5746, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0676, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(40000., device='cuda:0')
# Loss peak_height:  tensor(19624.2793, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([0.0035], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([0.3221], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  2000
# Loss is:  tensor(15796.0572, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(3.5659, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(110.3175, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0007, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(15329.1494, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([-0.0222], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([0.0378], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  4000
# Loss is:  tensor(12070.7117, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(14.1293, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.5672, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.2585, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(10657.1885, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([0.0019], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.7754e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  6000
# Loss is:  tensor(11008.8293, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(21.4240, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4555, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0790, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8865.9688, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([0.0007], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.4130e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  8000
# Loss is:  tensor(10830.3191, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(23.0853, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4495, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0466, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8521.3301, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([0.0005], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5048e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  10000
# Loss is:  tensor(10658.0631, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(24.8953, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4526, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8168.0820, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([8.3950e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5413e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  12000
# Loss is:  tensor(10641.0129, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.0861, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4505, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8131.9565, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([4.5326e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5480e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  14000
# Loss is:  tensor(10623.5647, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.2853, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4446, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0057, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8094.5928, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([1.6375e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5459e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  16000
# Loss is:  tensor(10613.9773, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.3965, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4409, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0053, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8073.8833, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([1.1488e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5463e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  18000
# Loss is:  tensor(10612.1616, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4181, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4391, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0051, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8069.9116, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([8.9430e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5457e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  20000
# Loss is:  tensor(10610.3438, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4397, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4379, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.9370, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([4.1356e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5479e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  22000
# Loss is:  tensor(10610.3383, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4398, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4428, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.9180, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([2.7558e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5516e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  24000
# Loss is:  tensor(10610.3257, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4399, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4425, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.8931, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([4.4261e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5509e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  26000
# Loss is:  tensor(10610.3205, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4399, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4421, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.8838, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([5.2544e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5510e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  28000
# Loss is:  tensor(10610.3188, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4400, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4422, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.8794, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([5.4185e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5510e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])
# ==================================================
# Epoch:  30000
# Loss is:  tensor(10610.3187, device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Loss data:  tensor(25.4400, device='cuda:0', dtype=torch.float64, grad_fn=<MulBackward0>)
# Loss ODE:  tensor(0.4422, device='cuda:0', grad_fn=<MulBackward0>)
# Loss I_B_C:  tensor(0.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# Loss expert:  tensor(38809., device='cuda:0')
# Loss peak_height:  tensor(8065.8770, device='cuda:0', grad_fn=<MeanBackward0>)
#
# dinn.beta tensor([5.6035e-05], device='cuda:0', grad_fn=<TanhBackward0>)
# dinn.gamma tensor([1.5509e-06], device='cuda:0', grad_fn=<TanhBackward0>)
# torch.Size([320, 1])

# %%
fig1, ax1 = plt.subplots(figsize=(10, 6))
ax1.scatter(timesteps[10:x][::10], infected[10:x][::10],
                    c='blue', alpha=0.5, lw=0.5, label='Real data')
ax1.scatter(timesteps[x:][::10], infected[x:][::10], c='white',
                    edgecolors='black', alpha=0.5, lw=0.5, label='Future data')
ax1.plot(timesteps[10:], I_pred_list[0].cpu().detach().numpy(
)[10:], 'black', alpha=0.9, 
                lw=2, label='Model', linestyle='dashed')
ax1.set_xlabel("Time, days")
ax1.set_ylabel("Infected, persons")
ax1.legend()
ax1.set_title("Infected Prediction (from day 10)")
# Out:
# Text(0.5, 1.0, 'Infected Prediction (from day 10)')

# %%
plt.scatter(timesteps[10:x][::9], infected[10:x][::9],
            c='blue', alpha=0.5, lw=0.5, label='Real data')
plt.scatter(timesteps[x:][::10], infected[x:][::10], c='white',
            edgecolors='black', alpha=0.5, lw=0.5, label='Future data')
plt.plot(timesteps[10:], I_pred_list[0].cpu().detach().numpy(
)[10:], 'black', alpha=0.9, lw=2, label='Model', linestyle='dashed')
plt.xlabel("Time, days")
plt.ylabel("Infected, persons")
plt.legend()
plt.show()

# %%
plt.scatter(timesteps[:x][::9], infected[:x][::9],
            c='blue', alpha=0.5, lw=0.5, label='Real data')
plt.scatter(timesteps[x:][::10], infected[x:][::10], c='white',
            edgecolors='black', alpha=0.5, lw=0.5, label='Future data')
plt.plot(timesteps, I_pred_list[0].cpu().detach().numpy(
), 'black', alpha=0.9, lw=2, label='Model', linestyle='dashed')
plt.xlabel("Time, days")
plt.ylabel("Infected, persons")
plt.legend()
plt.show()

# %%
def save_model(model, filepath):
    temp_dir = tempfile.gettempdir()
    temp_file_path = os.path.join(temp_dir, filepath)
    """Сохранить модель полностью"""
    torch.save({
        'model_state_dict': model.state_dict(),
        'beta_tilda': model.beta_tilda,
        'gamma_tilda': model.gamma_tilda,
        'S_max': model.S_max,
        'I_max': model.I_max,
        'D_max': model.D_max,
        'R_max': model.R_max,
        'S_min': model.S_min,
        'I_min': model.I_min,
        'D_min': model.D_min,
        'R_min': model.R_min,
        't': model.t,
        'S': model.S,
        'I': model.I,
        'D': model.D,
        'R': model.R,
        'train_size': model.train_size,  # Добавлено
        'device': model.device           # Добавлено
    }, temp_file_path)
    print(f"Model saved to {temp_file_path}")





save_model(dinn, "NEW_MODEL_dinn_cuda_2.pth")
